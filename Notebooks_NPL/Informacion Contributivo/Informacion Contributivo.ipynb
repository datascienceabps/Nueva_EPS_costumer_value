# %%
import time

# %%
pwd
# Out:
# '/content'

# %%
#https://stackoverflow.com/questions/57113226/how-to-prevent-google-colab-from-disconnecting

# %%
# #coneccion con drive
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# cd /content/drive/MyDrive/NUEVA EPS COD/Datos

# %%
import os
carpeta = 'Informacion Contributivo'
path = '/content/drive/MyDrive/NUEVA EPS COD/'+carpeta
os.chdir(path)

# %%
pwd
# Out:
# '/content/drive/MyDrive/NUEVA EPS COD/Informacion Contributivo'

# %%
#!pip list

# %% [markdown]
# # Instalacion de paquetes.

# %%
# @title Intalación de paquetes adicionales necesarios
# !pip install pyLDAvis
# !pip install pyLDAvis==2.1.2
# !pip install gensim
# muy costoso computacionalmente, tarda bastante, te recomiendo usar AWS
# !pip install pyspellchecker
# NEUTRAL, POSIITIVA, NEGATIVA
# !pip install spanish-sentiment-analysis
# !pip install sentiment-analysis-spanish
# !pip install keras tensorflow
# Necesaria para el proceso de traducción VERSION FREE 15000 CARACTARES
# !pip install googletrans
# !pip install googletrans==3.1.0a0
# Para eliminar posibles emojis
# !pip install emoji
# Para procesar texto de manera rápida con tensorflow
# !pip install tweet-preprocessor
# Out:
# Requirement already satisfied: pyLDAvis==2.1.2 in /usr/local/lib/python3.7/dist-packages (2.1.2)
# Requirement already satisfied: wheel>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (0.36.2)
# Requirement already satisfied: jinja2>=2.7.2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (2.11.3)
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (1.19.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (0.16.0)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (1.15)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (3.6.4)
# Requirement already satisfied: pandas>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (1.1.5)
# Requirement already satisfied: scipy>=0.18.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (1.4.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (2.7.3)
# Requirement already satisfied: joblib>=0.8.4 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.7.2->pyLDAvis==2.1.2) (1.1.1)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->pyLDAvis==2.1.2) (1.4.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->pyLDAvis==2.1.2) (8.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pytest->pyLDAvis==2.1.2) (54.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->pyLDAvis==2.1.2) (20.3.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->pyLDAvis==2.1.2) (1.10.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->pyLDAvis==2.1.2) (0.7.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from pytest->pyLDAvis==2.1.2) (1.15.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.0->pyLDAvis==2.1.2) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.0->pyLDAvis==2.1.2) (2.8.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.19.5)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (4.2.0)
# Requirement already satisfied: pyspellchecker in /usr/local/lib/python3.7/dist-packages (0.6.1)
# Requirement already satisfied: spanish-sentiment-analysis in /usr/local/lib/python3.7/dist-packages (1.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from spanish-sentiment-analysis) (1.19.5)
# Requirement already satisfied: marisa-trie in /usr/local/lib/python3.7/dist-packages (from spanish-sentiment-analysis) (0.7.5)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from spanish-sentiment-analysis) (3.2.5)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from spanish-sentiment-analysis) (0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from spanish-sentiment-analysis) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->spanish-sentiment-analysis) (1.15.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->spanish-sentiment-analysis) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->spanish-sentiment-analysis) (1.0.1)
# Requirement already satisfied: sentiment-analysis-spanish in /usr/local/lib/python3.7/dist-packages (0.0.25)
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.4.3)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras) (2.10.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.12)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.4.1)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.12.4)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.10.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.36.2)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.32.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow) (1.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow) (54.0.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow) (0.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow) (2.23.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.7.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow) (3.7.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow) (3.4.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (3.1.0)
# Requirement already satisfied: googletrans==3.1.0a0 in /usr/local/lib/python3.7/dist-packages (3.1.0a0)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.7/dist-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.4.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.2.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2020.12.22)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2020.12.5)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.7/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.7/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.7/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)
# Requirement already satisfied: emoji in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: tweet-preprocessor in /usr/local/lib/python3.7/dist-packages (0.6.0)

# %%
# @title instalación Dicionario
#*Instalación del diccionario que contiene las palabras clasificadas según los sentimientos, esta parte es para evaluar el vocabulario empleado a los agentes*
# Eliminamos la carpeta EmoLex en caso de que exista
# !rm -rf EmoLex/
# Descargamos un .zip con el léxico
# !wget -O emolex.zip https://raw.githubusercontent.com/larajuse/share/master/EmoLex.zip
# Descomprimimos el .zip
# !unzip emolex.zip
# Out:
# --2021-03-09 23:34:15--  https://raw.githubusercontent.com/larajuse/share/master/EmoLex.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52446 (51K) [application/zip]
# Saving to: ‘emolex.zip’
#
# emolex.zip          100%[===================>]  51.22K  --.-KB/s    in 0.01s
#
# 2021-03-09 23:34:15 (4.62 MB/s) - ‘emolex.zip’ saved [52446/52446]
#
# Archive:  emolex.zip
#    creating: EmoLex/
#   inflating: EmoLex/joy.txt
#   inflating: EmoLex/positive.txt
#   inflating: EmoLex/anticipation.txt
#   inflating: EmoLex/trust.txt
#   inflating: EmoLex/fear.txt
#   inflating: EmoLex/sadness.txt
#   inflating: EmoLex/surprise.txt
#   inflating: EmoLex/anger.txt
#   inflating: EmoLex/disgust.txt
#   inflating: EmoLex/negative.txt

# %% [markdown]
# # Librerías

# %%
#@title Librerías para NLP
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import re #expresiones regulares
import itertools
from collections import Counter 
import seaborn as sns
import matplotlib as mpl
plt.style.use('ggplot')
sns.set_context("talk")
import datetime
import dateutil

#Librerias de visualizacion dinámica
import plotly.express as px
from PIL import Image
from wordcloud import WordCloud
from pprint import pprint #Manipulacion de datos

#LDA MODEL FOR OBSERVACIONES
#quitar mas profundamente stop_words
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
import unicodedata
import tqdm
import spacy.cli
from spacy.lang.es.stop_words import STOP_WORDS 
#descargamos los modelos
from nltk.corpus import stopwords
nltk.download('stopwords')

nltk.download('punkt')
from nltk.tokenize import word_tokenize
import preprocessor as p
nltk.download('stopwords')
spacy.cli.download("es_core_news_md")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ✔ Download and installation successful
# You can now load the model via spacy.load('es_core_news_md')

# %%
####LIBRERIAS EMOCIONES
#@title Librerías de emociones
from collections import defaultdict

import googletrans
from googletrans import Translator
import emoji
import os
from sklearn.preprocessing import MinMaxScaler

#############LSTM
import sklearn 
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from keras.models import load_model
from sklearn.model_selection import train_test_split

import tensorflow as tf
from keras.preprocessing import text, sequence
from keras import Sequential
from keras.layers import Embedding, SpatialDropout1D, LSTM, Dense

# %%
#@title Librerías  modelo de Word2Vec
#word2vec modelo de EMBEDDING
#word2vec
from gensim.models import word2vec
import multiprocessing
from gensim.models import Word2Vec
from collections import defaultdict 
import seaborn as sns
sns.set_style("darkgrid")
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from scipy import stats
from pylab import rcParams
from google.colab import widgets

# %%
#@title Librerias Experiencia General del cliente 
#necesarias para evaluar la experiencia general del cliente
#clasificacion de sentimientos, en español

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from spellchecker import SpellChecker
spell = SpellChecker(language='es')
from classifier import *
clf = SentimentClassifier()
from pylab import rcParams
from google.colab import widgets
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning:
#
# sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.

# %%
#@title Librerías modelo de LDA
## APLLY LDA MODEL TO OBSERVACIONES
#Gensim para modelado de temas, indexación de documentos y recuperación de similitudes con grandes corpus
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
#Spacy para la lemmatization
import spacy
# Herramientas de graficado
import pyLDAvis
import pyLDAvis.gensim
import matplotlib.pyplot as plt
# %matplotlib inline
# Habilitado de logging para gensim (opcional)
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning:
#
# Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working

# %% [markdown]
# # Funciones Globales.

# %%
# @title Funciones Globales para la Limpieza de Texto
def elimina_tildes(cadena):
  #Función para eliminar acentos en el texto
              s = ''.join((c for c in unicodedata.normalize('NFD',cadena) if unicodedata.category(c) != 'Mn'))
              return s

        
def clean_text(text):

          ''' remove text in square brackets, remove punctuation and remove words containing numbers.'''
          text=re.sub('0','O',text)
          text = re.sub('\w*\d\w*', '', text)
          text = re.sub('[‘’“”?¿#&¡!\/$%()\|/*+=-@]', '', text)
          text= re.sub('[!"#$%&\'()*+-/<=>?@[\\]^_{|}]', '', text)
          text=re.sub('[~Œƒ„‰Š‹•™›Ÿ¢£¤¦§¨©ª«¬®°²³´µ¶·¹º»¼½¾¿ÀÁÂÃÄÅÆÇÈÉÊËÌÍÎÏÐÒÓÔÕÖ×ØÙÚÛÜÝÞß÷]','', text, flags=re.UNICODE)
          text=re.sub(':','', text, flags=re.UNICODE)
          return text

def replace(word):
  #arregla palabras como holaaa----hola, rrapido-----rapido- raaaaaaaaaaaaaaaaaapido---rapido
     if wordnet.synsets(word):
       return word 
     repl_word = re.compile(r'(\w*)(\w)\2(\w*)').sub(r'\1\2\3', word) 
     if repl_word != word:            
       return replace(repl_word)        
     else:            
       return repl_word 


def s_correction( text, patterns): 

  #Función auxiliar que corrige errores ortográficos, como rezpeto---respeto, se debe pasar una lista con estas correciones

          patterns1 = [(re.compile(regex), repl) for (regex, repl) in   patterns]      
          s = text       
          for (pattern, repl) in patterns1:        
                 (s, count) = re.subn(pattern, repl, s)    
          return s
    
def remove_stop(x, lista):
  #Función que optimiza la remoción de stop-words
  pattern = re.compile(r'\b(' + r'|'.join(lista_stop_words) + r')\b\s*')
  text = pattern.sub(' ',x)
  return text

def clean_text_p(text):
  #Quita palabras cortas 
        ''' remove text in square brackets, remove punctuation and remove words containing numbers.'''
        text =  re.sub(r'\b\w{1,3}\b', '', text) 
        return text

def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))

# %%
# @title Funcion global para la frecuencia de las palabras y polaridad de sentimientos.
def plot_10_most_common_words(count_data, count_vectorizer):
   #Grafico de frecuencias
    words = count_vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:15]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 
    
    fig = px.bar( x=words, y=counts, color_discrete_sequence=["#25427B","#33BBFF","#EBECED"], title='TÉRMINOS MÁS COMUNES EN:'+' '+segmento,  labels=dict(x="Palabra Clave", y="Frecuencia", color="Place")) #COLORES DE ECOPETROL, PUEDES VARIAR LOS COLORES
    fig.write_html(segmento+"_.html")
    fig.show()
    return words,counts

#Puntuadora de sentimientos
def polaridad(x): return np.nan if str(x) == '' else clf.predict(x)

#Ajustador de vocabulario
def adjustment_all(text, dic):
    for i, j in dic.items():
        text = text.replace(i, j)
    return text

def get_sentiment(model,text):
    text = clean_text(text)
    #tokenize
    twt = token.texts_to_sequences([text])
    twt = sequence.pad_sequences(twt, maxlen=max_len, dtype='int32')
    sentiment = model.predict(twt,batch_size=1,verbose = 2)
    sent = np.round(np.dot(sentiment,100).tolist(),0)[0]
    result = pd.DataFrame([sent_to_id.keys(),sent]).T
    result.columns = ["sentiment","percentage"]
    result=result[result.percentage !=0]
    return result


def plot_result(df, segment):
    #colors=['#D50000','#000000','#008EF8','#F5B27B','#EDECEC','#D84A09','#019BBD','#FFD000','#7800A0','#098F45','#807C7C','#85DDE9','#F55E10']
    #fig = go.Figure(data=[go.Pie(labels=df.sentiment,values=df.percentage, hole=.3,textinfo='percent',hoverinfo='percent+label',marker=dict(colors=colors, line=dict(color='#000000', width=2)))])
    #fig.show()
    colors={'amor':'rgb(213,0,0)','vacio':'rgb(0,0,0)',
                    'incertidumbre':'rgb(0,142,248)','entusiasmo':'rgb(245,178,123)',
                    'neutral':'rgb(237,236,236)','preocupación':'rgb(216,74,9)',
                    'sorpresa':'rgb(1,155,189)','diversión':'rgb(255,208,0)',
                    'odio':'rgb(120,0,160)','felicidad':'rgb(9,143,69)',
                    'desinterés':'rgb(128,124,124)','alivio':'rgb(133,221,233)',
                    'enojo':'rgb(245,94,16)',
                    'disfrute': 'rgb(141,235,59)',
                    'miedo': 'rgb(235,59,217)'
            }
    col_2={}
    for i in df.sentiment.to_list():
        col_2[i]=colors[i]
    fig = px.pie(df,values='percentage', names='sentiment',color='sentiment',color_discrete_map=col_2,hole=0.3,title=segment,)
    fig.show()
    fig.write_html(segment+"_emotion.html")

# %% [markdown]
# # Carga de rutas

# %%
# Carpeta pasada por Carlos. 8/02/2021 se conecta con drive
FOLDER_EMOTION_ANALISIS = "/content/drive/MyDrive/NPL/emotion_analysis/"
FOLDER_DATASET_TRANSCRIPT = "/content/drive/MyDrive/NPL/"
FOLDER_STOP_WORDS = "/content/drive/MyDrive/NPL/stop_word/"
FOLDER_RAW = "/content/drive/MyDrive/NPL/"

# %% [markdown]
# # Carga de Archivos

# %%
# #Conexion con drive.
# from google.colab import drive
# drive.mount('/content/drive')
# #4/1AY0e-g7ZUuKkyeFN-va4pfLDSPJp0QAACG95cHvt4W7hPy4X6ZckrfsYVhM # mmi codigo perosnal

# %%
import sqlite3
import os
import pandas as pd
import re

# %%
lista = os.listdir()
lista
# Out:
# ['jose_Informacion_Contributivo_Enero.db',
#  'jose_Informacion_Contributivo_Diciembre.db',
#  'jose_Informacion_Contributivo_Noviembre.db',
#  'jose_Informacion_contributivo_Agosto.db',
#  'my_model_emotion_jose.h5',
#  'jose_Informacion_contributivo_Septiembre.db',
#  'jose_Informacion_contributiva_Octubre.db',
#  'emolex.zip',
#  'Informacion Contributivo.ipynb',
#  'GENERAL_.html',
#  'personal_patrones.png',
#  'USUARIO NUEVA EPS INFORMACION CONTRIBUTIVO (2-GRAMAS)_.html',
#  'USUARIO NUEVA EPS INFORMACION CONTRIBUTIVO (N-GRAMAS)_.html',
#  'USUARIO INFORMACION CONTRIBUTIVO_.html',
#  'EmoLex']

# %%
#FIltro de archivos que sean solo db
lista = pd.Series(lista)
lista = lista[lista.str.contains('.db')]
lista
# Out:
# 0         jose_Informacion_Contributivo_Enero.db
# 1     jose_Informacion_Contributivo_Diciembre.db
# 2     jose_Informacion_Contributivo_Noviembre.db
# 3        jose_Informacion_contributivo_Agosto.db
# 5    jose_Informacion_contributivo_Septiembre.db
# 6       jose_Informacion_contributiva_Octubre.db
# dtype: object

# %%
for i in lista:
  conn = sqlite3.connect(i)
  def tables_in_sqlite_db(conn):
      cursor = conn.execute("SELECT name FROM sqlite_master WHERE type='table';")
      tables = [
          v[0] for v in cursor.fetchall()
          if v[0] != "sqlite_sequence"
      ]
      cursor.close()
      return tables
  name =tables_in_sqlite_db(conn)
  print(i,name)
# Out:
# jose_Informacion_Contributivo_Enero.db ['speech_to_text']
# jose_Informacion_Contributivo_Diciembre.db ['speech_to_text']
# jose_Informacion_Contributivo_Noviembre.db ['speech_to_text']
# jose_Informacion_contributivo_Agosto.db ['speech_to_text']
# jose_Informacion_contributivo_Septiembre.db ['speech_to_text']
# jose_Informacion_contributiva_Octubre.db ['speech_to_text']

# %%
dfs = []
for i in lista:
  name =i
  conn = sqlite3.connect(name)
  nameTable =tables_in_sqlite_db(conn)
  df = pd.read_sql("select * from "+nameTable[0], con=conn)
  if re.search('agosto', name, flags=re.IGNORECASE):
    df['Mes']='Agosto'

  elif re.search('septiembre', name, flags=re.IGNORECASE):
    df['Mes']='Septiembre'

  elif re.search('octubre', name, flags=re.IGNORECASE):
    df['Mes']='Octubre'

  elif re.search('noviembre', name, flags=re.IGNORECASE):
    df['Mes']='Noviembre'

  elif re.search('diciembre', name, flags=re.IGNORECASE):
    df['Mes']='Diciembre'
  elif re.search('enero', name, flags=re.IGNORECASE):
    df['Mes']='Enero'
  else:
    df['Mes']='Mal_valor'
  dfs.append(df)

# %%
dfs[-1].columns
# Out:
# Index(['name_file', 'transcripcion', 'speech_ratio', 'confidance', 'owner',
#        'raw', 'Mes'],
#       dtype='object')

# %%
for i in dfs:
  if 'client'in i.columns:
    i['transcripcion']=i['client']

# %%
for i,j in zip(dfs,lista):
  print(i.shape,j)# quiero los idex para poner al lado los nombres
df_all = pd.concat(dfs).reset_index(drop = True)
# Out:
# (698, 7) jose_Informacion_Contributivo_Enero.db
# (710, 7) jose_Informacion_Contributivo_Diciembre.db
# (686, 7) jose_Informacion_Contributivo_Noviembre.db
# (630, 7) jose_Informacion_contributivo_Agosto.db
# (670, 7) jose_Informacion_contributivo_Septiembre.db
# (882, 7) jose_Informacion_contributiva_Octubre.db

# %%
df_all['Mes'].value_counts()
# Out:
# Octubre       882
# Diciembre     710
# Enero         698
# Noviembre     686
# Septiembre    670
# Agosto        630
# Name: Mes, dtype: int64

# %%
df_all.head(1)
# Out:
#                                            name_file  ...  raw
# 0  l0040842843_20210111091020_091020_091848_50686...  ...  NaN
#
# [1 rows x 9 columns]

# %%
df_all.tail(1)
# Out:
#                                               name_file  ...                                                raw
# 4275  l0040199934_DATE-20201011222035_222617_NIT-X_C...  ...  {\n  "result_index": 0,\n  "results": [\n    {...
#
# [1 rows x 9 columns]

# %%
df_user = df_all.copy()# com ose cuenta con canal mono con agente y usuario se carga todo en user para depues lipiar al agente.
df_user.index.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Creacion de variables para deteccion y limpieza de atipicos.

# %%
print('Antes de limpieza de atipicos{}'.format(df_user.shape))
df_user['len_trans']=df_user['transcripcion'].apply(lambda x: len(x))
df_user['media'] = df_user['len_trans'].mean(axis=0)
df_user['desv'] = df_user['len_trans'].std(axis=0)
df_user['lim_atip_max'] = df_user['media'] + (3*df_user['desv'])
df_user['atipico'] = df_user['len_trans'] >= df_user['lim_atip_max']
df_user = df_user[df_user['atipico']==False]
df_user.reset_index(inplace = True, drop=True)
print('Después de limpieza de atipicos{}'.format(df_user.shape))
# Out:
# Antes de limpieza de atipicos(4276, 9)
# Después de limpieza de atipicos(4222, 14)

# %% [markdown]
# # (No correr)LSTM FOR EMOTION EXTRACTION genera un modelo

# %% [markdown]
# En esta sección se explicará como se elaboró el modelo para la extracción de emociones de las conversaciones de los usuarios. Todos los dataset empleados están en inglés. El modelo puede elaborarse o modificarse si se logra encontrar un dataset con la clasificación de las emociones en español. También podemos mejorar el modelo corriendo con emmbedings entrenados, como word2vec u otros. El modelo ya se encuentra guardado y puede ser empleado en cualquier momento, sin embargo, si se quiere modificar el modelo, algún parámetros se tiene que volver a correr y guardarlo en formato que tensor flow pueda reconocer después.
#
# Long Short Term Memory networks.

# %% [markdown]
# **Carga de los datos para el train**

# %%
# lectura en la carpeta pasada por Carlos.
data = pd.read_csv(FOLDER_EMOTION_ANALISIS+"text_emotion.csv")
data0=pd.read_csv(FOLDER_EMOTION_ANALISIS+"train.txt", sep=';',names=["content","sentiment"])

# %%
#Unión de los dataframes
data=data[['content','sentiment']]
data0=data0[['content','sentiment']]
data=pd.concat([data, data0],axis=0)
data.reset_index(inplace=True)

# %%
#Corregir errores de tipografía,
misspell_data = pd.read_csv(FOLDER_EMOTION_ANALISIS+"spell.txt",sep=":",names=["correction","misspell"])
misspell_data.misspell = misspell_data.misspell.str.strip()
misspell_data.misspell = misspell_data.misspell.str.split(" ")
misspell_data = misspell_data.explode("misspell").reset_index(drop=True)
misspell_data.drop_duplicates("misspell",inplace=True)
miss_corr = dict(zip(misspell_data.misspell, misspell_data.correction))

#Sample of the dict
{v:miss_corr[v] for v in [list(miss_corr.keys())[k] for k in range(20)]}
# Out:
# {'Steffen': 'Stephen',
#  'abilitey': 'ability',
#  'abouy': 'about',
#  'absorbtion': 'absorption',
#  'accidently': 'accidentally',
#  'accomodate': 'accommodate',
#  'acommadate': 'accommodate',
#  'acord': 'accord',
#  'adultry': 'adultery',
#  'aggresive': 'aggressive',
#  'alchohol': 'alcohol',
#  'alchoholic': 'alcoholic',
#  'allieve': 'alive',
#  'alright': 'all_right',
#  'aquantance': 'acquaintance',
#  'equire': 'acquire',
#  'nevade': 'Nevada',
#  'presbyterian': 'Presbyterian',
#  'rsx': 'RSX',
#  'susan': 'Susan'}

# %%
def misspelled_correction(val):
  #Función que corrige los errores de tipografía
    for x in val.split(): 
        if x in miss_corr.keys(): 
            val = val.replace(x, miss_corr[x]) 
    return val

# %%
data["clean_content"] = data.content.apply(lambda x : misspelled_correction(x))

# %%
#Contractions, Dataset que contiene las contracciones típicas del inglés lo cargamos para eliminar este
#tipo de escritura en el texto en inglés
contractions = pd.read_csv(FOLDER_EMOTION_ANALISIS+"datasets_697638_1220322_contractions.csv")
cont_dic = dict(zip(contractions.Contraction, contractions.Meaning))

# %%
def cont_to_meaning(val): 
  #Función que retira las contracciones en el texto (Inglés)
    for x in val.split(): 
        if x in cont_dic.keys(): 
            val = val.replace(x, cont_dic[x]) 
    return val

# %%
data.clean_content = data.clean_content.apply(lambda x : cont_to_meaning(x))
data["clean_content"]=data.content.apply(lambda x : p.clean(x))

# %%
#Puntuaction 
def punctuation(val): 
  #Función que remueve otro titpo de puntuaciones y simbolos
    punctuations = '''()-[]{};:'"\,<>./@#$%^&_~'''
  
    for x in val.lower(): 
        if x in punctuations: 
            val = val.replace(x, " ") 
    return val

# %%
sent_to_id  = {"empty":0, "sadness":1,"enthusiasm":2,"neutral":3,"worry":4,
                        "surprise":5,"love":6,"fun":7,"hate":8,"happiness":9,"boredom":10,"relief":11,"anger":12, "fear":13, "joy":14}

# %%
data["sentiment_id"] = data['sentiment'].map(sent_to_id)

# %%
label_encoder = LabelEncoder()#Vectorización de las palabras
integer_encoded = label_encoder.fit_transform(data.sentiment_id)

onehot_encoder = OneHotEncoder(sparse=False)
integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
Y = onehot_encoder.fit_transform(integer_encoded)

# %%
#División del dataset para entrenar y evaluar el modelo
X_train, X_test, y_train, y_test = train_test_split(data.clean_content,Y, random_state=1995, test_size=0.2, shuffle=True)

# %%
# Usando Keras para realizar la limpieza del texto
token = text.Tokenizer(num_words=None)
max_len = 160
Epoch = 5
token.fit_on_texts(list(X_train) + list(X_test))
X_train_pad = sequence.pad_sequences(token.texts_to_sequences(X_train), maxlen=max_len)
X_test_pad = sequence.pad_sequences(token.texts_to_sequences(X_test), maxlen=max_len)

# %%
w_idx = token.word_index

# %%
len(w_idx)
# Out:
# 36744

# %%
# #desde aqui se silencia
# embed_dim = 160
# lstm_out = 250

# model = Sequential()
# model.add(Embedding(len(w_idx) +1 , embed_dim,input_length = X_test_pad.shape[1]))
# model.add(SpatialDropout1D(0.2))
# model.add(LSTM(lstm_out, dropout=0.2, recurrent_dropout=0.2))
# model.add(Dense(15, activation='softmax'))
# #adam rmsprop 
# model.compile(loss = "categorical_crossentropy", optimizer='adam',metrics = ['accuracy'])
# print(model.summary())

# %%
# #Elección del tamaño del bacth en el dataset general
# batch_size = 32 # dejar tal cual

# %%
# model.fit(X_train_pad, y_train, epochs = Epoch, batch_size=batch_size,validation_data=(X_test_pad, y_test))
# ####modelo creeacion silenciado

# %%
# #Evaluación del modelo, con todos los accuracy 
# losses=pd.DataFrame(model.history.history)
# losses.plot();

# %%
# # #Modelo entrenado, se puede utilizar directamente.
# path = '/content/drive/MyDrive/NUEVA EPS COD/'+carpeta+'/my_model_emotion_jose.h5'
# model.save(path)
# # se genere un modelo para utilizar despues.

# %%
'/content/drive/MyDrive/NUEVA EPS COD/'+carpeta+'/my_model_emotion_jose.h5'
# Out:
# '/content/drive/MyDrive/NUEVA EPS COD/Informacion Contributivo/my_model_emotion_jose.h5'

# %% [markdown]
# # Limpieza de Audios

# %%
# temp = df_user.copy()

# %%
# df_user.columns

# %%
# cont=0
# i = df_user['transcripcion'].copy()

# re = {'comento':'documento','celulas':'cedula'}


# i = i.map(lambda x: adjustment_all(x,  re))


# prueba = i.str.findall('documento')

# cantidad =  prueba.map(lambda x: len(x))

# i = i[cantidad==0]

# prueba[cantidad==0] = prueba[cantidad==0] + i.str.findall('identidad')
# prueba[cantidad==0] = prueba[cantidad==0]+i.str.findall('civil')
# prueba[cantidad==0] = prueba[cantidad==0]+i.str.findall('cedula')
# prueba[cantidad==0] =prueba[cantidad==0]+i.str.findall('certificado nacido vivo')
# prueba[cantidad==0] =prueba[cantidad==0]+i.str.findall('celulas')




# cantidad =  prueba.map(lambda x: len(x))
# # print((cantidad==0).sum())
# # prueba[cantidad==0]
# # cantidad
# df_user['Cantidad de pacientes por llamada']=cantidad

# %%
# map = temp['Cantidad de pacientes por llamada']!=0


# fig = px.box(df_user, y=df_user[map]['Cantidad de pacientes por llamada'], title='Numero de Pacientes por llamada.')
# fig.show()
# #falata eliminar cedula o todo lo demas si  ya existe la pralabra documento.
# #falata elminar lo que este en 0
# df_user[map]['Cantidad de pacientes por llamada'].describe(percentiles=[0.05,0.015,0.25,0.50,0.75,0.85,0.95])

# %%
STOP_WORDS1=[]
for i in STOP_WORDS:
  a=elimina_tildes(i)
  STOP_WORDS1.append(i)

# %%
# @title Stop words globales. Nombres
','elvira','elvis','ely','elza','ema','emaida','emanuel','emaris','ember','emberto','embus','emelda','emely','emerita','emerson','emid','emidio','emigdio','emilce','emilda','emili','emilia','emiliana','emiliano','emilio','emilli','emilse','emilsen','emilssen','emily','emir','emira','emiro','emlia','emma','emmanuel','emmily','emperatriz','emplear','empresa','en','enais','enaliced','encarnacion','enciso','encizo','ened','enedis','eneida','enelia','eneriet','enerieth','eneyda','engracia','enid','enides','enidia','enidt','enilda','enio','enit','enith','enna','enny','enoc','enoe','enoris','enrioue','enrique','enriqueta','enriquez','enriquez','enrquez','enrrique','ensueño','enuar','enyell','epaminondas','epm','erasmo','eraso','erazmo','erazo','ercelly','ercilia','ercy','erdilia','eric','erica','erick','erik','erika','erlendy','ermeliza','ermila','erminda','erminia','erminso','erminsul','ermira','erned','ernedys','ernestina','ernesto','erney','ernilso','ervin','ery','esau','escalante','escallon','escamilla','escandon','escarpetta','escarraga','escarragas','escarria','escilda','esclava','escobar','escobedo','escolastica','escovar','escudero','escuela','esdrube','ese','esguerra','esilia','esimirey','esleida','eslendi','eslin','esly','esme','esmeralda','esmerlin','esmilda','esmira','esnayder','esneda','esnedy','esneider','esnelda','esnelia','esnery','esneth','esney','esneyder','esnna','españa','esparza','especialista','espejo','espeña','esperanza','espin','espinal','espinel','espinosa','espinoza','espitia','esquivel','essica','est','estacio','estafany','estanislao','esteba','estebali','esteban','estefam','estefani','estefania','estefanny','estefany','esteffany','estefhany','estefi','estela','estelia','estella','estephania','ester','esterling','estevan','esteven','esthefania','esther','estiben','estiven','estrada','estrella','estrellita','estrid','estupiñan','etayo','etelberto','etelvina','ethan','etm','etna','etsahin','eucaris','euclides','eudalia','eudocia','eufemia','eufemiano','eufracio','eufrasino','eugenia','eugenio','eugenioa','eugradis','eulalia','euli','eulises','eulofia','eulogio','eumir','eunice','eunise','euripides','euscategui','euse','eusebia','eusebio','eusse','eustacia','eustorgio','euvid','eva','evadista','evan','evangelina','evangelista','evarbo','evelia','evelier','evelin','evelina','evelio','evelly','evelsi','evelyn','evencio','evening','ever','everney','evert','eveyiseth','evolet','exdubar','exel','exela','expain','exposito','eybar','eyber','eyder','eydi','eydryan','eyiseth','eyleen','eylin','eylyn','eyzlen','ezequiel','ezray','fabara','faber','fabert','fabian','fabian','fabiano','fabio','fabioa','fabiola','fabricio','facundo','faency','fager','fahissury','faissury','faisully','faisuri','faisury','faizury','fajardo','falla','falon','fals','falya','fandino','fandiño','fanery','fanni','fannor','fanny','fanor','fanory','farfan','farid','faride','farley','farnery','farnesio','farney','fary','fatima','faustina','faustino','fausto','faver','favian','favid','favio','fayneri','faysiury','faysuli','fayzuly','fda','feder','federico','federman','felicia','felicidad','felicitas','felipa','felipe','felisa','felix','feneida','feniber','fenifer','feniver','fenner','ferannda','ferdinando','fergie','feria','ferla','ferley','fermin','fernada','fernadez','fernado','fernan','fernana','fernanada','fernanda','fernandez','fernandez','fernando','fernely','ferney','ferraro','ferreira','ferrer','ferrerosa','ferrin','ferro','fiallo','fich
yovanni','yovany','ysis','yubel','yubiza','yubleny','yuceth','yuco','yucuma','yudi','yudy','yuladith','yulady','yulani','yulder','yule','yuleidy','yuleni','yuleny','yuli','yulian','yuliana','yulianna','yuliany','yulied','yulier','yuliet','yuliete','yulieth','yulisa','yulisnedy','yulissa','yulith','yuliza','yullieth','yully','yulmery','yuly','yumarly','yunda','yuraima','yurani','yuranny','yurany','yureidi','yuri','yurian','yuridya','yurledy','yurley','yurly','yury','yusbeli','yusef','yusell','yuseth','yusledi','yusmery','yustes','yusti','yustres','yusty','yuttajeidi','yuttiel','yuviza','yvonne','z','zabala','zacha','zaday','zafiro','zafra','zahira','zaida','zailem','zaitler','zalamanca','zamara','zambran','zambrano','zamir','zamora','zamorano','zamudio','zandra','zapata','zape','zarah','zarama','zarante','zarate','zaray','zareth','zaria','zayda','zazipa','zea','zegarra','zeida','zein','zemanate','zemyaxe','zenaida','zenon','zharick','zharik','zipagauta','zmin','zoe','zoila','zonal','zonia','zoraida','zoray','zoraya','zorayda','zorelly','zorilla','zorrilla','zoyla','zulay','zuleima','zulema','zuleta','zuley','zuleyma','zuleyme','zulima','zully','zulma','zulman','zuluaga','zuly','zulyma','zuñiga','zuñiga','zuri','zurita','zury']
d_name=pd.read_csv(FOLDER_STOP_WORDS+'Names_2010Census.csv') 
d_name=d_name[d_name.name.notna()]
d_name['name']=d_name['name'].apply(lambda x: x.lower())
d_name=d_name.name.tolist()
a_surname=pd.read_csv(FOLDER_STOP_WORDS+'surnames_freq_ge_20_le_99.csv')
a_surname=a_surname[a_surname.surnames.notna()]
a_surname['surnames']=a_surname['surnames'].apply(lambda x: x.lower())
a_surname=a_surname.surnames.tolist()
names=a_name+b_name+c_name+d_name+a_surname

# %%
# @title Stop Words generales
stop_num=['uno','dos','tres','cuatro','cinco','seis','siete','ocho','nueve','diez','once','doce','trece','catorce','quince','dieciseis','diecisiete','dieciocho','diecinueve','veinte','veintiuno','veintidos','ventitres','veinticuatro','veinticinco','veintiseis','veintisiete','veintiocho','veintinueve','treinta','treinta y uno','treinta y dos','treinta y tres','treinta y cuatro','treinta y cinco','treinta y seis','treinta y siete','treinta y ocho','treinta y nueve','cuarenta','cuarenta y uno', 'cuarentay dos', 'cuarentay tres','cuarenta y cuatro','cuarenta y cinco', 'cuarenta y seis', 'cuarenta y siete', 'cuarentay ocho', 'cuarentay nueve', 'cincuenta', 'cincuenta y uno','cincuenta y dos', 'cincuenta y tres', 'cincuenta y cuatro', 'cincuenta y cinco', 'cincuenta y seis', 'cincuenta y siete', 'cincuenta y ocho', 'cincuenta y nueve', 'sesenta', 'sesenta y uno', 'sesenta y dos', 'sesenta y tres', 'sesenta y cuatro', 'sesenta y cinco', 'sesenta y seis', 'sesenta y siete', 'sesenta y ocho', 'sesenta y nueve', 'setenta','setenta y uno', 'setenta y dos', 'setenta y tres', 'setenta y cuatro', 'setenta y cinco', 'setenta y seis', 'setenta y siete', 'setenta y ocho', 'setenta y nueve', 'ochenta', 'ochenta y uno', 'ochenta y dos', 'ochenta y tres', 'ochenta y cuatro', 'ochenta y cinco', 'ochenta y seis', 'ochenta y siete', 'ochenta y ocho', 'ochenta y nueve', 'noventa', 'noventa y uno', 'noventa y dos', 'noventa y tres', 'noventa y cuatro', 'noventa y cinco', 'noventa y seis', 'noventa y siete', 'noventa y siete', 'noventa y ocho', 'noventa y nueve', 'cien','ciento', 'doscientos','trescientos','cuatrocientos','quinientos','seiscientos','setecientos','ochocientos', 'novecientos','mil','dosmil', 'tresmil','cuatromil','cincomil','seismil','sietemil','ochomil','nuevemil','diezmil', 'oncemil','docemil','trecemil','catorcemil','quincemil','dieciseismil','diecisietemil','dieciochomil','diecinuevemil','veintemil'  ]
sw_basico = ['ahorita','ahora','siguiente','mucho','traves','pues','dijeron','dice','gracias','senora','senor','señora','señor','buena','buen','buenos','buenas','dias','dia','noche','noches','tarde','tardes','a','al','algo','algunas','algunos','ante','antes','como','con','contra','cual','cuando','del','desde','donde','durante','e','el','ella','ellas','ellos','en','entre','era','erais','eramos','eran','eras','eres','es','esa','esas','ese','eso','esos','esta','estaba','estabais','estabamos','estaban','estabas','estad','estada','estadas','estado','estados','estais','estamos','estan','estando','estar','estara','estaran','estaras','estare','estareis','estaremos','estaria','estariais','estariamos','estarian','estarias','estas','este','esteis','estemos','esten','estes','esto','estos','estoy','estuve','estuviera','estuvierais','estuvieramos','estuvieran','estuvieras','estuvieron','estuviese','estuvieseis','estuviesemos','estuviesen','estuvieses','estuvimos','estuviste','estuvisteis','estuvo','fue','fuera','fuerais','fueramos','fueran','fueras','fueron','fuese','fueseis','fuesemos','fuesen','fueses','fui','fuimos','fuiste','fuisteis','ha','habeis','habia','habiais','habiamos','habian','habias','habida','habidas','habido','habidos','habiendo','habra','habran','habras','habre','habreis','habremos','habria','habriais','habriamos','habrian','habrias','han','has','hasta','hay','haya','hayais','hayamos','hayan','hayas','he','hemos','hube','hubiera','hubierais','hubieramos','hubieran','hubieras','hubieron','hubiese','hubieseis','hubiesemos','hubiesen','hubieses','hubimos','hubiste','hubisteis','hubo','la','las','le','les','lo','los','mas','me','mi','mia','mias','mio','mios','mis','mucho','muchos','muy','nada','ni','no','nos','nosotras','nosotros','nuestra','nuestras','nuestro','nuestros','o','os','otra','otras','otro','otros','para','pero','poco','por','porque','que','quien','quienes','se','sea','seais','seamos','sean','seas','sentid','sentida','sentidas','sentido','sentidos','sera','seran','seras','sere','sereis','seremos','seria','seriais','seriamos','serian','serias','si','siente','sin','sintiendo','sobre','sois','somos','son','soy','su','sus','suya','suyas','suyo','suyos','tambien','tanto','te','tendra','tendran','tendras','tendre','tendreis','tendremos','tendria','tendriais','tendriamos','tendrian','tendrias','tened','teneis','tenemos','tenga','tengais','tengamos','tengan','tengas','tengo','tenia','teniais','teniamos','tenian','tenias','tenida','tenidas','tenido','tenidos','teniendo','ti','tiene','tienen','tienes','todo','todos','tu','tus','tuve','tuviera','tuvierais','tuvieramos','tuvieran','tuvieras','tuvieron','tuviese','tuvieseis','tuviesemos','tuviesen','tuvieses','tuvimos','tuviste','tuvisteis','tuvo','tuya','tuyas','tuyo','tuyos','un','una','uno','unos','vosotras','vosotros','vuestra','vuestras','vuestro','vuestros','y','ya','yo','a','aca','ahi','ajena','ajenas','ajeno','ajenos','al','algo','algun','alguna','algunas','alguno','algunos','alla','alli','alli','ambos','ampleamos','ante','antes','aquel','aquella','aquellas','aquello','aquellos','aqui','aqui','arriba','asi','atras','aun','aunque','bajo','bastante','bien','cabe','cada','casi','cierta','ciertas','cierto','ciertos','como','como','con','conmigo','conseguimos','conseguir','consigo','consigue','consiguen','consigues','contigo','contra','cual','cuales','cualquier','cualquiera','cualquieras','cuan','cuan','cuando','cuanta','cuanta','cuantas','cuantas','cuanto','cuanto','cuantos','cuantos','de','dejar','del','demas','demas','demasiada','demasiadas','demasiado','demasiados','dentro','desde','donde','dos','el','el','ella','ellas','ello','ellos','empleais','emplean','emplear','empleas','empleo','en','encima','entonces','entre','era','eramos','eran','eras','eres','es','esa','esas','ese','eso','esos','esta','estaba','estado','estais','estamos','estan','estar','estas','este','esto','estos','estoy','etc','fin','fue','fueron','fui','fuimos','gueno','ha','hace','haceis','hacemos','hacen','hacer','haces','hacia','hago','hasta','incluso','intenta','intentais','intentamos','intentan','intentar','intentas','intento','ir','jamas','junto','juntos','la','largo','las','lo','los','mas','mas','me','menos','mi','mia','mia','mias','mientras','mio','mio','mios','mis','misma','mismas','mismo','mismos','modo','mucha','muchas','muchisima','muchisimas','muchisimo','muchisimos','mucho','muchos','muy','nada','ni','ningun','ninguna','ningunas','ninguno','ningunos','no','nos','nosotras','nosotros','nuestra','nuestras','nuestro','nuestros','nunca','os','otra','otras','otro','otros','para','parecer','pero','poca','pocas','poco','pocos','podeis','podemos','poder','podria','podriais','podriamos','podrian','podrias','por que','por','porque','primero desde','primero','puede','pueden','puedo','pues','que','que','querer','quien','quien','quienes','quienesquiera','quienquiera','quiza','quizas','sabe','sabeis','sabemos','saben','saber','sabes','se','segun','ser','si','si','siempre','siendo','sin','sin','sino','so','sobre','sois','solamente','solo','somos','soy','sr','sra','sres','sta','su','sus','suya','suyas','suyo','suyos','tal','tales','tambien','tambien','tampoco','tan','tanta','tantas','tanto','tantos','te','teneis','tenemos','tener','tengo','ti','tiempo','tiene','tienen','toda','todas','todo','todos','tomar','trabaja','trabajais','trabajamos','trabajan','trabajar','trabajas','trabajo','tras','tu','tu','tus','tuya','tuyo','tuyos','ultimo','un','una','unas','uno','unos','usa','usais','usamos','usan','usar','usas','uso','usted','ustedes','va','vais','valor','vamos','van','varias','varios','vaya','verdad','verdadera','vosotras','vosotros','voy','vuestra','vuestras','vuestro','vuestros','y','ya','yo']
lista_stop_words= names+stopwords.words('spanish')+stop_num+sw_basico

# %%
# @title Stop Words weird
# %%
# @title Stop words user
#Crear propia lista
# aqui se puede filtrar a el agente.
### Agregar terminos propios dl agente, de esta forma podriamos filtrar al agente del usuario.
#'paciente','autorizacion','codigo',
stop_words_user=['colaborar', 'amable', 'documento','pemitame','momento','gracias','linea','colgar',
                 'para','como','senora','tres','pero','esta','seis','favor','cinco','siete',
                 'cuatro','este','cero','treinta','nueve','senor','ocho','vale','dejo','breve',
                 'encuesta','como','buenos','dias','actuaizar','celular','correo',
                 'electronico','codigo','permitame','informacion','gracias', 'mucho',
                 'gusto','confirmar','punto','arroba','hotmail','numero',
                 'senorita','depues','despues','indico','calificacion','atencion',
                 'octubre','datos', 'normas','acuerdo','decreto','veintitres',
                 'transaccional','pagina','aplicacion','sistema','recuerde',
                 'dispocicion','virturales','telefono fijo','telefono','fijo',
                 'opcion','calificar','bienvenido','proceder', 'realizar', 'actualizacion',
                 'autorizar','hablar','habla','puesta','espera']


stop_words_user = stop_words_user#+ stop_words_user2

# %%
df_user['transcripcion']=df_user['transcripcion'].apply(lambda x: x.lower())# se transformaciontodo a minuscula.

# %%
df_user.shape
# Out:
# (4222, 14)

# %% [markdown]
# Limpieza generar a los datos.

# %%
# df_user =df_user.drop(labels='Cantidad de pacientes por llamada',axis =1)

# %%
#Aplicación de las funciones generales de limpieza de texto (puede incluir otra sí así lo desea)

df_user['transcripcion']=df_user['transcripcion'].apply(lambda x: elimina_tildes(x))

################################clean text
df_user['transcripcion']=df_user['transcripcion'].apply(lambda x: clean_text(x))

####remove short words
df_user['transcripcion']=df_user['transcripcion'].apply(lambda x: clean_text_p(x))

#Reparacion de espacios
df_user['transcripcion']=df_user['transcripcion'].map(lambda x: re.sub('\\s{2,}', ' ', x))

# %%
# las muestras no se sabe si son rpresentativas de el mes , adicionalmente se selecionaron de manera aleaotria cantidades, por lo que un analisis de cantidad por mes no aportaria informacion rela de la ditribucion de cantidad de llamadas por mes.

a=pd.DataFrame(df_user['Mes'].value_counts())
# a=a.rename(columns={'mes_x':'mes'})
a.reset_index(inplace=True)
a=a.rename(columns={'index':'Cantidad de llamadas'})
fig = px.bar(a, x='Cantidad de llamadas', y=a['Mes'], title='Cantidad de llamadas por mes')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c3c0b3f3-a1b8-44ca-a986-f5677fca3c2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c3c0b3f3-a1b8-44ca-a986-f5677fca3c2c")) {
#                     Plotly.newPlot(
#                         'c3c0b3f3-a1b8-44ca-a986-f5677fca3c2c',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Cantidad de llamadas=%{x}<br>Mes=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Octubre", "Diciembre", "Enero", "Noviembre", "Septiembre", "Agosto"], "xaxis": "x", "y": [861, 709, 693, 681, 654, 624], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
df_user.columns
# Out:
# Index(['name_file', 'agent', 'client', 'speech_ratio', 'confidance', 'Mes',
#        'transcripcion', 'owner', 'raw', 'len_trans', 'media', 'desv',
#        'lim_atip_max', 'atipico'],
#       dtype='object')

# %%
freq_important = pd.Series(' '.join(df_user['transcripcion']).split()).value_counts()[:900]

# %%
# freq_important[0:50]

# %%
lista_stop_words=lista_stop_words+stop_words_user+stop_words_weird

# %%
# %%time
df_user['transcripcion']=df_user['transcripcion'].apply(lambda x: word_tokenize(x) )
# Out:
# CPU times: user 7.35 s, sys: 28 ms, total: 7.38 s
# Wall time: 7.42 s

# %%
# df_user.head(2)

# %%
df_user['transcripcion']=df_user['transcripcion'].apply(lambda x: ' '.join(x) )
df_user_sentiment=df_user.copy()
# df_user.head(2)

# %%
# df_user.reset_index(inplace=True)

# %%
# Ajuste de vocabulario #  importante , revisar palabras con mala sintaxis, sinonimos . Entender el contexto del negocio
# revisar la reiz etimologica. Hacer este diccionario especial para NUEVA EPS , sector salud , cambiar palabras.
# se corre primero  
# adjustment = {"llegando": "llega", "llame": "llamar", "apagarlo": "pagar",
#               "facturas": "factura", "facturar": "factura",
#               "facturacion": "factura", "fractura": "factura",
#               "mensuales": "mensual",  "intereses": "interes",
#               "cobran": "cobrandome", "cobren": "cobrandome",
#               "cobrando": "cobrandome", "cobrar": "cobrandome",
#               "llegaban": "llega", "llevando": "llega",
#               "mensajes": "mensaje", "enviando_mensajes": "mensaje",
#               "sigues": "sigue", 'cuotas': 'cuota', 'llamada': 'llamar',
#               'intere': 'interes', 'interess': 'interes',
#               'memento': 'momento', "febrero": "meses",
#               'llamando': 'llamar', "enero": "meses",
#               "marzo": "meses", "abril": "meses",  "mayo": "meses",
#               "junio": "meses", "julio": "meses", "agosto": "meses",
#               "septiembre": "meses", "octubre": "meses",
#               "noviembre": "meses", "diciembre": "meses"}
adjustment ={"pacientes":"paciente",'confirmacion':'confirmar','confirmo':'confirmar','confirmar':'confirma','confirma':'confirmar','confirmarr':'confirmar',
             'autorizaciones':'autorizar','autorizacion':'autorizar','sirven':'sisben','sirve':'sisben','activos':'activo','pacientes':'paciente','beneficiarios':'beneficiario',
             'beneficiaria':'beneficiario','peritaje':'priorizar','caliza':'medicaliza','afiliados':'afiliado','registrar':'registra','registra':'registrar',
             'siguen':'sisben','septiembre':'mes','beneficiario':'beneficio','beneficiaria':'beneficio','mexico':'medico','collina':'covid','quirurgicas':'quirurgica',
             'asesores':'acceso','portas':'portal','reuiere':'requerir','procedimientos':'procedimiento','soportes':'soporte','autorizadas':'autorizar','autorizada':'autorizar',
             'mickey':'y que','hablar':'habla','medicamentos':'medicamento'}                                                                                                            
df_user['transcripcion'] = df_user['transcripcion'] .map(
                            lambda x: adjustment_all(x,  adjustment))

# %%
freq_important = pd.Series(' '.join(df_user['transcripcion']).split()).value_counts()[:900]
pd.Series(' '.join(df_user['transcripcion']).split()).value_counts()
# Out:
# para            28185
# como            22493
# senora          16581
# tres            16305
# pero            16292
#                 ...
# resurreccion        1
# rodean              1
# poblema             1
# escanearla          1
# federativo          1
# Length: 47459, dtype: int64

# %%
#Para la nube de palabras es necesario tener una cadena larga.
lista_mensajeuser=[]
for i in range(len(df_user)):
  lista_mensajeuser+=df_user['transcripcion'][i]#input debe ser un string
long_string=''.join(lista_mensajeuser)
# Creacion lista stop words
wordcloud = WordCloud(background_color="white",min_font_size=5, max_font_size=150, max_words=600, contour_width=50, contour_color='steelblue', margin=15, stopwords=lista_stop_words+['problema','pregunta'])
# Crear el word cloud
wordcloud.generate(long_string)
# Visualizar el word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F1170803A90>

# %%
time.sleep(10)

# %%
# %matplotlib inline

# %%
# %matplotlib inline
segmento = str.upper("GENERAL")
# Iniciar el count vectorizer con stop words personalizado en español
count_vectorizer = CountVectorizer(stop_words=stopwords.words('spanish')+lista_stop_words)#Usos de stop
# Ajustar y transformar los términos procesados
count_data = count_vectorizer.fit_transform(df_user['transcripcion'])
#Visualizar los términos mas comunes
plot_10_most_common_words(count_data, count_vectorizer)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d2e3de77-ada6-468f-83df-8455b1ea3177" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d2e3de77-ada6-468f-83df-8455b1ea3177")) {
#                     Plotly.newPlot(
#                         'd2e3de77-ada6-468f-83df-8455b1ea3177',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Palabra Clave=%{x}<br>Frecuencia=%{y}", "legendgroup": "", "marker": {"color": "#25427B"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["medicamento", "formula", "entrega", "correcto", "directamente", "decir", "aparece", "mejor", "reclamar", "respuesta", "solicitud", "meses", "luego", "parte", "fecha"], "xaxis": "x", "y": [7149.0, 3776.0, 3263.0, 2993.0, 2580.0, 2420.0, 2290.0, 2245.0, 2233.0, 2160.0, 2155.0, 2101.0, 2069.0, 2028.0, 2026.0], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...
# (['medicamento',
#   'formula',
#   'entrega',
#   'correcto',
#   'directamente',
#   'decir',
#   'aparece',
#   'mejor',
#   'reclamar',
#   'respuesta',
#   'solicitud',
#   'meses',
#   'luego',
#   'parte',
#   'fecha'],
#  [7149.0,
#   3776.0,
#   3263.0,
#   2993.0,
#   2580.0,
#   2420.0,
#   2290.0,
#   2245.0,
#   2233.0,
#   2160.0,
#   2155.0,
#   2101.0,
#   2069.0,
#   2028.0,
#   2026.0])

# %%
mapa =[]
for i,j in df_user.iterrows():
  x = (j['transcripcion'].find('puesta espera'))
  if x ==-1:
    mapa.append(False)
  else:
    mapa.append(True)

# %%
print(df_user.shape,len(mapa),sum(mapa))
# Out:
# (4222, 14) 4222 6

# %%
existencia = df_user[mapa]
num =3
display(existencia.iloc[num])
display(existencia.iloc[num]['name_file'])
display(existencia.iloc[num]['transcripcion'])
# Out:
# name_file        l0040477839_DATE-20201120143002_145819_NIT-X_C...
# agent             llamada su llamada su llamada su llamada su l...
# client            fue puesta en espera fue puesta en espera fue...
# speech_ratio                                                 0.809
# confidance                                                0.867692
# Mes                                                      Noviembre
# transcripcion    puesta espera puesta espera puesta espera pues...
# owner                                                          NaN
# raw                                                            NaN
# len_trans                                                    13351
# media                                                      4121.16
# desv                                                       3338.19
# lim_atip_max                                               14135.7
# atipico                                                      False
# Name: 1957, dtype: object
# 'l0040477839_DATE-20201120143002_145819_NIT-X_CC-X_EXT-55502_AGE-71896.wav'
# 'puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera expuesta especias puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera cuesta especias puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera cuesta pegas puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera expuesta especias puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta esteras puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera puesta espera ...

# %% [markdown]
# Guardado  de la informacion limpia para el **usuario**, este paso es muy importante ya que define los dataframes con los que vamos a trabajar después.

# %% [markdown]
# #Afiliaciones

# %%
df_personal=df_user.copy()
#df_personal=df_personal.drop_duplicates('GUID') #Quitamos los duplicados porque algunas llamadas son transferidas a otros agentes que pertenecen a otras operaciones, y quedan con el mismo GUIID

# %%
df_personal.reset_index(inplace=True, drop=True)

# %%
#Eliminamos los espacios al inicio y al final de cada strig
df_personal['transcripcion']=df_personal['transcripcion'].apply(lambda x: x.strip() if type(x)==str else x)

# %%
df_personal.head(2)
# Out:
#                                            name_file  ... atipico
# 0  l0040842843_20210111091020_091020_091848_50686...  ...   False
# 1  l0040885536_DATE-20210117124301_125646_NIT-X_C...  ...   False
#
# [2 rows x 14 columns]

# %% [markdown]
# <b><font color=orange size=5>Patrones</font></b>

# %% [markdown]
# **Necesitamos que el índice sea secuencial**

# %%
lista_mensajeuser=[]
for i in range(len(df_personal)):
  lista_mensajeuser+=df_personal['transcripcion'][i]
long_string=''.join(lista_mensajeuser)
#Creacion lista stop words
wordcloud = WordCloud(background_color="white",min_font_size=5, max_font_size=150, max_words=600, contour_width=50, contour_color='steelblue', margin=15, stopwords=lista_stop_words)
#Crear el word cloud
wordcloud.generate(long_string)
#Visualizar el word cloud
wordcloud.to_file('personal_patrones.png')
wordcloud.to_image()
#revisar estas palabras, la semantica  y cojer palabras raras (fuera de contexto) Tranformarlas. Con el codifo de arriba aqui se hace crecer esta lista.
#escuchar audios para estar en contexto.
#Esto dalogia a los patrones iniciales.
#Proceso ciclico.
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F1166261B90>

# %% [markdown]
# <b><font color=orange size=5>TERMINOS CLAVE N-GRAMAS</font></b>

# %% [markdown]
# Para obtener la Figura de los N-Gramas solo debemos especificar el N-range en la función CountVectorizer para que este vectorice las palabras conjuntas.

# %% [markdown]
# A continuación se presenta la función para corregir la ortografía

# %%
### importante para definir si hay que adicionar terminos a nuestro diccionario.
lista=[(r'certificadoes','certificado'),(r'educativos','educativo'),(r'beneficiaria','beneficiario'),
       (r'solicitud','solicitar'),(r'solicitar','solicita'),(r'solicita','solicitar'),(r'beneficios','beneficio'),(r'legalizaron','legalizar'), (r'legalizacion','legalizar'),
       (r'personajes','personaje'), (r'certificadoes','certificado'), (r'certificacion','certificado'), (r'disponibles','disponible'),
       (r'certificados','certificado'), (r'documentos','documento'), (r'disfrute','disfrutar'), (r'pagara','pagar'), (r'pagare','pagar'),
       (r'tratando','tratar'),(r'reportes','reporte'),(r'desprendibles','desprendible')]
       
df_personal['transcripcion']=df_personal['transcripcion'].apply(lambda x: s_correction(x, lista))

# %%
time.sleep(10)

# %%
# %matplotlib inline

# %%
# %matplotlib inline
segmento = str.upper("USUARIO NUEVA EPS "+carpeta+" (2-gramas)")
# Iniciar el count vectorizer con stop words personalizado en español
count_vectorizer = CountVectorizer(stop_words=['entiendo','pregunta','desempena','quincena']+lista_stop_words,ngram_range=(2, 2))
# Ajustar y transformar los términos procesados
count_data = count_vectorizer.fit_transform(df_personal['transcripcion'])
#Visualizar los términos mas comunes
words,counts = plot_10_most_common_words(count_data, count_vectorizer)

#trigramas , identifica que otras dos palabras esta asosiado a una misma palabra. se muestra el top 15.
# de que se esta hablando a un nivel general. Tambien sirve para reconocer las palabras para el filtro.
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a4626294-85ad-4c39-9e81-bd723693fac6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a4626294-85ad-4c39-9e81-bd723693fac6")) {
#                     Plotly.newPlot(
#                         'a4626294-85ad-4c39-9e81-bd723693fac6',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Palabra Clave=%{x}<br>Frecuencia=%{y}", "legendgroup": "", "marker": {"color": "#25427B"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["regimen subsidiado", "mensaje texto", "tercera entrega", "medicamento medicamento", "reclamar medicamento", "oficina administrativa", "parte derecha", "formula formula", "disposicion virtuales", "entrega medicamento", "ultima entrega", "regimen contributivo", "entrega entrega", "certificado afiliacion", "entrega reclamar"], "xaxis": "x", "y": [398.0, 297.0, 290.0, 279.0, 273.0, 234.0, 231.0, 227.0, 210.0, 204.0, 192.0, 184.0, 174.0, 170.0, 153.0], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
# %matplotlib inline
segmento = str.upper("USUARIO NUEVA EPS "+carpeta+" (N-gramas)")
# Iniciar el count vectorizer con stop words personalizado en español
count_vectorizer = CountVectorizer(stop_words=['entiendo','pregunta','desempena','quincena']+lista_stop_words,ngram_range=(3, 3))
# Ajustar y transformar los términos procesados
count_data = count_vectorizer.fit_transform(df_personal['transcripcion'])
#Visualizar los términos mas comunes
words,counts = plot_10_most_common_words(count_data, count_vectorizer)

#trigramas , identifica que otras dos palabras esta asosiado a una misma palabra. se muestra el top 15.
# de que se esta hablando a un nivel general. Tambien sirve para reconocer las palabras para el filtro.
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1e4feb3e-3101-4ee5-aa0e-397d59392a52" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1e4feb3e-3101-4ee5-aa0e-397d59392a52")) {
#                     Plotly.newPlot(
#                         '1e4feb3e-3101-4ee5-aa0e-397d59392a52',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Palabra Clave=%{x}<br>Frecuencia=%{y}", "legendgroup": "", "marker": {"color": "#25427B"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["respuesta podra consultar", "podra consultar tipo", "vigentes proximos meses", "medicamento procedimiento insumos", "relacionadas tratamiento personales", "formulario unico afiliacion", "disposicion virtuales respuesta", "entrega valida reclamar", "recibir mensaje texto", "disposicion virtuales audio", "tratamiento personales agradecemos", "virtuales audio respuesta", "personales agradecemos llevar", "texto vigentes proximos", "asunto colocar formula"], "xaxis": "x", "y": [64.0, 58.0, 54.0, 50.0, 45.0, 39.0, 38.0, 38.0, 33.0, 30.0, 30.0, 30.0, 28.0, 28.0, 27.0], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
# saca los ngramas para luegro pintarlo en power bi
n_gramas_for_powerbi = pd.DataFrame()
n_gramas_for_powerbi["word"] = words
n_gramas_for_powerbi["freq"] = counts
n_gramas_for_powerbi.set_index("word", inplace=True)
# lista guarda ngramas , explotarlo a excel , pandas to excel.

# %% [markdown]
# <b><font color=orange size=5> TERMINOS CLAVE</font></b>

# %%
time.sleep(2)

# %%
# %matplotlib inline

# %%
# %matplotlib inline
segmento = str.upper("Usuario "+carpeta)
# Iniciar el count vectorizer con stop words personalizado en español
count_vectorizer = CountVectorizer(stop_words=['interes','ejemplo','personas','llega','hablar','nuevamente','envie',
                                               'diciendo','llamada','envio','aparece','necesito','respuesta','informacion',
                                               'entiendo','solicitud','problema','pregunta', 'haciendo']+lista_stop_words)
# Ajustar y transformar los términos procesados
count_data = count_vectorizer.fit_transform(df_personal['transcripcion'])
#Visualizar los términos mas comunes
plot_10_most_common_words(count_data, count_vectorizer)
## se usan para identificar las palabras individuales claves, para mas adelanteponerlos en contexto. Generalmente solo las tres primeras palabras .
##
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1547733b-63fa-4ea0-84fb-5ef8f2adfbd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1547733b-63fa-4ea0-84fb-5ef8f2adfbd9")) {
#                     Plotly.newPlot(
#                         '1547733b-63fa-4ea0-84fb-5ef8f2adfbd9',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Palabra Clave=%{x}<br>Frecuencia=%{y}", "legendgroup": "", "marker": {"color": "#25427B"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["medicamento", "formula", "solicita", "entrega", "correcto", "directamente", "decir", "mejor", "reclamar", "meses", "luego", "parte", "fecha", "registrar", "digo"], "xaxis": "x", "y": [7149.0, 3776.0, 3536.0, 3263.0, 2993.0, 2580.0, 2420.0, 2245.0, 2233.0, 2101.0, 2069.0, 2028.0, 2026.0, 2015.0, 2004.0], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...
# (['medicamento',
#   'formula',
#   'solicita',
#   'entrega',
#   'correcto',
#   'directamente',
#   'decir',
#   'mejor',
#   'reclamar',
#   'meses',
#   'luego',
#   'parte',
#   'fecha',
#   'registrar',
#   'digo'],
#  [7149.0,
#   3776.0,
#   3536.0,
#   3263.0,
#   2993.0,
#   2580.0,
#   2420.0,
#   2245.0,
#   2233.0,
#   2101.0,
#   2069.0,
#   2028.0,
#   2026.0,
#   2015.0,
#   2004.0])

# %% [markdown]
# <b><font color=orange size=5> Modelado de topicos</font></b>

# %% [markdown]
# **EL INPUT DE ESTE MODELO ES UNA LISTA DE LISTAS NO SUPERVISADO, POR LO TANTO BUSCAR CLUSTERS EN EL TEXTO PATRONES, SEGUN METRICAS DE SEMEJAZA EN ESTE ES LA COHERENCIA.....LA SIMILARIDAD ENTRE PALABRAS Y ENTRE TOPICOS**

# %%
# LDA modelo usado. lee el texo , luego lee el siguiente -> en medio de estas conversaciones se puede agrupar  en grupos.
# no es supervisado ni  no supervisado, cuasi supervisado.
dw = list(sent_to_words(df_personal[['transcripcion']]['transcripcion']))

# %%
# @title Creación del Corpus
# %%time

nlp = spacy.load('es_core_news_md')

#Oraciones a lista de palabras, remocion de puntuacion y caracteres innecesarios
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True remueve puctuacion

def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in swseg] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

#CREACION DEL CORPUS Y FACTORIZACION DE TERMINOS
#Analizando los mensajes del usuario en general
data=df_personal['transcripcion'].tolist()

data_words = list(sent_to_words(data))# Se crea una lista de listas

#BRIGRAMAS
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # Umbral superior de pocas frases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

bigram_mod = gensim.models.phrases.Phraser(gensim.models.Phrases(dw, min_count=5, threshold=100))
trigram_mod = gensim.models.phrases.Phraser(gensim.models.Phrases(bigram[dw], threshold=100))

def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in lista_stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

#Definicion de segmento a analizar
dw = list(sent_to_words(df_personal[['transcripcion']]['transcripcion']))
data_words_bigrams = make_bigrams(remove_stopwords(dw))
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
id2word = corpora.Dictionary(data_lemmatized)
texts = data_lemmatized
corpus = [id2word.doc2bow(text) for text in texts]
# Out:
# CPU times: user 1h 28min 16s, sys: 11.3 s, total: 1h 28min 27s
# Wall time: 1h 28min 39s

# %%
#analisis
# for text in texts:
#   print(text)
# id2word.doc2bow(text)
text
# Out:
# <module 'tensorflow.keras.preprocessing.text' from '/usr/local/lib/python3.7/dist-packages/tensorflow/keras/preprocessing/text/__init__.py'>

# %%
# #@title Optimización del Modelo
# #Definicion del segmento persistente
# segmento = "Campaña_Afiliaciones"

# #Funcion de soporte
# def compute_coherence_values(corpus, dictionary, k, a, b):
    
#     lda_model = gensim.models.LdaMulticore(corpus=corpus,
#                                            id2word=id2word,
#                                            num_topics=10, 
#                                            random_state=100,
#                                            chunksize=100,
#                                            passes=10,
#                                            alpha=a,
#                                            eta=b,
#                                            per_word_topics=True)
    
#     coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
    
#     return coherence_model_lda.get_coherence()

# grid = {}
# grid['Validation_Set'] = {}

# #Rango de topicos
# min_topics = 2
# # max_topics = 11
# max_topics = 5
# step_size = 1
# topics_range = range(min_topics, max_topics, step_size)

# #Parametro Alpha
# alpha = list(np.arange(0.01, 1, 0.3))
# alpha.append('symmetric')
# alpha.append('asymmetric')

# #Parametro Beta
# beta = list(np.arange(0.01, 1, 0.3))
# beta.append('symmetric')

# #Conjuntos de validacion
# num_of_docs = len(corpus)
# corpus_sets = [corpus]

# corpus_title = ['100% Corpus']

# model_results = {'Validation_Set': [],
#                  'Topics': [],
#                  'Alpha': [],
#                  'Beta': [],
#                  'Coherence': []
#                 }

# #Intensivo en tiempo (Promedio de tiempo: 2 Horas)

# if 1 == 1:
#     pbar = tqdm.tqdm(total=540)
    
#     for i in range(len(corpus_sets)):
#         for k in topics_range:
#             for a in alpha:
#                 for b in beta:
#                     cv = compute_coherence_values(corpus=corpus_sets[i], dictionary=id2word, 
#                                                   k=k, a=a, b=b)

#                     model_results['Validation_Set'].append(corpus_title[i])
#                     model_results['Topics'].append(k)
#                     model_results['Alpha'].append(a)
#                     model_results['Beta'].append(b)
#                     model_results['Coherence'].append(cv)
                    
#                     pbar.update(1)
#     pd.DataFrame(model_results).to_csv(segmento+'.csv', index=False)
#     pbar.close()

# #Persistencia de hiperparámetros
# model_results_tabc = pd.DataFrame(model_results)
# model_results_tabc.to_csv(segmento + '_model.csv')
# print("**", len(model_results_tabc), segmento, "\n")
# model_results_tabc.head()

# #Mejor Modelo
# model_results_tabc = pd.read_csv(segmento + '_model.csv')
# best_model = model_results_tabc[model_results_tabc.Coherence == model_results_tabc.Coherence.max()][:1]
# #display(best_model.head())

# #Hiperparámetros del mejor modelo
# Topics = int(best_model.Topics.item())
# Alpha = float(best_model.Alpha.item())
# Beta = float(best_model.Beta.item())

# print("HIPERPARÁMETROS DEL MODELO OPTIMIZADO:")
# print('\nNumero de Tópicos:', Topics)
# print('Parámetro Alfa:', Alpha)
# print('Parámetro Beta:', Beta)
# #esto estaba silenciado

# %%
# data

# %%
# %matplotlib inline

# %%
#@title Modelo LDA Optimizado 
# %%time
# se cambio la vesion de pylavis https://stackoverflow.com/questions/66123774/why-pyldavis-graph-does-not-display-topic-keywords-on-the-bar-chart
# import pyLDAvis.gensim
# %matplotlib inline
#Visualización del modelo
pyLDAvis.enable_notebook()
# pyLDAvis.enable_notebook(local=True)

lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=3, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto', #0.909999999999999,
                                           eta=None, #0.61,                                        
                                           per_word_topics=True)

#Visualizacion de los tópicos generados en el modelo LDA
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]

#Prerrequisitos minimos para la representacion grafica del modelado de topicos
d = id2word
c = corpus
lda = lda_model

#Parametros de visualizacion
data = pyLDAvis.gensim.prepare(lda, c, d)

#Persistencia de resultados de modelado de tópicos
pyLDAvis.save_html(data, 'vis_' + segmento + '.html')
print('\n\n')
#Visualizacion
display(data)
# Out:
# [(0,
#   '0.041*"medicamento" + 0.039*"decir" + 0.034*"entregar" + 0.028*"formular" + '
#   '0.020*"reclamar" + 0.016*"llamar" + 0.010*"querer" + 0.009*"dar" + '
#   '0.008*"llegar" + 0.008*"mandar"'),
#  (1,
#   '0.027*"indicar" + 0.020*"solicitar" + 0.020*"directamente" + '
#   '0.019*"correcto" + 0.018*"registrar" + 0.015*"validar" + 0.014*"comunicar" '
#   '+ 0.012*"radicar" + 0.012*"respuesta" + 0.011*"realizar"'),
#  (2,
#   '0.030*"decir" + 0.015*"aparecer" + 0.014*"activar" + 0.014*"certificar" + '
#   '0.013*"querer" + 0.012*"beneficiar" + 0.012*"afiliar" + 0.011*"pagar" + '
#   '0.011*"llamar" + 0.011*"hacer"')]
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0      0.089482  0.162544       1        1  46.059306
# 1     -0.225998 -0.021089       2        1  34.272098
# 2      0.136515 -0.141455       3        1  19.668597, topic_info=            Term          Freq         Total Category  logprob  loglift
# 4    medicamento   8207.000000   8207.000000  Default  30.0000  30.0000
# 49      entregar   6813.000000   6813.000000  Default  29.0000  29.0000
# 55       indicar   4012.000000   4012.000000  Default  28.0000  28.0000
# 273     formular   5534.000000   5534.000000  Default  27.0000  27.0000
# 161        decir  10764.000000  10764.000000  Default  26.0000  26.0000
# ..           ...           ...           ...      ...      ...      ...
# 12        contar    479.627610   1370.425593   Topic3  -5.1783   0.5763
# 25     preguntar    498.572872   1676.414096   Topic3  -5.1395   0.4135
# 238       hablar    500.198527   1748.276671   Topic3  -5.1363   0.3748
# 267     entender    470.392220   1272.341842   Topic3  -5.1977   0.6311
# 305        luego    467.364862   2267.061210   Topic3  -5.2042   0.0470
#
# [208 rows x 6 columns], token_table=      Topic      Freq          Term
# term
# 753       1  0.993772  acetaminofen
# 2188      1  0.980858        acidar
# 2188      2  0.017915        acidar
# 543       1  0.000824       activar
# 543       3  0.999001       activar
# ...     ...       ...           ...
# 1006      2  0.940691       virtual
# 80        1  0.996072      vitamina
# 227       1  0.636412        volver
# 227       2  0.220611        volver
# 227       3  0.143442        volver
#
# [285 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 2, 3])
# CPU times: user 24.4 s, sys: 292 ms, total: 24.7 s
# Wall time: 27.4 s

# %%
#@title Modelo LDA Optimizado 
# %%time
# se cambio la vesion de pylavis https://stackoverflow.com/questions/66123774/why-pyldavis-graph-does-not-display-topic-keywords-on-the-bar-chart
# import pyLDAvis.gensim
# %matplotlib inline
#Visualización del modelo
pyLDAvis.enable_notebook()
# pyLDAvis.enable_notebook(local=True)

lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=3, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha=0.909999999999999,
                                           eta=0.61,                                        
                                           per_word_topics=True)

#Visualizacion de los tópicos generados en el modelo LDA
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]

#Prerrequisitos minimos para la representacion grafica del modelado de topicos
d = id2word
c = corpus
lda = lda_model

#Parametros de visualizacion
data = pyLDAvis.gensim.prepare(lda, c, d)

#Persistencia de resultados de modelado de tópicos
pyLDAvis.save_html(data, 'vis_' + segmento + '.html')
print('\n\n')
#Visualizacion
display(data)
# Out:
# [(0,
#   '0.046*"medicamento" + 0.039*"entregar" + 0.037*"decir" + 0.031*"formular" + '
#   '0.023*"reclamar" + 0.015*"llamar" + 0.010*"dar" + 0.009*"autorizar" + '
#   '0.009*"querer" + 0.008*"llegar"'),
#  (1,
#   '0.026*"indicar" + 0.019*"solicitar" + 0.019*"directamente" + '
#   '0.018*"correcto" + 0.017*"registrar" + 0.014*"validar" + 0.013*"comunicar" '
#   '+ 0.012*"radicar" + 0.011*"respuesta" + 0.011*"realizar"'),
#  (2,
#   '0.032*"decir" + 0.013*"querer" + 0.012*"llamar" + 0.012*"aparecer" + '
#   '0.011*"activar" + 0.011*"certificar" + 0.010*"hacer" + 0.009*"necesitar" + '
#   '0.009*"beneficiar" + 0.009*"afiliar"')]
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0      0.102591  0.116462       1        1  39.020096
# 1     -0.183523  0.009538       2        1  34.355904
# 2      0.080932 -0.126000       3        1  26.623999, topic_info=            Term         Freq        Total Category  logprob  loglift
# 4    medicamento  7838.000000  7838.000000  Default  30.0000  30.0000
# 49      entregar  6507.000000  6507.000000  Default  29.0000  29.0000
# 273     formular  5286.000000  5286.000000  Default  28.0000  28.0000
# 55       indicar  3877.000000  3877.000000  Default  27.0000  27.0000
# 288     reclamar  3869.000000  3869.000000  Default  26.0000  26.0000
# ..           ...          ...          ...      ...      ...      ...
# 353        mejor   657.034250  2102.374810   Topic3  -5.1663   0.1603
# 12        contar   575.999243  1355.744298   Topic3  -5.2980   0.4674
# 305        luego   595.761635  2217.342977   Topic3  -5.2642   0.0091
# 209     problema   555.711856  1436.288475   Topic3  -5.3338   0.3738
# 193       llevar   574.668948  1995.876835   Topic3  -5.3003   0.0783
#
# [212 rows x 6 columns], token_table=      Topic      Freq          Term
# term
# 753       1  0.992578  acetaminofen
# 753       2  0.007193  acetaminofen
# 753       3  0.007193  acetaminofen
# 543       1  0.002412       activar
# 543       2  0.004020       activar
# ...     ...       ...           ...
# 1006      2  0.930807       virtual
# 1006      3  0.003134       virtual
# 80        1  0.995536      vitamina
# 80        2  0.004904      vitamina
# 80        3  0.004904      vitamina
#
# [487 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 2, 3])
# CPU times: user 28.5 s, sys: 223 ms, total: 28.7 s
# Wall time: 29.5 s

# %%
#@title Dominancia de Temas
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=texts)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(10)
# Out:
#    Document_No  ...                                               Text
# 0            0  ...  [medicamento, oxidar, cinc, hallar, hacer, feb...
# 1            1  ...  [venir, ciudad, trasladar, correcto, llegar, a...
# 2            2  ...  [paciente, parentesco, medicamente, escultura,...
# 3            3  ...  [hallar, partir, autopsia, converso, numeros, ...
# 4            4  ...  [edificio, director, necesitar, certificador, ...
# 5            5  ...                                        [silenciar]
# 6            6  ...  [viral, necesitar, certificar, dejarte, tipo, ...
# 7            7  ...  [hermano, hermano, tratamiento, linfoma, confi...
# 8            8  ...    [moderno, comercio, cirugia, facil, edad, jazz]
# 9            9  ...  [hablar, hablar, daran, ingresar, rebotar, cer...
#
# [10 rows x 5 columns]

# %%
#@title Oracion mas Representativa por cada Tema
pd.options.display.max_colwidth = 100

sent_topics_sorteddf_mallet = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)
    
# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf_mallet.head(10)
# Out:
#    Topic_Num  ...                                                                                  Representative Text
# 0        0.0  ...  [necesitar, medicamento, cambiar, miligramo, mesar, sentir, cuartar, pistar, cambiar, comer, com...
# 1        1.0  ...  [comunicarse, apreciar, completar, fecho, control, realizar, rapidamente, actual, residenciar, c...
# 2        2.0  ...  [decir, mente, hablar, hablar, escuchar, suave, pongale, cuidar, afiliar, nuevo, voz, propiciar,...
#
# [3 rows x 4 columns]

# %%
#@title Nubes de Palabras de los Términos clave N Principales en cada Tema
# 1. Wordcloud of Top N words in each topic
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=lista_stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=20,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(1, 3, figsize=(15,15), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=15))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.savefig("personal_topics_results.png",bbox_inches = 'tight')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# <b><font color=orange size=5> REDES SEMANTICAS</font></b>

# %% [markdown]
# Tener en cuenta que hay quitar palabras, la remoción de las palabras debe realizarce con mucho cuidado.

# %%
lista=[(r'certificadoes','certificado'),(r'educativos','educativo'),(r'beneficiaria','beneficiario'),(r'solicitar','solicita'),(r'beneficios','beneficio'),(r'legalizaron','legalizar'), (r'legalizacion','legalizar'),(r'personajes','personaje'), (r'certificadoes','certificado'), (r'certificacion','certificado'), (r'disponibles','disponible'),(r'certificados','certificado'), (r'documentos','documento'), (r'disfrute','disfrutar'), (r'pagara','pagar'), (r'pagare','pagar'),(r'tratando','tratar'),(r'reportes','reporte'),(r'desprendibles','desprendible')]
df_personal['transcripcion']=df_personal['transcripcion'].apply(lambda x: s_correction(x, lista))

# %%
# %%time
sw_w2v=['diciendome','certificadoes','certificadoes','solicitarr','solicitarndo','solicitardo','solicitarn','pesar','tranquilo','mandan','bendicion','bendecir','dios','caer','entraron','personalmente','acepta','tomado','meramente','sustituta','volvera','alta','ahorita','eseh','haciendo','haria','yendo','hayan','comedy','yoga','izzy','ayudo','medios','torneo','lados','deben','debia','debio','disculpame','climas','segundito','maldita','importe','menciono','quieras','pescar','entendido','caldo','entro','puto','puta','mierda','putos','putas','siguientes','listas','vuelvo','miren','hotel','poner','permite','contacto','conjunto','viene','abajo','existe','cliente','exactamente','quinientas','piden','amables','actual','perdona','llamaba','llevo','respecto','puesto','trato','hotmail','gustaria','escucho','celula','llamaba','vieja','podido','llamen','nuevamente','contestarrrrrrn','contestarrrrrrr','contestarrrrrr','contestarrrrdo','contestarrrrr','diciendo','actualmente','contestarrr', 'contestarrrdo','contestarrrn','contestarrrron', 'contestarrrr','dicho','volvio','sitio','hablado','cuentos','clientes','vieja','entran','venga','triple','aparecen','importa','pregunta','mirar','presente','color','estaciones','preguntar','llegado','contiene','cinta','lleva','contestarr','hagame','siguiente','cancion','maldicion','gmail','dije','pude','entrar','pistas','comento','quedan','quieres','ingrese','existen','esperan','cuerdo','simplemente','esperen','pese','altamente','indicar','cumplir','intentando','puntas','maneras','ambiente','tele','menciona','conozco','repente','hacerlo','tranquila','recuerde','acepto','normalmente','intentado','ninas','paren','ademas','pregunto','companero','consta','pidiendo','realizo','llame','visto','seguimiento','actuacion','llamando','cuestion','especies','cuestion','idea','disculpe','regalar','indica','inca','indica','siento','momentico','acerca','quisieron','quieren','hombres','debido','comuna','senores','hablo','this','acto','comunas','cuerda','adelante','mitad','vuelta','invierno','debia','parecio','mision','mananas','texto','maldito','aldeas','vieron','decirle','manejar','mantenido','exito','podian','quieren','conocen','parezca','hicieron','deberia','debemos','tratar','llamamos','caen','humor','llegue','actor','diseno','vienen','decia','anterior','talud','decide','curso','leyenda','dicto','ayudas','dejamos','aparecia','puedas','deje','hacerte','ayuden','darle','utah','rebelde','verlo','horno','podido','perdedor','necesitando','perfecto','perfectamente','callate','entiendo','detente','nuevamente','comentando','tanque','imaginate','momento','momentos','recorre','dependen','canciones','hicimos','atico','partir','claramente','pastizal','sirve','imbecil','bajas','montar','posterior','oyes','oye', 'llevan','parecen','necesitan','trae','aparece','posee','iguales','trajes','ahoritica','llevar','revisando','acido','culta','ultimos','vieja','podido','llamen','nuevamente','contestarrrrrrn','contestarrrrrrr','contestarrrrrr','contestarrrrdo','contestarrrrr','diciendo','actualmente','contestarrr', 'contestarrrdo','contestarrrn','contestarrrron', 'contestarrrr','dicho','volvio','sitio','hablado','leyenda','dicto','ayudas','dejamos','aparecia','puedas','deje','hacerte','ayuden','darle','especificado','utah','rebelde','verlo','horno','podido','perdedor','necesitando','perfecto','perfectamente','callate','entiendo','detente','nuevamente','comentando','tanque','imaginate','momento','momentos','recorre','dependen','canciones','hicimos','atico','partir','claramente','motivos','pastizal','detalles','sirve','imbecil','bajas','montar','posterior','oyes','oye', 'llevan','parecen','necesitan','trae','aparece','posee','iguales','trajes','ahoritica','llevar','revisando','acido','culta','ultimos']
sw_w2v=sw_w2v+stop_words_user#adicione 


df_personal['transcripcion1']=df_personal['transcripcion'].apply(lambda x: word_tokenize(x) )
df_personal['transcripcion1']=df_personal['transcripcion1'].apply(lambda x: [word for word in x if not word in sw_w2v] )
df_personal['transcripcion1']=df_personal['transcripcion1'].apply(lambda x: ' '.join(x) )
# Out:
# CPU times: user 19 s, sys: 227 ms, total: 19.2 s
# Wall time: 19.3 s

# %% [markdown]
# **todavía está sujeto a desarrollo**
# un diccionario de hiperparametros, y correr el modelo para cada uno de ellos y evaluar los resultados

# %%
#@title Red Semántica

#CREACION DEL CORPUS Y FACTORIZACION DE TERMINOS
#Analizando los mensajes del usuario en general
data=df_personal['transcripcion1'].tolist()

#Oraciones a lista de palabras, remocion de puntuacion y caracteres innecesarios
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True remueve puctuacion

data_words = list(sent_to_words(data))# Se crea una lista de listas

#BRIGRAMAS
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # Umbral superior de pocas frases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
#print(trigram_mod[bigram_mod[data_words[0]]])
# Funciones para bigrams, trigrams lemmatization
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

#Aplicacion de las respectivas funciones
#Formacion de bigramas
data_words_bigrams = make_bigrams(data_words)

#Creacion del diccionario
id2word = corpora.Dictionary(data_words_bigrams)

# Creacion del Corpus
texts = data_words_bigrams

#Frecuencia termino documento
corpus = [id2word.doc2bow(text) for text in texts]

#VEMOS CUANTOS TERMINOS ESTAN EN NUESTRO DICCIONARIO Y CUALES SON LOS MÁS FRECUENTE
word_freq = defaultdict(int)
for sent in data_words_bigrams:
    for i in sent:
        word_freq[i] += 10
len(word_freq)

sorted(word_freq, key=word_freq.get, reverse=True)[50:100]

cores = multiprocessing.cpu_count()

##Entrenamiento del Modelo
w2v_model = Word2Vec(min_count=7, #SE CONSTRUYE EL VOCABULARIO A PARTIR DE LA FRECUENCIA DE APARICION QUE SE DEFINA AQUI
                     window=3,#SE AJUSTA EL NUMERO DE PALABRAS ATRAS Y ADELANTE DE LA PALABRA OBJETIVO PARA VECORIZARLA
                     size=30, #EL TAMANO DEL VECTOR DE CADA PALABRA
                     sample=1e-4, #-5 en principio #ESTE ES EL PARAMETRO QUE HAY QUE AJUSTAR, ES EL MAS SENSIBLE DEL MODELO
                     alpha=0.003, 
                     min_alpha=0.007, 
                     negative=10,
                     workers=cores-1)

#Construccion de vocabulario
w2v_model.build_vocab(data_words_bigrams, progress_per=10000)

#Entrenamiento del modelo
a=w2v_model.train(data_words_bigrams, total_examples=w2v_model.corpus_count, epochs=200, report_delay=1)

#Terminos similares
# w2v_model.wv.most_similar(positive=["contrasena"], topn=10)

##FUNCION PARA REDUCIR LA DIMENSION DEL ESPACIO DE PALABRAS Y PODER VISUALIZARLAS
def tsnescatterplot(model, word, list_names):
    """ Plot in seaborn the results from the t-SNE dimensionality reduction algorithm of the vectors of a query word,
    its list of most similar words, and a list of words.
    """
    arrays = np.empty((0, 30), dtype='f')
    word_labels = [word]
    color_list  = ["#25427B"] #a los colores de la campaña

    # adds the vector of the query word
    arrays = np.append(arrays, model.wv.__getitem__([word]), axis=0)
    
    # gets list of most similar words
    close_words = model.wv.most_similar([word])
    
    # adds the vector for each of the closest words to the array
    for wrd_score in close_words:
        wrd_vector = model.wv.__getitem__([wrd_score[0]])
        word_labels.append(wrd_score[0])
        color_list.append("#33BBFF")
        arrays = np.append(arrays, wrd_vector, axis=0)
    
    # adds the vector for each of the words from list_names to the array
    for wrd in list_names:
        wrd_vector = model.wv.__getitem__([wrd])
        word_labels.append(wrd)
        color_list.append("#EBECED")
        arrays = np.append(arrays, wrd_vector, axis=0)
        
    # Reduces the dimensionality from 300 to 50 dimensions with PCA
    reduc = PCA(n_components=10).fit_transform(arrays)
    
    # Finds t-SNE coordinates for 2 dimensions
    np.set_printoptions(suppress=True)
    
    Y = TSNE(n_components=2, random_state=0, perplexity=15).fit_transform(reduc)
    freq=[]
    for i in word_labels:
       freq.append(word_freq[i])

    # Sets everything up to plot
    df = pd.DataFrame({'x': [x for x in Y[:, 0]],
                       'y': [y for y in Y[:, 1]],
                       'words': word_labels,
                       'color': color_list,'freq':freq})
    
    fig, _ = plt.subplots()
    fig.set_size_inches(9, 9)
    
    # Basic plot
    p1 = sns.regplot(data=df,
                     x="x",
                     y="y",
                     fit_reg=False,
                     marker="o",
                     scatter_kws={'s': df['freq'],
                                  'facecolors': df['color']
                                 }
                    )
    
    # Adds annotations one by one with a loop
    for line in range(0, df.shape[0]):
         p1.text(df["x"][line],
                 df['y'][line],
                 '  ('+ df["words"][line].title()+','+str(df['freq'][line])+')',
                 horizontalalignment='left',
                 verticalalignment='top', size='small',
                 #color=df['color'][line],
                 color='black',
                 weight='normal'
                ).set_size(11)
    
    plt.axis(emit=True)
    plt.xlim(Y[:, 0].min()-10, Y[:, 0].max()+10)
    plt.ylim(Y[:, 1].min()-10, Y[:, 1].max()+30)
    plt.title('Visualización semántica para {}'.format(word.title()))

# %%
time.sleep(10)

# %%
# %matplotlib inline
segmento = str.upper("Usuario Informacion Contributivo")
# Iniciar el count vectorizer con stop words personalizado en español
count_vectorizer = CountVectorizer(stop_words=['interes','ejemplo','personas','llega','hablar','nuevamente','envie',
                                               'diciendo','llamada','envio','aparece','necesito','respuesta','informacion',
                                               'entiendo','solicitud','problema','pregunta', 'haciendo']+lista_stop_words)
# Ajustar y transformar los términos procesados
count_data = count_vectorizer.fit_transform(df_personal['transcripcion'])
#Visualizar los términos mas comunes
x, y =plot_10_most_common_words(count_data, count_vectorizer)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="14570d65-ade5-4bb0-9e9e-69c5ec0aec4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("14570d65-ade5-4bb0-9e9e-69c5ec0aec4e")) {
#                     Plotly.newPlot(
#                         '14570d65-ade5-4bb0-9e9e-69c5ec0aec4e',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Palabra Clave=%{x}<br>Frecuencia=%{y}", "legendgroup": "", "marker": {"color": "#25427B"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["medicamento", "formula", "solicita", "entrega", "correcto", "directamente", "decir", "mejor", "reclamar", "meses", "luego", "parte", "fecha", "registrar", "digo"], "xaxis": "x", "y": [7149.0, 3776.0, 3536.0, 3263.0, 2993.0, 2580.0, 2420.0, 2245.0, 2233.0, 2101.0, 2069.0, 2028.0, 2026.0, 2015.0, 2004.0], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
x[0]
# Out:
# 'medicamento'

# %%
#@title
nombre = x[0]
tsnescatterplot(w2v_model, nombre, [t[0] for t in w2v_model.wv.most_similar(positive=[nombre], topn=20)][10:])
plt.savefig(x[0]+"_calidad_personal_certificado.png",bbox_inches = 'tight')
##

# %%
#@title
carreras = ["periodismo", "pedagogia", "educación"]


# tsnescatterplot(w2v_model, "activo", [t[0] for t in w2v_model.wv.most_similar(positive=["activo"], topn=20)][10:])
# plt.savefig("cuota_similaridad_calidad_personal_certificado.png",bbox_inches = 'tight')
#@title
nombre = x[1]
tsnescatterplot(w2v_model, nombre, [t[0] for t in w2v_model.wv.most_similar(positive=[nombre], topn=20)][10:])
plt.savefig(nombre+"_calidad_personal_certificado.png",bbox_inches = 'tight')
##

# %%
# @title 
#cuota se replaza por el temino clave que encontramos en las graficas de barras para 1-gramas
# tsnescatterplot(w2v_model, "confirmar", [t[0] for t in w2v_model.wv.most_similar(positive=["confirmar"], topn=20)][10:])
# plt.savefig("cuota_similaridad_calidad_personal_certificado.png",bbox_inches = 'tight')

nombre = x[2]
tsnescatterplot(w2v_model, nombre, [t[0] for t in w2v_model.wv.most_similar(positive=[nombre], topn=20)][10:])
plt.savefig(nombre+"_calidad_personal_certificado.png",bbox_inches = 'tight')
##

# %%
#@title
# tsnescatterplot(w2v_model, "actualizar", [t[0] for t in w2v_model.wv.most_similar(positive=["actualizar"], topn=20)][10:])
# plt.savefig("intereses_similaridad_calidad_personal_certificado.png",bbox_inches = 'tight')
nombre = x[3]
tsnescatterplot(w2v_model, nombre, [t[0] for t in w2v_model.wv.most_similar(positive=[nombre], topn=20)][10:])
plt.savefig(nombre+"_calidad_personal_certificado.png",bbox_inches = 'tight')
##

# %%
#@title
# tsnescatterplot(w2v_model, "codigo", [t[0] for t in w2v_model.wv.most_similar(positive=["codigo"], topn=20)][10:])
# plt.savefig("llegando_similaridad_calidad_personal_certificado.png",bbox_inches = 'tight')

nombre = x[4]
tsnescatterplot(w2v_model, nombre, [t[0] for t in w2v_model.wv.most_similar(positive=[nombre], topn=20)][10:])
plt.savefig(nombre+"_calidad_personal_certificado.png",bbox_inches = 'tight')
##

# %% [markdown]
# Esta parte es muy relevante para poder realizar las gráficas en 3d. Al guardar el modelo de Word2Vec, da dos archivos uno contiene la vectorización de cada una de las palabras, y el otro contiene los labels de esa vectorización.

# %%
FOLDER_RAW
# Out:
# '/content/drive/MyDrive/NPL/'

# %%
 word_vectors = w2v_model.wv
 word_vectors.save_word2vec_format('w2vecx')
 #Save model
from gensim.scripts.word2vec2tensor import word2vec2tensor 
word2vec2tensor('w2vecx', '_tensor00')
# hata aca estriamo sbn con el contexto.

# %% [markdown]
# <b><font color=orange size=5> DETECCION DE LA TIPOLOGIA DE LAS PALABRAS EMPLEADAS POR LOS AGENTES</font></b>

# %% [markdown]
# Para realiar esta parte, es necsariao previamente traducir el texto puro al inglés, es decir, el texto completo, con las stop-words y demás tal como lo obtenemos del algoritmo de speech to text.

# %%
segmento='general'

# %%
# !pip install googletrans==3.1.0a0 # en español por el momento no esta rubusta la deteccion de emociones . Toca en ingles , por eso se traduce.

# %%
# !pip install googletrans==3.1.0a0
from googletrans import Translator
import pandas as pd
translator = Translator()

def en_translation(x):
  translate = translator.translate(x, src='es',dest='en')
  translate = translate.text
  return translate

# %%
en_translation("hola")
# Out:
# 'hola'

# %%
# df_user

# %%
# df_agent_afi = pd.read_parquet(FOLDER_RAW+"data/speech_icetex.parquet")
#df_agent_afi =df_user.copy()### carga de mis datos #asi estaba antes jose
df_agent_afi = df_user_sentiment.copy()# modificacion de estefania
# df_agent_afi = df_agent_afi [df_agent_afi.owner == "agente"]
df_agent_afi = df_agent_afi [df_agent_afi["transcripcion"].notna()]

# %%
df_agent_afi.head(2)
# Out:
#                                                                            name_file  ...                                                                                            c_english
# 0  l0040842843_20210111091020_091020_091848_50686_50686_23461463_50686_AGE-11230.wav  ...  dias senorita kong dare hagame favor para saber codigo medicamento cinco ochocientos catorce cer...
# 1          l0040885536_DATE-20210117124301_125646_NIT-X_CC-X_EXT-50691_AGE-79919.wav  ...  buenos dias aguila lilly dejaras bueno tengo preguntica pasa bien hacia pereira pero vinimos sol...
#
# [2 rows x 15 columns]

# %%
df_agent_afi["c_english"] = df_agent_afi["transcripcion"].apply(lambda x: en_translation(x))
df_agent_afi.head(2)
# Out:
#                                                                            name_file  ...                                                                                            c_english
# 0  l0040842843_20210111091020_091020_091848_50686_50686_23461463_50686_AGE-11230.wav  ...  dias senorita kong dare hagame favor para saber codigo medicamento cinco ochocientos catorce cer...
# 1          l0040885536_DATE-20210117124301_125646_NIT-X_CC-X_EXT-50691_AGE-79919.wav  ...  buenos dias aguila lilly dejaras bueno tengo preguntica pasa bien hacia pereira pero vinimos sol...
#
# [2 rows x 15 columns]

# %%
df = df_agent_afi.copy()# copia profunda del dataframe evita modificacion por fragmentos.

# %%
# Diccionario donde se guardarán los léxicos.
vocab={}
# Iteramos para cada una de las emociones de EmoLex.
for lexicon in os.listdir("EmoLex/"):
    # Se abre cada .txt, se extraen todas las palabras y se eliminan saltos de línea.
    with open("EmoLex/"+lexicon,"r") as f:
        vocab[lexicon.split(".")[0]]=[i[:-1] for i in f.readlines()]

# %%
def emotion_count(text,vocab):
    # Separamos las palábras por espacios.
    words=text.split(" ")
    # Creamos un diccionario donde se guardarán los conteos por cada emoción.
    counts={i:0 for i in list(vocab.keys())}
    # Creamos un diccionario donde se guardarán las palabras coincidentes con cada léxico.
    words_per_emo={i:[] for i in list(vocab.keys())}
    # Iteramos para cada una de las palábras dentro del texto.
    for word in words:
        # Iteramos para cada una de las emociones del léxico.
        for emo in vocab:
            # Evalúamos si la palabra está dentro del léxico de cada emoción
            if word in vocab[emo]:
                # Si la palabra está en el léxico de la emoción, sumamos 1 al conteo acumulado.
                counts[emo]+=1
                # También agregamos la palabra coincidente.
                words_per_emo[emo].append(word)
    return counts, words_per_emo

# %%
df['counts,detected_words']=df['c_english'].apply(lambda x: emotion_count(x,vocab)[0])

# %%
dd = defaultdict(list)
list_emotions=df['counts,detected_words'].tolist()
for d in (list_emotions): 
     for key, value in d.items():
         dd[key].append(value)




for name, value in dd.items():
  dd[name]=sum(value)

# %%
dd0={}
for name, value in dd.items():
   if name=='anger':
    name='enojo'
    dd0[name]=value
  
   if name=='fear':
    name='ansiedad'
    dd0[name]=value
  
   if name=='trust':
    name='confianza'
    dd0[name]=value
  
   if name=='negative':
    name='negativa'
    dd0[name]=value
  
   if name=='anticipation':
    name='anticipación'
    dd0[name]=value
  
   if name=='disgust':
    name='disgusto'
    dd0[name]=value
  
   if name=='positive':
    name='positiva'
    dd0[name]=value
  
   if name=='joy':
    name='disfrute'
    dd0[name]=value
  
   if name=='surprise':
    name='sorpresa'
    dd0[name]=value
  
   if name=='sadness':
    name='aflicción'
    dd0[name]=value

# %%
df_p=pd.DataFrame(dd0, index=range(0,11))
df_p=df_p.T
df_p=df_p.rename(columns={0:'Frecuencia'})
df_p=df_p[['Frecuencia']]
df_p=df_p.sort_values(by='Frecuencia', ascending=False)

# %%
df_p
# Out:
#               Frecuencia
# positiva           12810
# confianza          10358
# negativa            5537
# ansiedad            3215
# enojo               2555
# disgusto            2082
# anticipación        1919
# aflicción           1880
# disfrute            1359
# sorpresa             994

# %%
time.sleep(2)

# %%
#plt.figure(figsize=(15,10))
fig=px.bar( x=df_p.index,color_discrete_sequence=["#25427B","#33BBFF","#EBECED"], y=df_p.Frecuencia, title='Ámbito de las expresiones utilizadas por los agentes en las conversaciones:',  labels=dict(x="Tipología de las palabras empleadas", y="Frecuencia", color="Place"))
fig.write_html("experienccia emitida"+"_palabras_agente_.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="884096b7-58be-4744-a22a-897fee844205" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("884096b7-58be-4744-a22a-897fee844205")) {
#                     Plotly.newPlot(
#                         '884096b7-58be-4744-a22a-897fee844205',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Tipolog\u00eda de las palabras empleadas=%{x}<br>Frecuencia=%{y}", "legendgroup": "", "marker": {"color": "#25427B"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["positiva", "confianza", "negativa", "ansiedad", "enojo", "disgusto", "anticipaci\u00f3n", "aflicci\u00f3n", "disfrute", "sorpresa"], "xaxis": "x", "y": [12810, 10358, 5537, 3215, 2555, 2082, 1919, 1880, 1359, 994], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
# dataframe para pasar filtros en power BI
df_personal_a=pd.DataFrame()
df_personal_a['cantidad_palabras']=list(dd0.values())
df_personal_a['tipo_palabra']=list(dd0.keys())

# %% [markdown]
# # <b><font color=orange size=5> DETECCION DE EMOCIONES </font></b>

# %% [markdown]
# Para la detección de emociones en el texto, debemos cargar el texto traducido al inglés. Se realia la aclaración de que el texto traducido debe ser el texto puro, con las stop-words y demás debido a que es necesario tener las frases completas para la clasificación.

# %% [markdown]
# Cargamos el modelo previamente entrenado para la obtención de las emociones

# %%
#Cargar el modelo
import keras
# model = keras.models.load_model(FOLDER_EMOTION_ANALISIS+'my_model_emtion.h5')
# model = keras.models.load_model('/content/drive/MyDrive/NUEVA EPS COD/Datos/my_model_emotion_jose.h5')
model = keras.models.load_model('/content/drive/MyDrive/NUEVA EPS COD/'+carpeta+'my_model_emotion_jose.h5')

# %% [markdown]
# Calculamos los sentimientos para cada conversación, el resultado es un diccionario con los porcentajes asignados de cada emoción para el texto en particular.

# %%
df.head(2)
# Out:
#                                                                            name_file  ...                                                                                counts,detected_words
# 0  l0040842843_20210111091020_091020_091848_50686_50686_23461463_50686_AGE-11230.wav  ...  {'joy': 0, 'positive': 0, 'anticipation': 1, 'trust': 1, 'fear': 1, 'sadness': 0, 'surprise': 0,...
# 1          l0040885536_DATE-20210117124301_125646_NIT-X_CC-X_EXT-50691_AGE-79919.wav  ...  {'joy': 0, 'positive': 1, 'anticipation': 0, 'trust': 1, 'fear': 1, 'sadness': 0, 'surprise': 0,...
#
# [2 rows x 16 columns]

# %%
get_sentiment(model,df.iloc[2]['c_english'])
# Out:
# 1/1 - 1s
#    sentiment percentage
# 12     anger          3
# 14       joy         97

# %%
df.iloc[2]['c_english']
# Out:
# 'buenas tardes bienvenido nueve funda carolina maniqui este nombre paciente cual parentesco senor vale solo favor este nombre dejo medicamente senora alejandra bueno bueno esculturas lineas sencillas orden fecha pero orden medicamento diciendo salud salud para todos orden hermano sabor matcha utilizadas conferencias cosa este pues orden vale tiene radica cierta orden traves movil extras oficina administrativos antes llegue treinta porque ordenes tiempo respuesta desconocidas treinta diria cual nombre personas cuando ingrese numero cedula cual medicamento esas cuasi permitame favor momento bueno consolas alineo entonces habla ninos registran segunda entregas segunda entrega tiene numero direccionan cuatro cero ocho treinta cuatro siete siete bien plazo maximo hasta veintisiete enero orden tambien esta autorizada desde diecisiete codigo autorizacion siete cincuenta siete setecientos ochenta cinco formacion arma numero precision orden termina cincuenta nueve siete villa validamos chicas indique precio estoy validando precio desde veintiocho noviembre orden nosotros tenemos sobra culturas tener linea fija indico acetaminofen cafeina segun registra casi cien seria fuente entrega medicamento bueno disculpen esperen entonces indico numero direccionan tercera entrega cuatrocientos doce ochenta cinco ochenta cuatro deformacion seria este quince febrero sobre estado orissa desde dieciseis enero codigo autorizacion siete cero ocho ochenta tres ademas abrio forma numero apreciacion otra interminente encuentre seis siete ocho indico cual otro cuando encuentre serenidad anime director ochenta cinco comprar cuando hacemos tambien hasta quince febrero hace labor masa desde dieciseis enero codigo siete cero cero noventa ocho siete ocho tiene misma formacion mismo numero prescripcion creo diez tenga buen comunico'

# %%
df.iloc[0]['c_english']
# Out:
# 'dias senorita kong dare hagame favor para saber codigo medicamento cinco ochocientos catorce cero noventa luis castro tres trece seis cincuenta cuatro treinta cuatro siete tres pues oxido cinc vino halla creo tercera entrega baja sabes hector mismo hizo bueno dieciseis noventa cuatro siete setenta nueve noventa tres ochenta seis entonces bueno penso hagan favor naves antrax como queja seis seis febrero hace favor tres trece seis cincuenta cuatro tres trece cincuenta cuatro treinta cuatro siete tres bueno senorita muchas gracias'

# %%
palabras_no = []
cont = 0 
for i in df.iloc[2]['c_english']:
  try:
    get_sentiment(i)
  except:
    palabras_no.append([i,cont])
    cont+=1

print(cont)
# Out:
# 1825

# %%
# palabras_no

# %%
print(type(df.iloc[2]['c_english']),type(df.iloc[0]['c_english']))
# Out:
# <class 'str'> <class 'str'>

# %%
# df.reset_index(inplace=True,drop=True)

# %%
tipo_de_registro =[type(row['c_english']) for index, row in df.iterrows()]
pd.Series(tipo_de_registro).value_counts()
# Out:
# <class 'str'>    4222
# dtype: int64

# %%
# dic_sentiment={}
# cont = 0
# for index, row in df.iterrows():
#   new_dic={}
#   try:
#     result =get_sentiment(model,row['c_english'])
#     result=result.set_index('sentiment')
#     a=result.T.to_dict()
#     for sentiment, value in a.items():
#       new_dic[sentiment]=a[sentiment]['percentage']
#     dic_sentiment[index]=new_dic
#   except:
#     cont+=1
# cont

dic_sentiment={}
cont = 0
for index, row in df.iterrows():
  new_dic={}

  result =get_sentiment(model,row['c_english'])
  result=result.set_index('sentiment')
  a=result.T.to_dict()
  for sentiment, value in a.items():
    new_dic[sentiment]=a[sentiment]['percentage']
  dic_sentiment[index]=new_dic
# Out:
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s

# %%
dic_sentiment
# Out:
# {0: {'relief': 96.0, 'worry': 3.0},
#  1: {'fun': 1.0,
#   'happiness': 2.0,
#   'neutral': 5.0,
#   'relief': 30.0,
#   'sadness': 1.0,
#   'surprise': 46.0,
#   'worry': 14.0},
#  2: {'anger': 3.0, 'joy': 97.0},
#  3: {'worry': 99.0},
#  4: {'anger': 30.0,
#   'boredom': 2.0,
#   'empty': 1.0,
#   'fear': 4.0,
#   'hate': 1.0,
#   'joy': 1.0,
#   'sadness': 60.0,
#   'surprise': 1.0,
#   'worry': 1.0},
#  5: {'empty': 14.0,
#   'enthusiasm': 2.0,
#   'fear': 1.0,
#   'fun': 1.0,
#   'happiness': 2.0,
#   'hate': 1.0,
#   'love': 2.0,
#   'neutral': 70.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 2.0,
#   'worry': 3.0},
#  6: {'boredom': 1.0,
#   'empty': 35.0,
#   'neutral': 61.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'worry': 1.0},
#  7: {'anger': 97.0, 'sadness': 1.0},
#  8: {'happiness': 1.0,
#   'love': 82.0,
#   'neutral': 1.0,
#   'sadness': 15.0,
#   'worry': 1.0},
#  9: {'joy': 81.0, 'sadness': 1.0, 'surprise': 17.0},
#  10: {'anger': 10.0, 'fear': 1.0, 'joy': 89.0},
#  11: {'enthusiasm': 4.0,
#   'happiness': 6.0,
#   'love': 1.0,
#   'neutral': 6.0,
#   'relief': 77.0,
#   'worry': 5.0},
#  12: {'love': 91.0, 'sadness': 1.0, 'surprise': 7.0},
#  13: {'anger': 35.0, 'fear': 1.0, 'joy': 63.0, 'sadness': 1.0},
#  14: {'anger': 1.0, 'boredom': 3.0, 'fear': 1.0, 'hate': 91.0, 'worry': 3.0},
#  15: {'happiness': 1.0, 'joy': 2.0, 'relief': 96.0},
#  16: {'anger': 53.0, 'fear': 3.0, 'joy': 43.0, 'love': 1.0},
#  17: {'fear': 98.0, 'joy': 1.0, 'sadness': 1.0},
#  18: {'surprise': 100.0},
#  19: {'anger': 2.0,
#   'boredom': 1.0,
#   'fear': 12.0,
#   'sadness': 45.0,
#   'worry': 39.0},
#  20: {'anger': 64.0, 'fear': 24.0, 'sadness': 12.0},
#  21: {'boredom': 8.0,
#   'empty': 1.0,
#   'hate': 57.0,
#   'relief': 1.0,
#   'worry': 33.0},
#  22: {'empty': 1.0,
#   'enthusiasm': 4.0,
#   'fun': 1.0,
#   'hate': 1.0,
#   'neutral': 18.0,
#   'relief': 63.0,
#   'surprise': 7.0,
#   'worry': 4.0},
#  23: {'fun': 1.0,
#   'happiness': 1.0,
#   'love': 55.0,
#   'neutral': 2.0,
#   'relief': 1.0,
#   'sadness': 2.0,
#   'surprise': 38.0},
#  24: {'hate': 5.0, 'worry': 95.0},
#  25: {'anger': 10.0,
#   'boredom': 2.0,
#   'enthusiasm': 1.0,
#   'happiness': 1.0,
#   'hate': 25.0,
#   'love': 1.0,
#   'relief': 57.0,
#   'worry': 2.0},
#  26: {'anger': 4.0, 'boredom': 5.0, 'hate': 87.0, 'worry': 4.0},
#  27: {'empty': 1.0,
#   'hate': 1.0,
#   'neutral': 1.0,
#   'relief': 87.0,
#   'worry': 10.0},
#  28: {'enthusiasm': 2.0,
#   'fun': 27.0,
#   'happiness': 4.0,
#   'relief': 1.0,
#   'surprise': 1.0,
#   'worry': 66.0},
#  29: {'relief': 100.0},
#  30: {'anger': 14.0,
#   'boredom': 4.0,
#   'fear': 4.0,
#   'hate': 5.0,
#   'relief': 1.0,
#   'sadness': 29.0,
#   'surprise': 3.0,
#   'worry': 39.0},
#  31: {'enthusiasm': 1.0, 'neutral': 1.0, 'relief': 92.0, 'surprise': 4.0},
#  32: {'enthusiasm': 1.0,
#   'fun': 1.0,
#   'joy': 2.0,
#   'neutral': 1.0,
#   'relief': 75.0,
#   'sadness': 1.0,
#   'surprise': 13.0,
#   'worry': 5.0},
#  33: {'anger': 15.0,
#   'boredom': 2.0,
#   'fun': 1.0,
#   'happiness': 1.0,
#   'hate': 38.0,
#   'love': 3.0,
#   'relief': 15.0,
#   'sadness': 3.0,
#   'worry': 22.0},
#  34: {'happiness': 1.0, 'love': 1.0, 'surprise': 98.0},
#  35: {'love': 45.0, 'sadness': 3.0, 'surprise': 50.0},
#  36: {'surprise': 99.0},
#  37: {'anger': 2.0, 'joy': 10.0, 'love': 3.0, 'relief': 1.0, 'surprise': 84.0},
#  38: {'anger': 15.0,
#   'fear': 1.0,
#   'joy': 76.0,
#   'love': 6.0,
#   'sadness': 1.0,
#   'surprise': 2.0},
#  39: {'anger': 9.0, 'fear': 1.0, 'joy': 2.0, 'sadness': 83.0, 'surprise': 4.0},
#  40: {'empty': 1.0,
#   'enthusiasm': 1.0,
#   'happiness': 33.0,
#   'neutral': 11.0,
#   'relief': 53.0},
#  41: {'empty': 1.0,
#   'enthusiasm': 6.0,
#   'fun': 1.0,
#   'happiness': 11.0,
#   'love': 2.0,
#   'neutral': 63.0,
#   'relief': 15.0,
#   'surprise': 1.0},
#  42: {'anger': 15.0,
#   'boredom': 3.0,
#   'empty': 1.0,
#   'fear': 5.0,
#   'hate': 44.0,
#   'sadness': 28.0,
#   'worry': 5.0},
#  43: {'anger': 1.0,
#   'boredom': 12.0,
#   'empty': 5.0,
#   'fear': 75.0,
#   'hate': 1.0,
#   'worry': 5.0},
#  44: {'empty': 1.0,
#   'enthusiasm': 1.0,
#   'neutral': 1.0,
#   'relief': 97.0,
#   'worry': 1.0},
#  45: {'anger': 14.0,
#   'fear': 1.0,
#   'joy': 19.0,
#   'love': 4.0,
#   'relief': 1.0,
#   'sadness': 31.0,
#   'surprise': 29.0},
#  46: {'joy': 100.0},
#  47: {'enthusiasm': 2.0,
#   'fun': 1.0,
#   'happiness': 4.0,
#   'joy': 3.0,
#   'relief': 87.0,
#   'surprise': 1.0,
#   'worry': 2.0},
#  48: {'love': 72.0, 'surprise': 27.0},
#  49: {'hate': 1.0,
#   'neutral': 13.0,
#   'relief': 62.0,
#   'sadness': 2.0,
#   'surprise': 9.0,
#   'worry': 12.0},
#  50: {'boredom': 2.0, 'empty': 1.0, 'hate': 4.0, 'worry': 92.0},
#  51: {'hate': 1.0, 'relief': 68.0, 'worry': 30.0},
#  52: {'anger': 82.0,
#   'fear': 1.0,
#   'joy': 2.0,
#   'sadness': 14.0,
#   'surprise': 1.0},
#  53: {'anger': 33.0,
#   'fear': 3.0,
#   'joy': 39.0,
#   'love': 2.0,
#   'sadness': 1.0,
#   'surprise': 22.0},
#  54: {'boredom': 1.0,
#   'empty': 1.0,
#   'enthusiasm': 2.0,
#   'happiness': 1.0,
#   'hate': 7.0,
#   'neutral': 9.0,
#   'relief': 14.0,
#   'sadness': 1.0,
#   'worry': 64.0},
#  55: {'joy': 100.0},
#  56: {'anger': 18.0, 'fear': 41.0, 'joy': 4.0, 'love': 9.0, 'surprise': 27.0},
#  57: {'surprise': 99.0},
#  58: {'fear': 2.0,
#   'joy': 2.0,
#   'love': 43.0,
#   'relief': 2.0,
#   'sadness': 11.0,
#   'surprise': 40.0},
#  59: {'anger': 5.0,
#   'fear': 1.0,
#   'joy': 44.0,
#   'love': 5.0,
#   'relief': 2.0,
#   'sadness': 15.0,
#   'surprise': 27.0},
#  60: {'anger': 93.0, 'fear': 1.0, 'joy': 1.0, 'love': 3.0, 'sadness': 1.0},
#  61: {'happiness': 91.0, 'relief': 9.0},
#  62: {'fun': 2.0,
#   'love': 1.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 37.0,
#   'worry': 57.0},
#  63: {'fun': 1.0,
#   'happiness': 5.0,
#   'joy': 1.0,
#   'love': 1.0,
#   'neutral': 6.0,
#   'relief': 79.0,
#   'sadness': 2.0,
#   'surprise': 3.0,
#   'worry': 2.0},
#  64: {'anger': 75.0, 'fear': 2.0, 'joy': 23.0},
#  65: {'anger': 8.0, 'fear': 1.0, 'surprise': 90.0},
#  66: {'enthusiasm': 7.0,
#   'fun': 6.0,
#   'happiness': 7.0,
#   'neutral': 14.0,
#   'relief': 53.0,
#   'sadness': 1.0,
#   'surprise': 1.0,
#   'worry': 11.0},
#  67: {'anger': 73.0, 'boredom': 1.0, 'hate': 24.0, 'sadness': 1.0},
#  68: {'empty': 75.0, 'neutral': 25.0},
#  69: {'fun': 4.0,
#   'happiness': 49.0,
#   'neutral': 2.0,
#   'relief': 4.0,
#   'surprise': 2.0,
#   'worry': 38.0},
#  70: {'happiness': 1.0, 'love': 2.0, 'sadness': 3.0, 'surprise': 93.0},
#  71: {'boredom': 7.0,
#   'empty': 2.0,
#   'hate': 85.0,
#   'sadness': 1.0,
#   'worry': 4.0},
#  72: {'happiness': 99.0},
#  73: {'boredom': 5.0,
#   'empty': 15.0,
#   'enthusiasm': 1.0,
#   'hate': 4.0,
#   'neutral': 7.0,
#   'relief': 2.0,
#   'worry': 67.0},
#  74: {'anger': 6.0, 'boredom': 1.0, 'hate': 89.0, 'worry': 3.0},
#  75: {'hate': 1.0, 'worry': 98.0},
#  76: {'anger': 1.0, 'boredom': 2.0, 'enthusiasm': 1.0, 'relief': 95.0},
#  77: {'fun': 1.0,
#   'happiness': 89.0,
#   'love': 2.0,
#   'neutral': 3.0,
#   'relief': 3.0,
#   'sadness': 1.0,
#   'surprise': 1.0},
#  78: {'fun': 11.0,
#   'happiness': 71.0,
#   'love': 13.0,
#   'neutral': 1.0,
#   'sadness': 1.0,
#   'surprise': 2.0,
#   'worry': 1.0},
#  79: {'anger': 7.0, 'fear': 16.0, 'joy': 75.0, 'love': 1.0, 'sadness': 1.0},
#  80: {'anger': 96.0, 'fear': 1.0, 'joy': 1.0, 'sadness': 1.0, 'surprise': 1.0},
#  81: {'anger': 29.0, 'fear': 5.0, 'joy': 64.0, 'love': 1.0, 'surprise': 1.0},
#  82: {'anger': 3.0, 'fear': 92.0, 'joy': 3.0, 'sadness': 1.0},
#  83: {'fun': 4.0, 'happiness': 64.0, 'relief': 30.0, 'surprise': 1.0},
#  84: {'anger': 52.0, 'fear': 1.0, 'joy': 8.0, 'love': 38.0, 'surprise': 1.0},
#  85: {'enthusiasm': 1.0,
#   'fun': 4.0,
#   'happiness': 18.0,
#   'relief': 73.0,
#   'surprise': 3.0,
#   'worry': 2.0},
#  86: {'anger': 92.0,
#   'hate': 1.0,
#   'joy': 2.0,
#   'love': 3.0,
#   'sadness': 1.0,
#   'surprise': 1.0},
#  87: {'fun': 1.0, 'happiness': 6.0, 'love': 93.0},
#  88: {'surprise': 100.0},
#  89: {'fun': 2.0,
#   'happiness': 6.0,
#   'relief': 73.0,
#   'surprise': 14.0,
#   'worry': 3.0},
#  90: {'enthusiasm': 4.0,
#   'fun': 4.0,
#   'happiness': 22.0,
#   'neutral': 1.0,
#   'relief': 64.0,
#   'worry': 4.0},
#  91: {'enthusiasm': 4.0,
#   'happiness': 1.0,
#   'love': 1.0,
#   'neutral': 1.0,
#   'relief': 52.0,
#   'surprise': 1.0,
#   'worry': 40.0},
#  92: {'fun': 1.0,
#   'happiness': 3.0,
#   'joy': 1.0,
#   'love': 1.0,
#   'neutral': 1.0,
#   'relief': 2.0,
#   'sadness': 1.0,
#   'surprise': 90.0},
#  93: {'anger': 10.0,
#   'boredom': 6.0,
#   'enthusiasm': 1.0,
#   'hate': 26.0,
#   'joy': 1.0,
#   'relief': 2.0,
#   'worry': 53.0},
#  94: {'anger': 2.0,
#   'boredom': 35.0,
#   'empty': 3.0,
#   'fear': 7.0,
#   'hate': 38.0,
#   'sadness': 2.0,
#   'worry': 11.0},
#  95: {'fun': 3.0,
#   'happiness': 86.0,
#   'neutral': 5.0,
#   'relief': 4.0,
#   'worry': 3.0},
#  96: {'fun': 2.0,
#   'happiness': 8.0,
#   'relief': 67.0,
#   'surprise': 18.0,
#   'worry': 6.0},
#  97: {'anger': 1.0,
#   'fear': 7.0,
#   'love': 1.0,
#   'sadness': 1.0,
#   'surprise': 89.0},
#  98: {'enthusiasm': 47.0,
#   'fun': 26.0,
#   'happiness': 8.0,
#   'love': 4.0,
#   'relief': 3.0,
#   'surprise': 7.0,
#   'worry': 2.0},
#  99: {'anger': 82.0,
#   'boredom': 1.0,
#   'fear': 1.0,
#   'hate': 1.0,
#   'joy': 7.0,
#   'love': 7.0},
#  100: {'anger': 3.0,
#   'fun': 2.0,
#   'happiness': 1.0,
#   'joy': 2.0,
#   'love': 5.0,
#   'relief': 86.0,
#   'worry': 1.0},
#  101: {'anger': 84.0,
#   'fear': 2.0,
#   'joy': 3.0,
#   'sadness': 9.0,
#   'surprise': 1.0},
#  102: {'anger': 9.0,
#   'joy': 46.0,
#   'love': 39.0,
#   'relief': 2.0,
#   'sadness': 3.0,
#   'surprise': 1.0},
#  103: {'fun': 1.0,
#   'happiness': 18.0,
#   'joy': 3.0,
#   'love': 1.0,
#   'neutral': 1.0,
#   'relief': 54.0,
#   'sadness': 5.0,
#   'surprise': 14.0,
#   'worry': 2.0},
#  104: {'anger': 1.0, 'sadness': 98.0},
#  105: {'anger': 1.0,
#   'enthusiasm': 3.0,
#   'fun': 1.0,
#   'joy': 81.0,
#   'love': 1.0,
#   'relief': 11.0,
#   'sadness': 1.0,
#   'surprise': 1.0},
#  106: {'surprise': 99.0},
#  107: {'enthusiasm': 1.0,
#   'fun': 15.0,
#   'happiness': 23.0,
#   'relief': 48.0,
#   'surprise': 11.0,
#   'worry': 1.0},
#  108: {'happiness': 2.0, 'love': 97.0, 'surprise': 1.0},
#  109: {'happiness': 1.0,
#   'joy': 1.0,
#   'love': 1.0,
#   'relief': 1.0,
#   'surprise': 95.0},
#  110: {'anger': 46.0,
#   'fear': 2.0,
#   'joy': 1.0,
#   'love': 1.0,
#   'sadness': 46.0,
#   'surprise': 4.0},
#  111: {'anger': 9.0,
#   'fear': 3.0,
#   'joy': 1.0,
#   'sadness': 82.0,
#   'surprise': 3.0},
#  112: {'anger': 6.0,
#   'fear': 35.0,
#   'sadness': 57.0,
#   'surprise': 1.0,
#   'worry': 1.0},
#  113: {'boredom': 1.0,
#   'enthusiasm': 28.0,
#   'fun': 67.0,
#   'hate': 1.0,
#   'love': 1.0,
#   'relief': 1.0},
#  114: {'surprise': 99.0},
#  115: {'anger': 11.0,
#   'fear': 10.0,
#   'joy': 1.0,
#   'love': 1.0,
#   'sadness': 1.0,
#   'surprise': 77.0},
#  116: {'surprise': 100.0},
#  117: {'empty': 14.0,
#   'enthusiasm': 2.0,
#   'fear': 1.0,
#   'fun': 1.0,
#   'happiness': 2.0,
#   'hate': 1.0,
#   'love': 2.0,
#   'neutral': 70.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 2.0,
#   'worry': 3.0},
#  118: {'fun': 1.0,
#   'happiness': 2.0,
#   'joy': 2.0,
#   'love': 3.0,
#   'relief': 7.0,
#   'sadness': 4.0,
#   'surprise': 78.0,
#   'worry': 3.0},
#  119: {'surprise': 100.0},
#  120: {'anger': 1.0,
#   'fear': 1.0,
#   'joy': 62.0,
#   'love': 1.0,
#   'sadness': 2.0,
#   'surprise': 34.0},
#  121: {'surprise': 100.0},
#  122: {'fear': 1.0,
#   'joy': 62.0,
#   'love': 3.0,
#   'sadness': 2.0,
#   'surprise': 32.0},
#  123: {'joy': 3.0, 'surprise': 96.0},
#  124: {'happiness': 1.0,
#   'joy': 65.0,
#   'love': 23.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 10.0},
#  125: {'joy': 6.0, 'surprise': 93.0},
#  126: {'joy': 100.0},
#  127: {'anger': 71.0, 'fear': 21.0, 'joy': 1.0, 'sadness': 5.0},
#  128: {'empty': 14.0,
#   'enthusiasm': 2.0,
#   'fear': 1.0,
#   'fun': 1.0,
#   'happiness': 2.0,
#   'hate': 1.0,
#   'love': 2.0,
#   'neutral': 70.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 2.0,
#   'worry': 3.0},
#  129: {'relief': 100.0},
#  130: {'sadness': 1.0, 'surprise': 98.0},
#  131: {'happiness': 2.0, 'relief': 4.0, 'surprise': 94.0},
#  132: {'anger': 7.0,
#   'fear': 1.0,
#   'joy': 56.0,
#   'love': 1.0,
#   'sadness': 1.0,
#   'surprise': 33.0},
#  133: {'fun': 1.0, 'sadness': 1.0, 'surprise': 29.0, 'worry': 69.0},
#  134: {'anger': 49.0,
#   'fear': 1.0,
#   'joy': 38.0,
#   'sadness': 10.0,
#   'surprise': 1.0},
#  135: {'happiness': 1.0, 'relief': 11.0, 'surprise': 1.0, 'worry': 86.0},
#  136: {'anger': 1.0,
#   'joy': 1.0,
#   'love': 10.0,
#   'sadness': 1.0,
#   'surprise': 87.0},
#  137: {'anger': 1.0, 'hate': 11.0, 'love': 2.0, 'relief': 85.0},
#  138: {'enthusiasm': 1.0,
#   'fun': 20.0,
#   'happiness': 16.0,
#   'joy': 3.0,
#   'love': 3.0,
#   'neutral': 1.0,
#   'relief': 3.0,
#   'surprise': 53.0},
#  139: {'fun': 53.0, 'happiness': 3.0, 'love': 3.0, 'surprise': 40.0},
#  140: {'fear': 1.0, 'surprise': 99.0},
#  141: {'fun': 2.0, 'happiness': 97.0, 'worry': 1.0},
#  142: {'anger': 1.0,
#   'boredom': 3.0,
#   'empty': 3.0,
#   'fear': 26.0,
#   'sadness': 7.0,
#   'worry': 60.0},
#  143: {'fear': 88.0, 'joy': 10.0, 'sadness': 1.0, 'surprise': 1.0},
#  144: {'anger': 2.0,
#   'fear': 82.0,
#   'sadness': 9.0,
#   'surprise': 3.0,
#   'worry': 2.0},
#  145: {'surprise': 99.0},
#  146: {'enthusiasm': 1.0,
#   'fun': 1.0,
#   'joy': 5.0,
#   'neutral': 1.0,
#   'relief': 73.0,
#   'sadness': 3.0,
#   'surprise': 15.0},
#  147: {'happiness': 93.0, 'neutral': 3.0, 'relief': 2.0},
#  148: {'anger': 88.0,
#   'fear': 2.0,
#   'joy': 1.0,
#   'sadness': 8.0,
#   'surprise': 2.0},
#  149: {'anger': 93.0, 'fear': 1.0, 'sadness': 3.0, 'surprise': 2.0},
#  150: {'anger': 1.0, 'fear': 3.0, 'joy': 80.0, 'surprise': 16.0},
#  151: {'fun': 16.0, 'happiness': 84.0},
#  152: {'boredom': 4.0,
#   'empty': 1.0,
#   'enthusiasm': 1.0,
#   'fun': 1.0,
#   'hate': 2.0,
#   'relief': 8.0,
#   'worry': 82.0},
#  153: {'anger': 99.0, 'fear': 1.0},
#  154: {'anger': 35.0, 'hate': 65.0},
#  155: {'anger': 82.0, 'fear': 1.0, 'joy': 15.0, 'love': 1.0},
#  156: {'anger': 60.0, 'fear': 3.0, 'joy': 27.0, 'love': 8.0, 'sadness': 1.0},
#  157: {'anger': 16.0, 'fear': 77.0, 'joy': 7.0},
#  158: {'anger': 91.0,
#   'fear': 1.0,
#   'hate': 1.0,
#   'joy': 1.0,
#   'sadness': 6.0,
#   'surprise': 1.0},
#  159: {'anger': 2.0,
#   'boredom': 2.0,
#   'fear': 24.0,
#   'hate': 1.0,
#   'sadness': 58.0,
#   'worry': 12.0},
#  160: {'anger': 1.0,
#   'empty': 1.0,
#   'enthusiasm': 9.0,
#   'fun': 35.0,
#   'happiness': 9.0,
#   'love': 1.0,
#   'neutral': 2.0,
#   'relief': 37.0,
#   'sadness': 2.0,
#   'surprise': 1.0,
#   'worry': 2.0},
#  161: {'surprise': 100.0},
#  162: {'anger': 6.0,
#   'fear': 1.0,
#   'joy': 62.0,
#   'love': 1.0,
#   'sadness': 1.0,
#   'surprise': 28.0},
#  163: {'anger': 2.0,
#   'fear': 37.0,
#   'sadness': 58.0,
#   'surprise': 1.0,
#   'worry': 1.0},
#  164: {'boredom': 2.0,
#   'hate': 73.0,
#   'relief': 19.0,
#   'sadness': 2.0,
#   'worry': 4.0},
#  165: {'boredom': 5.0,
#   'empty': 43.0,
#   'enthusiasm': 12.0,
#   'fun': 1.0,
#   'neutral': 36.0,
#   'relief': 1.0,
#   'worry': 1.0},
#  166: {'anger': 95.0, 'fear': 2.0, 'joy': 1.0, 'sadness': 2.0},
#  167: {'anger': 53.0, 'fear': 10.0, 'joy': 2.0, 'love': 1.0, 'sadness': 34.0},
#  168: {'anger': 95.0, 'fear': 1.0, 'joy': 1.0, 'sadness': 2.0},
#  169: {'boredom': 28.0,
#   'empty': 62.0,
#   'enthusiasm': 1.0,
#   'fear': 2.0,
#   'hate': 2.0,
#   'relief': 4.0},
#  170: {'joy': 100.0},
#  171: {'boredom': 3.0,
#   'empty': 3.0,
#   'hate': 4.0,
#   'sadness': 1.0,
#   'worry': 89.0},
#  172: {'anger': 84.0, 'fear': 1.0, 'joy': 14.0, 'sadness': 1.0},
#  173: {'fun': 2.0,
#   'happiness': 30.0,
#   'love': 65.0,
#   'relief': 1.0,
#   'surprise': 1.0,
#   'worry': 1.0},
#  174: {'joy': 24.0, 'love': 4.0, 'sadness': 1.0, 'surprise': 70.0},
#  175: {'anger': 46.0,
#   'boredom': 7.0,
#   'empty': 1.0,
#   'fear': 12.0,
#   'hate': 4.0,
#   'joy': 27.0,
#   'love': 1.0,
#   'sadness': 2.0},
#  176: {'anger': 81.0,
#   'fear': 5.0,
#   'joy': 11.0,
#   'love': 1.0,
#   'sadness': 1.0,
#   'surprise': 1.0},
#  177: {'anger': 96.0, 'sadness': 3.0},
#  178: {'anger': 91.0, 'joy': 1.0, 'love': 2.0, 'sadness': 5.0},
#  179: {'boredom': 5.0,
#   'empty': 2.0,
#   'fear': 6.0,
#   'relief': 2.0,
#   'sadness': 1.0,
#   'worry': 83.0},
#  180: {'anger': 80.0,
#   'fear': 2.0,
#   'joy': 4.0,
#   'love': 4.0,
#   'sadness': 6.0,
#   'surprise': 5.0},
#  181: {'anger': 1.0, 'joy': 95.0, 'love': 1.0, 'surprise': 2.0},
#  182: {'anger': 2.0,
#   'fun': 17.0,
#   'happiness': 43.0,
#   'joy': 2.0,
#   'love': 8.0,
#   'relief': 26.0,
#   'surprise': 1.0},
#  183: {'surprise': 99.0},
#  184: {'anger': 1.0,
#   'fear': 1.0,
#   'joy': 60.0,
#   'love': 3.0,
#   'relief': 1.0,
#   'sadness': 13.0,
#   'surprise': 21.0},
#  185: {'love': 6.0, 'relief': 93.0},
#  186: {'joy': 100.0},
#  187: {'anger': 46.0,
#   'joy': 2.0,
#   'love': 45.0,
#   'sadness': 1.0,
#   'surprise': 3.0,
#   'worry': 1.0},
#  188: {'anger': 1.0,
#   'boredom': 15.0,
#   'empty': 63.0,
#   'fear': 6.0,
#   'hate': 1.0,
#   'sadness': 5.0,
#   'worry': 9.0},
#  189: {'boredom': 1.0, 'hate': 58.0, 'relief': 31.0, 'worry': 10.0},
#  190: {'anger': 21.0,
#   'fear': 1.0,
#   'joy': 10.0,
#   'love': 26.0,
#   'relief': 1.0,
#   'sadness': 6.0,
#   'surprise': 35.0},
#  191: {'anger': 1.0, 'fear': 98.0, 'sadness': 1.0},
#  192: {'anger': 1.0,
#   'joy': 10.0,
#   'love': 1.0,
#   'relief': 67.0,
#   'sadness': 21.0},
#  193: {'anger': 17.0,
#   'fear': 2.0,
#   'joy': 40.0,
#   'love': 13.0,
#   'sadness': 4.0,
#   'surprise': 24.0},
#  194: {'joy': 100.0},
#  195: {'surprise': 100.0},
#  196: {'enthusiasm': 1.0,
#   'fun': 3.0,
#   'happiness': 4.0,
#   'neutral': 11.0,
#   'relief': 35.0,
#   'sadness': 1.0,
#   'surprise': 11.0,
#   'worry': 33.0},
#  197: {'anger': 73.0,
#   'boredom': 4.0,
#   'empty': 1.0,
#   'fear': 4.0,
#   'hate': 3.0,
#   'joy': 1.0,
#   'sadness': 10.0,
#   'surprise': 1.0,
#   'worry': 1.0},
#  198: {'empty': 4.0,
#   'hate': 1.0,
#   'neutral': 15.0,
#   'relief': 3.0,
#   'worry': 77.0},
#  199: {'joy': 1.0, 'relief': 86.0, 'surprise': 1.0, 'worry': 11.0},
#  200: {'anger': 14.0,
#   'boredom': 25.0,
#   'empty': 10.0,
#   'fear': 2.0,
#   'hate': 3.0,
#   'relief': 28.0,
#   'sadness': 16.0},
#  201: {'happiness': 1.0,
#   'joy': 3.0,
#   'love': 8.0,
#   'sadness': 1.0,
#   'surprise': 86.0},
#  202: {'surprise': 100.0},
#  203: {'fear': 96.0, 'sadness': 3.0},
#  204: {'surprise': 100.0},
#  205: {'neutral': 97.0, 'worry': 2.0},
#  206: {'joy': 9.0, 'love': 7.0, 'sadness': 1.0, 'surprise': 83.0},
#  207: {'anger': 44.0,
#   'fear': 1.0,
#   'joy': 7.0,
#   'love': 2.0,
#   'sadness': 32.0,
#   'surprise': 13.0},
#  208: {'surprise': 99.0},
#  209: {'joy': 98.0, 'surprise': 1.0},
#  210: {'anger': 2.0,
#   'fear': 88.0,
#   'joy': 4.0,
#   'sadness': 4.0,
#   'surprise': 1.0},
#  211: {'enthusiasm': 1.0,
#   'fun': 46.0,
#   'happiness': 2.0,
#   'neutral': 4.0,
#   'relief': 2.0,
#   'surprise': 34.0,
#   'worry': 11.0},
#  212: {'anger': 1.0,
#   'joy': 1.0,
#   'love': 83.0,
#   'neutral': 1.0,
#   'sadness': 2.0,
#   'surprise': 12.0},
#  213: {'anger': 40.0,
#   'fear': 3.0,
#   'joy': 5.0,
#   'love': 2.0,
#   'sadness': 24.0,
#   'surprise': 26.0},
#  214: {'empty': 1.0, 'neutral': 99.0},
#  215: {'enthusiasm': 4.0,
#   'fun': 12.0,
#   'happiness': 26.0,
#   'neutral': 4.0,
#   'relief': 52.0,
#   'sadness': 1.0,
#   'worry': 2.0},
#  216: {'boredom': 4.0,
#   'empty': 39.0,
#   'neutral': 12.0,
#   'sadness': 1.0,
#   'worry': 44.0},
#  217: {'anger': 97.0, 'joy': 2.0},
#  218: {'fear': 1.0, 'joy': 13.0, 'sadness': 1.0, 'surprise': 84.0},
#  219: {'anger': 4.0,
#   'fear': 30.0,
#   'sadness': 59.0,
#   'surprise': 2.0,
#   'worry': 4.0},
#  220: {'anger': 2.0, 'fear': 1.0, 'sadness': 92.0, 'surprise': 4.0},
#  221: {'fear': 1.0, 'sadness': 4.0, 'worry': 95.0},
#  222: {'happiness': 100.0},
#  223: {'anger': 1.0,
#   'joy': 7.0,
#   'love': 3.0,
#   'sadness': 2.0,
#   'surprise': 87.0},
#  224: {'joy': 1.0, 'love': 95.0, 'sadness': 2.0},
#  225: {'fun': 7.0,
#   'happiness': 2.0,
#   'love': 57.0,
#   'neutral': 16.0,
#   'relief': 2.0,
#   'sadness': 6.0,
#   'surprise': 8.0,
#   'worry': 1.0},
#  226: {'boredom': 1.0,
#   'empty': 1.0,
#   'fear': 3.0,
#   'sadness': 12.0,
#   'worry': 83.0},
#  227: {'joy': 20.0, 'love': 2.0, 'sadness': 1.0, 'surprise': 76.0},
#  228: {'happiness': 16.0, 'relief': 83.0},
#  229: {'fun': 3.0,
#   'happiness': 6.0,
#   'joy': 1.0,
#   'love': 25.0,
#   'neutral': 1.0,
#   'relief': 1.0,
#   'sadness': 53.0,
#   'surprise': 7.0,
#   'worry': 2.0},
#  230: {'enthusiasm': 4.0,
#   'fun': 9.0,
#   'happiness': 1.0,
#   'neutral': 65.0,
#   'relief': 2.0,
#   'surprise': 11.0,
#   'worry': 8.0},
#  231: {'anger': 1.0,
#   'boredom': 11.0,
#   'empty': 13.0,
#   'fear': 1.0,
#   'hate': 52.0,
#   'sadness': 1.0,
#   'worry': 22.0},
#  232: {'anger': 1.0, 'surprise': 98.0},
#  233: {'happiness': 100.0},
#  234: {'anger': 65.0,
#   'fear': 2.0,
#   'joy': 8.0,
#   'love': 5.0,
#   'sadness': 10.0,
#   'surprise': 10.0},
#  235: {'boredom': 1.0,
#   'fear': 4.0,
#   'hate': 1.0,
#   'sadness': 4.0,
#   'surprise': 1.0,
#   'worry': 90.0},
#  236: {'love': 69.0, 'surprise': 31.0},
#  237: {'fear': 1.0, 'surprise': 99.0},
#  238: {'love': 1.0, 'surprise': 98.0},
#  239: {'anger': 25.0, 'fear': 2.0, 'joy': 69.0, 'sadness': 4.0},
#  240: {'fun': 5.0, 'happiness': 37.0, 'relief': 57.0},
#  241: {'surprise': 100.0},
#  242: {'surprise': 100.0},
#  243: {'fun': 2.0,
#   'happiness': 8.0,
#   'joy': 1.0,
#   'love': 1.0,
#   'neutral': 2.0,
#   'relief': 18.0,
#   'sadness': 1.0,
#   'surprise': 67.0,
#   'worry': 1.0},
#  244: {'boredom': 4.0,
#   'empty': 4.0,
#   'enthusiasm': 14.0,
#   'hate': 32.0,
#   'neutral': 7.0,
#   'relief': 38.0},
#  245: {'anger': 91.0,
#   'boredom': 1.0,
#   'fear': 1.0,
#   'hate': 3.0,
#   'love': 1.0,
#   'sadness': 1.0,
#   'surprise': 1.0,
#   'worry': 1.0},
#  246: {'enthusiasm': 2.0,
#   'fun': 7.0,
#   'happiness': 13.0,
#   'joy': 21.0,
#   'neutral': 1.0,
#   'relief': 51.0,
#   'surprise': 4.0},
#  247: {'enthusiasm': 1.0, 'fun': 5.0, 'happiness': 24.0, 'relief': 69.0},
#  248: {'happiness': 18.0, 'relief': 81.0},
#  249: {'fun': 1.0,
#   'happiness': 10.0,
#   'joy': 27.0,
#   'love': 3.0,
#   'neutral': 1.0,
#   'relief': 2.0,
#   'sadness': 3.0,
#   'surprise': 52.0,
#   'worry': 1.0},
#  250: {'surprise': 100.0},
#  251: {'boredom': 3.0,
#   'empty': 2.0,
#   'fear': 26.0,
#   'neutral': 1.0,
#   'sadness': 4.0,
#   'worry': 63.0},
#  252: {'relief': 100.0},
#  253: {'boredom': 8.0,
#   'empty': 1.0,
#   'enthusiasm': 8.0,
#   'hate': 26.0,
#   'relief': 36.0,
#   'worry': 21.0},
#  254: {'boredom': 2.0,
#   'empty': 10.0,
#   'fear': 7.0,
#   'neutral': 2.0,
#   'sadness': 40.0,
#   'worry': 38.0},
#  255: {'joy': 1.0, 'love': 98.0},
#  256: {'enthusiasm': 1.0,
#   'fun': 3.0,
#   'happiness': 1.0,
#   'neutral': 3.0,
#   'relief': 56.0,
#   'surprise': 2.0,
#   'worry': 34.0},
#  257: {'happiness': 12.0,
#   'love': 2.0,
#   'relief': 4.0,
#   'sadness': 1.0,
#   'surprise': 81.0},
#  258: {'anger': 1.0, 'fear': 1.0, 'joy': 83.0, 'love': 2.0, 'surprise': 14.0},
#  259: {'anger': 4.0,
#   'boredom': 20.0,
#   'empty': 3.0,
#   'fear': 8.0,
#   'hate': 43.0,
#   'sadness': 8.0,
#   'worry': 13.0},
#  260: {'fun': 2.0, 'happiness': 94.0, 'relief': 2.0, 'worry': 2.0},
#  261: {'anger': 3.0, 'boredom': 1.0, 'fear': 74.0, 'sadness': 21.0},
#  262: {'anger': 18.0, 'love': 81.0},
#  263: {'enthusiasm': 4.0,
#   'fun': 9.0,
#   'happiness': 6.0,
#   'love': 1.0,
#   'neutral': 8.0,
#   'relief': 62.0,
#   'sadness': 1.0,
#   'surprise': 2.0,
#   'worry': 6.0},
#  264: {'fun': 1.0, 'happiness': 97.0, 'relief': 1.0},
#  265: {'fun': 1.0, 'happiness': 36.0, 'love': 1.0, 'relief': 62.0},
#  266: {'anger': 29.0,
#   'fear': 12.0,
#   'joy': 2.0,
#   'love': 46.0,
#   'sadness': 1.0,
#   'surprise': 9.0},
#  267: {'anger': 2.0, 'fear': 94.0, 'joy': 4.0},
#  268: {'anger': 80.0,
#   'fear': 1.0,
#   'joy': 2.0,
#   'sadness': 11.0,
#   'surprise': 5.0},
#  269: {'boredom': 3.0,
#   'fear': 3.0,
#   'hate': 4.0,
#   'sadness': 2.0,
#   'worry': 87.0},
#  270: {'happiness': 7.0, 'neutral': 1.0, 'relief': 71.0, 'worry': 21.0},
#  271: {'surprise': 99.0},
#  272: {'anger': 60.0,
#   'fear': 1.0,
#   'joy': 9.0,
#   'love': 1.0,
#   'sadness': 18.0,
#   'surprise': 11.0},
#  273: {'anger': 7.0,
#   'fear': 1.0,
#   'joy': 2.0,
#   'relief': 1.0,
#   'sadness': 5.0,
#   'surprise': 83.0},
#  274: {'anger': 1.0,
#   'boredom': 23.0,
#   'empty': 4.0,
#   'hate': 70.0,
#   'worry': 1.0},
#  275: {'fun': 1.0,
#   'happiness': 1.0,
#   'joy': 1.0,
#   'neutral': 5.0,
#   'relief': 10.0,
#   'sadness': 3.0,
#   'surprise': 72.0,
#   'worry': 5.0},
#  276: {'boredom': 1.0,
#   'empty': 11.0,
#   'hate': 1.0,
#   'neutral': 1.0,
#   'relief': 81.0,
#   'worry': 4.0},
#  277: {'boredom': 10.0,
#   'empty': 77.0,
#   'hate': 9.0,
#   'relief': 1.0,
#   'worry': 2.0},
#  278: {'anger': 2.0,
#   'boredom': 1.0,
#   'hate': 68.0,
#   'sadness': 1.0,
#   'worry': 27.0},
#  279: {'anger': 18.0, 'fear': 5.0, 'joy': 76.0},
#  280: {'happiness': 27.0, 'joy': 1.0, 'love': 13.0, 'relief': 58.0},
#  281: {'enthusiasm': 40.0,
#   'fun': 11.0,
#   'happiness': 1.0,
#   'hate': 1.0,
#   'neutral': 5.0,
#   'relief': 33.0,
#   'surprise': 1.0,
#   'worry': 7.0},
#  282: {'anger': 1.0, 'fear': 2.0, 'joy': 5.0, 'surprise': 92.0},
#  283: {'anger': 1.0,
#   'fear': 1.0,
#   'joy': 46.0,
#   'love': 2.0,
#   'sadness': 1.0,
#   'surprise': 50.0},
#  284: {'enthusiasm': 2.0,
#   'fun': 57.0,
#   'happiness': 3.0,
#   'relief': 16.0,
#   'surprise': 5.0,
#   'worry': 16.0},
#  285: {'boredom': 3.0,
#   'enthusiasm': 1.0,
#   'hate': 1.0,
#   'relief': 3.0,
#   'sadness': 4.0,
#   'worry': 87.0},
#  286: {'anger': 21.0, 'fear': 1.0, 'joy': 74.0, 'love': 2.0, 'surprise': 1.0},
#  287: {'worry': 99.0},
#  288: {'anger': 2.0, 'fear': 1.0, 'joy': 95.0, 'love': 1.0},
#  289: {'hate': 2.0, 'relief': 95.0, 'worry': 1.0},
#  290: {'surprise': 100.0},
#  291: {'anger': 97.0, 'sadness': 3.0},
#  292: {'surprise': 100.0},
#  293: {'joy': 26.0, 'love': 72.0, 'surprise': 1.0},
#  294: {'anger': 3.0,
#   'fear': 2.0,
#   'joy': 9.0,
#   'love': 5.0,
#   'sadness': 2.0,
#   'surprise': 79.0},
#  295: {'joy': 100.0},
#  296: {'happiness': 18.0, 'love': 2.0, 'relief': 78.0, 'surprise': 1.0},
#  297: {'fear': 1.0, 'joy': 75.0, 'surprise': 24.0},
#  298: {'anger': 6.0, 'joy': 92.0, 'love': 1.0},
#  299: {'anger': 98.0, 'fear': 1.0},
#  300: {'relief': 47.0, 'worry': 52.0},
#  301: {'anger': 95.0, 'joy': 2.0, 'love': 2.0},
#  302: {'anger': 96.0, 'fear': 1.0, 'joy': 1.0, 'sadness': 1.0},
#  303: {'fear': 1.0,
#   'fun': 1.0,
#   'joy': 70.0,
#   'love': 1.0,
#   'neutral': 1.0,
#   'relief': 8.0,
#   'sadness': 1.0,
#   'surprise': 18.0},
#  304: {'surprise': 100.0},
#  305: {'anger': 1.0,
#   'boredom': 1.0,
#   'hate': 21.0,
#   'sadness': 4.0,
#   'surprise': 3.0,
#   'worry': 71.0},
#  306: {'empty': 2.0, 'hate': 1.0, 'neutral': 96.0, 'sadness': 1.0},
#  307: {'anger': 12.0,
#   'boredom': 11.0,
#   'empty': 9.0,
#   'enthusiasm': 3.0,
#   'fun': 18.0,
#   'happiness': 2.0,
#   'hate': 12.0,
#   'love': 1.0,
#   'neutral': 4.0,
#   'relief': 14.0,
#   'sadness': 13.0,
#   'worry': 1.0},
#  308: {'joy': 98.0, 'surprise': 1.0},
#  309: {'anger': 60.0,
#   'boredom': 10.0,
#   'empty': 4.0,
#   'enthusiasm': 1.0,
#   'fear': 2.0,
#   'fun': 1.0,
#   'hate': 17.0,
#   'joy': 2.0,
#   'love': 1.0,
#   'relief': 1.0,
#   'surprise': 1.0,
#   'worry': 1.0},
#  310: {'anger': 3.0, 'fear': 1.0, 'joy': 82.0, 'love': 1.0, 'surprise': 13.0},
#  311: {'worry': 100.0},
#  312: {'happiness': 94.0, 'relief': 6.0},
#  313: {'relief': 100.0},
#  314: {'anger': 5.0, 'boredom': 1.0, 'hate': 93.0},
#  315: {'anger': 10.0,
#   'fear': 1.0,
#   'joy': 2.0,
#   'love': 1.0,
#   'sadness': 81.0,
#   'surprise': 5.0},
#  316: {'boredom': 6.0, 'empty': 3.0, 'fear': 1.0, 'hate': 90.0},
#  317: {'fun': 2.0, 'happiness': 97.0, 'worry': 1.0},
#  318: {'surprise': 100.0},
#  319: {'neutral': 82.0, 'worry': 17.0},
#  320: {'joy': 1.0,
#   'love': 3.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 93.0,
#   'worry': 1.0},
#  321: {'anger': 46.0,
#   'fear': 1.0,
#   'joy': 5.0,
#   'love': 17.0,
#   'sadness': 28.0,
#   'surprise': 3.0},
#  322: {'anger': 2.0,
#   'joy': 7.0,
#   'love': 1.0,
#   'relief': 2.0,
#   'sadness': 12.0,
#   'surprise': 75.0},
#  323: {'fun': 1.0,
#   'happiness': 23.0,
#   'neutral': 2.0,
#   'relief': 48.0,
#   'worry': 27.0},
#  324: {'anger': 89.0, 'fear': 1.0, 'joy': 1.0, 'sadness': 9.0},
#  325: {'anger': 5.0,
#   'fear': 1.0,
#   'joy': 3.0,
#   'love': 77.0,
#   'sadness': 2.0,
#   'surprise': 12.0},
#  326: {'fun': 1.0,
#   'happiness': 14.0,
#   'love': 1.0,
#   'relief': 14.0,
#   'surprise': 70.0},
#  327: {'enthusiasm': 1.0,
#   'fun': 13.0,
#   'happiness': 28.0,
#   'love': 1.0,
#   'relief': 3.0,
#   'surprise': 5.0,
#   'worry': 49.0},
#  328: {'happiness': 6.0, 'relief': 93.0},
#  329: {'happiness': 99.0},
#  330: {'joy': 86.0, 'relief': 1.0, 'sadness': 10.0, 'surprise': 2.0},
#  331: {'surprise': 100.0},
#  332: {'joy': 1.0, 'relief': 97.0},
#  333: {'boredom': 18.0, 'empty': 1.0, 'hate': 74.0, 'worry': 7.0},
#  334: {'anger': 6.0,
#   'enthusiasm': 2.0,
#   'fear': 2.0,
#   'fun': 1.0,
#   'joy': 75.0,
#   'love': 1.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 11.0},
#  335: {'anger': 91.0, 'fear': 1.0, 'joy': 7.0, 'sadness': 1.0},
#  336: {'fear': 1.0, 'joy': 13.0, 'sadness': 2.0, 'surprise': 83.0},
#  337: {'anger': 1.0,
#   'joy': 1.0,
#   'love': 86.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 8.0},
#  338: {'fun': 3.0,
#   'happiness': 36.0,
#   'relief': 15.0,
#   'surprise': 45.0,
#   'worry': 1.0},
#  339: {'love': 96.0, 'sadness': 1.0, 'surprise': 1.0},
#  340: {'anger': 1.0, 'joy': 98.0},
#  341: {'anger': 96.0, 'fear': 4.0},
#  342: {'anger': 2.0,
#   'boredom': 4.0,
#   'enthusiasm': 1.0,
#   'happiness': 1.0,
#   'hate': 1.0,
#   'love': 1.0,
#   'relief': 25.0,
#   'sadness': 56.0,
#   'worry': 9.0},
#  343: {'boredom': 4.0,
#   'empty': 86.0,
#   'enthusiasm': 6.0,
#   'fear': 1.0,
#   'neutral': 1.0,
#   'relief': 1.0},
#  344: {'surprise': 99.0},
#  345: {'anger': 89.0, 'fear': 1.0, 'joy': 8.0, 'sadness': 1.0},
#  346: {'anger': 61.0,
#   'fear': 2.0,
#   'joy': 18.0,
#   'love': 1.0,
#   'sadness': 16.0,
#   'surprise': 3.0},
#  347: {'happiness': 89.0, 'relief': 10.0, 'worry': 1.0},
#  348: {'anger': 43.0,
#   'boredom': 1.0,
#   'fear': 13.0,
#   'joy': 1.0,
#   'sadness': 41.0},
#  349: {'anger': 98.0, 'fear': 1.0, 'sadness': 1.0},
#  350: {'enthusiasm': 1.0,
#   'fun': 3.0,
#   'happiness': 43.0,
#   'love': 1.0,
#   'relief': 51.0,
#   'surprise': 1.0},
#  351: {'anger': 98.0, 'fear': 1.0, 'sadness': 1.0},
#  352: {'anger': 8.0,
#   'fear': 2.0,
#   'joy': 61.0,
#   'love': 4.0,
#   'relief': 1.0,
#   'sadness': 4.0,
#   'surprise': 21.0},
#  353: {'anger': 4.0,
#   'boredom': 1.0,
#   'fear': 42.0,
#   'hate': 1.0,
#   'sadness': 42.0,
#   'surprise': 1.0,
#   'worry': 8.0},
#  354: {'anger': 82.0, 'fear': 4.0, 'joy': 1.0, 'sadness': 13.0},
#  355: {'enthusiasm': 1.0,
#   'fun': 1.0,
#   'happiness': 1.0,
#   'relief': 90.0,
#   'surprise': 5.0,
#   'worry': 1.0},
#  356: {'empty': 14.0,
#   'enthusiasm': 2.0,
#   'fear': 1.0,
#   'fun': 1.0,
#   'happiness': 2.0,
#   'hate': 1.0,
#   'love': 2.0,
#   'neutral': 70.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 2.0,
#   'worry': 3.0},
#  357: {'anger': 3.0, 'sadness': 95.0, 'surprise': 1.0},
#  358: {'anger': 96.0, 'fear': 2.0, 'joy': 1.0, 'sadness': 1.0},
#  359: {'anger': 1.0, 'fear': 2.0, 'joy': 1.0, 'surprise': 95.0},
#  360: {'happiness': 99.0, 'relief': 1.0},
#  361: {'joy': 99.0},
#  362: {'surprise': 100.0},
#  363: {'happiness': 13.0,
#   'love': 1.0,
#   'neutral': 5.0,
#   'relief': 75.0,
#   'surprise': 3.0,
#   'worry': 2.0},
#  364: {'anger': 34.0,
#   'boredom': 1.0,
#   'fear': 12.0,
#   'hate': 2.0,
#   'sadness': 42.0,
#   'surprise': 1.0,
#   'worry': 7.0},
#  365: {'worry': 99.0},
#  366: {'fun': 3.0, 'happiness': 91.0, 'neutral': 5.0, 'relief': 1.0},
#  367: {'anger': 66.0,
#   'boredom': 3.0,
#   'fear': 1.0,
#   'hate': 1.0,
#   'joy': 17.0,
#   'relief': 1.0,
#   'sadness': 12.0},
#  368: {'surprise': 100.0},
#  369: {'anger': 5.0,
#   'boredom': 1.0,
#   'fear': 37.0,
#   'sadness': 43.0,
#   'surprise': 1.0,
#   'worry': 13.0},
#  370: {'surprise': 99.0},
#  371: {'boredom': 1.0, 'hate': 1.0, 'relief': 1.0, 'worry': 97.0},
#  372: {'happiness': 36.0, 'love': 4.0, 'relief': 55.0, 'worry': 3.0},
#  373: {'anger': 95.0, 'fear': 2.0, 'joy': 3.0},
#  374: {'enthusiasm': 1.0,
#   'fun': 1.0,
#   'neutral': 1.0,
#   'relief': 87.0,
#   'surprise': 6.0,
#   'worry': 4.0},
#  375: {'anger': 1.0, 'sadness': 96.0, 'worry': 3.0},
#  376: {'fear': 1.0, 'joy': 2.0, 'surprise': 97.0},
#  377: {'sadness': 6.0, 'worry': 92.0},
#  378: {'fun': 1.0, 'love': 52.0, 'surprise': 45.0},
#  379: {'joy': 98.0, 'surprise': 1.0},
#  380: {'surprise': 99.0},
#  381: {'fun': 1.0,
#   'happiness': 71.0,
#   'relief': 25.0,
#   'surprise': 1.0,
#   'worry': 1.0},
#  382: {'boredom': 1.0,
#   'empty': 4.0,
#   'enthusiasm': 3.0,
#   'hate': 7.0,
#   'neutral': 38.0,
#   'relief': 3.0,
#   'worry': 44.0},
#  383: {'boredom': 2.0, 'hate': 97.0},
#  384: {'anger': 1.0, 'joy': 97.0, 'sadness': 1.0, 'surprise': 1.0},
#  385: {'anger': 1.0, 'fear': 1.0, 'surprise': 98.0},
#  386: {'anger': 3.0,
#   'boredom': 1.0,
#   'empty': 1.0,
#   'fear': 33.0,
#   'sadness': 58.0,
#   'surprise': 1.0,
#   'worry': 3.0},
#  387: {'boredom': 1.0, 'fear': 3.0, 'sadness': 8.0, 'worry': 87.0},
#  388: {'happiness': 45.0,
#   'love': 1.0,
#   'neutral': 1.0,
#   'relief': 51.0,
#   'sadness': 2.0,
#   'worry': 1.0},
#  389: {'fun': 1.0, 'happiness': 92.0, 'relief': 1.0, 'worry': 6.0},
#  390: {'anger': 1.0, 'joy': 98.0},
#  391: {'love': 1.0, 'surprise': 98.0},
#  392: {'love': 2.0, 'surprise': 98.0},
#  393: {'anger': 2.0,
#   'boredom': 55.0,
#   'empty': 5.0,
#   'fear': 1.0,
#   'hate': 6.0,
#   'love': 1.0,
#   'relief': 2.0,
#   'sadness': 27.0},
#  394: {'anger': 61.0,
#   'joy': 19.0,
#   'love': 4.0,
#   'sadness': 13.0,
#   'surprise': 2.0},
#  395: {'happiness': 94.0, 'neutral': 1.0, 'relief': 4.0},
#  396: {'fun': 1.0, 'love': 1.0, 'surprise': 97.0},
#  397: {'anger': 2.0,
#   'boredom': 25.0,
#   'empty': 4.0,
#   'enthusiasm': 4.0,
#   'fear': 1.0,
#   'fun': 2.0,
#   'happiness': 2.0,
#   'hate': 7.0,
#   'relief': 31.0,
#   'sadness': 13.0,
#   'worry': 8.0},
#  398: {'joy': 98.0, 'love': 1.0},
#  399: {'anger': 2.0, 'fear': 1.0, 'surprise': 97.0},
#  400: {'anger': 1.0, 'joy': 99.0},
#  401: {'boredom': 6.0,
#   'empty': 1.0,
#   'enthusiasm': 24.0,
#   'fun': 1.0,
#   'hate': 27.0,
#   'neutral': 2.0,
#   'relief': 26.0,
#   'surprise': 1.0,
#   'worry': 11.0},
#  402: {'anger': 4.0,
#   'boredom': 1.0,
#   'fear': 18.0,
#   'hate': 2.0,
#   'sadness': 26.0,
#   'surprise': 3.0,
#   'worry': 46.0},
#  403: {'anger': 1.0,
#   'enthusiasm': 16.0,
#   'fear': 2.0,
#   'fun': 2.0,
#   'joy': 64.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 10.0,
#   'worry': 1.0},
#  404: {'anger': 97.0, 'fear': 2.0},
#  405: {'surprise': 100.0},
#  406: {'anger': 96.0, 'fear': 3.0},
#  407: {'anger': 59.0, 'fear': 4.0, 'joy': 35.0, 'love': 1.0},
#  408: {'empty': 1.0, 'neutral': 99.0},
#  409: {'joy': 96.0, 'love': 3.0},
#  410: {'anger': 4.0,
#   'fear': 1.0,
#   'joy': 70.0,
#   'love': 4.0,
#   'relief': 1.0,
#   'sadness': 4.0,
#   'surprise': 16.0},
#  411: {'empty': 4.0,
#   'love': 1.0,
#   'neutral': 87.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 1.0,
#   'worry': 5.0},
#  412: {'surprise': 100.0},
#  413: {'enthusiasm': 1.0, 'fun': 1.0, 'happiness': 29.0, 'relief': 70.0},
#  414: {'happiness': 4.0, 'love': 89.0, 'surprise': 2.0, 'worry': 3.0},
#  415: {'happiness': 3.0, 'neutral': 20.0, 'relief': 74.0, 'worry': 2.0},
#  416: {'fun': 5.0,
#   'happiness': 2.0,
#   'neutral': 32.0,
#   'relief': 9.0,
#   'sadness': 2.0,
#   'surprise': 14.0,
#   'worry': 35.0},
#  417: {'enthusiasm': 4.0,
#   'fun': 1.0,
#   'neutral': 23.0,
#   'relief': 61.0,
#   'surprise': 5.0,
#   'worry': 4.0},
#  418: {'anger': 1.0,
#   'fear': 2.0,
#   'joy': 15.0,
#   'love': 3.0,
#   'sadness': 1.0,
#   'surprise': 76.0},
#  419: {'anger': 27.0, 'fear': 58.0, 'joy': 8.0, 'love': 1.0, 'surprise': 5.0},
#  420: {'anger': 1.0,
#   'boredom': 21.0,
#   'empty': 4.0,
#   'fear': 1.0,
#   'hate': 5.0,
#   'relief': 9.0,
#   'sadness': 57.0,
#   'worry': 1.0},
#  421: {'surprise': 100.0},
#  422: {'anger': 35.0,
#   'fear': 13.0,
#   'joy': 1.0,
#   'love': 1.0,
#   'sadness': 30.0,
#   'surprise': 19.0},
#  423: {'boredom': 1.0, 'hate': 1.0, 'worry': 98.0},
#  424: {'anger': 96.0, 'sadness': 3.0},
#  425: {'worry': 99.0},
#  426: {'anger': 7.0, 'fear': 10.0, 'surprise': 83.0},
#  427: {'anger': 3.0,
#   'boredom': 1.0,
#   'fear': 14.0,
#   'hate': 1.0,
#   'sadness': 55.0,
#   'surprise': 1.0,
#   'worry': 25.0},
#  428: {'empty': 14.0,
#   'enthusiasm': 2.0,
#   'fear': 1.0,
#   'fun': 1.0,
#   'happiness': 2.0,
#   'hate': 1.0,
#   'love': 2.0,
#   'neutral': 70.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 2.0,
#   'worry': 3.0},
#  429: {'anger': 67.0,
#   'boredom': 1.0,
#   'fear': 14.0,
#   'hate': 1.0,
#   'joy': 2.0,
#   'sadness': 9.0,
#   'surprise': 5.0},
#  430: {'anger': 1.0,
#   'fear': 1.0,
#   'happiness': 1.0,
#   'joy': 12.0,
#   'love': 23.0,
#   'relief': 1.0,
#   'sadness': 22.0,
#   'surprise': 39.0},
#  431: {'fun': 6.0,
#   'happiness': 10.0,
#   'love': 9.0,
#   'neutral': 15.0,
#   'relief': 7.0,
#   'sadness': 4.0,
#   'surprise': 1.0,
#   'worry': 47.0},
#  432: {'enthusiasm': 1.0,
#   'fun': 28.0,
#   'happiness': 22.0,
#   'neutral': 3.0,
#   'relief': 1.0,
#   'surprise': 17.0,
#   'worry': 28.0},
#  433: {'sadness': 4.0, 'surprise': 94.0},
#  434: {'empty': 7.0,
#   'enthusiasm': 1.0,
#   'fun': 1.0,
#   'happiness': 2.0,
#   'hate': 1.0,
#   'neutral': 47.0,
#   'relief': 2.0,
#   'sadness': 11.0,
#   'surprise': 1.0,
#   'worry': 27.0},
#  435: {'fun': 1.0,
#   'happiness': 42.0,
#   'neutral': 52.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 2.0,
#   'worry': 1.0},
#  436: {'joy': 100.0},
#  437: {'neutral': 1.0, 'relief': 2.0, 'surprise': 80.0, 'worry': 16.0},
#  438: {'anger': 84.0,
#   'fear': 1.0,
#   'joy': 4.0,
#   'love': 8.0,
#   'sadness': 1.0,
#   'surprise': 2.0},
#  439: {'anger': 12.0,
#   'fear': 1.0,
#   'joy': 7.0,
#   'sadness': 79.0,
#   'surprise': 1.0},
#  440: {'fun': 1.0,
#   'happiness': 5.0,
#   'neutral': 2.0,
#   'relief': 86.0,
#   'surprise': 3.0,
#   'worry': 2.0},
#  441: {'anger': 10.0,
#   'boredom': 1.0,
#   'fear': 77.0,
#   'joy': 2.0,
#   'sadness': 8.0,
#   'surprise': 1.0,
#   'worry': 1.0},
#  442: {'anger': 91.0, 'fear': 2.0, 'joy': 2.0, 'love': 1.0, 'surprise': 4.0},
#  443: {'anger': 2.0, 'joy': 98.0},
#  444: {'love': 2.0, 'relief': 97.0},
#  445: {'joy': 100.0},
#  446: {'joy': 100.0},
#  447: {'anger': 88.0, 'fear': 2.0, 'sadness': 9.0},
#  448: {'anger': 1.0, 'boredom': 7.0, 'hate': 90.0},
#  449: {'enthusiasm': 1.0,
#   'fun': 70.0,
#   'happiness': 4.0,
#   'relief': 22.0,
#   'surprise': 1.0,
#   'worry': 2.0},
#  450: {'fun': 1.0,
#   'happiness': 1.0,
#   'neutral': 72.0,
#   'relief': 5.0,
#   'worry': 21.0},
#  451: {'boredom': 1.0,
#   'empty': 73.0,
#   'happiness': 1.0,
#   'neutral': 17.0,
#   'relief': 7.0},
#  452: {'anger': 2.0,
#   'boredom': 2.0,
#   'empty': 4.0,
#   'enthusiasm': 1.0,
#   'hate': 3.0,
#   'love': 1.0,
#   'neutral': 22.0,
#   'relief': 60.0,
#   'sadness': 3.0,
#   'worry': 1.0},
#  453: {'anger': 4.0,
#   'fear': 1.0,
#   'joy': 12.0,
#   'love': 23.0,
#   'sadness': 11.0,
#   'surprise': 48.0},
#  454: {'anger': 1.0,
#   'enthusiasm': 2.0,
#   'fun': 1.0,
#   'hate': 4.0,
#   'neutral': 1.0,
#   'relief': 33.0,
#   'surprise': 34.0,
#   'worry': 23.0},
#  455: {'boredom': 1.0, 'fear': 14.0, 'sadness': 5.0, 'worry': 79.0},
#  456: {'enthusiasm': 16.0,
#   'fun': 3.0,
#   'happiness': 3.0,
#   'hate': 4.0,
#   'love': 1.0,
#   'relief': 69.0,
#   'surprise': 4.0},
#  457: {'surprise': 100.0},
#  458: {'anger': 66.0,
#   'boredom': 4.0,
#   'fear': 1.0,
#   'hate': 7.0,
#   'joy': 1.0,
#   'love': 1.0,
#   'sadness': 12.0,
#   'worry': 8.0},
#  459: {'anger': 96.0, 'fear': 3.0, 'joy': 1.0},
#  460: {'boredom': 2.0,
#   'empty': 1.0,
#   'fear': 10.0,
#   'sadness': 15.0,
#   'worry': 72.0},
#  461: {'anger': 7.0, 'boredom': 2.0, 'hate': 89.0, 'worry': 1.0},
#  462: {'anger': 2.0,
#   'joy': 31.0,
#   'love': 1.0,
#   'relief': 1.0,
#   'sadness': 64.0,
#   'surprise': 1.0},
#  463: {'fear': 100.0},
#  464: {'boredom': 9.0, 'hate': 91.0},
#  465: {'fun': 1.0,
#   'happiness': 3.0,
#   'neutral': 2.0,
#   'relief': 69.0,
#   'sadness': 2.0,
#   'surprise': 22.0,
#   'worry': 1.0},
#  466: {'anger': 96.0, 'joy': 1.0, 'love': 1.0, 'surprise': 1.0},
#  467: {'happiness': 96.0, 'neutral': 2.0, 'relief': 1.0},
#  468: {'anger': 2.0,
#   'fear': 9.0,
#   'sadness': 64.0,
#   'surprise': 3.0,
#   'worry': 20.0},
#  469: {'neutral': 76.0, 'relief': 1.0, 'worry': 22.0},
#  470: {'anger': 3.0,
#   'fear': 1.0,
#   'joy': 2.0,
#   'sadness': 65.0,
#   'surprise': 28.0},
#  471: {'worry': 100.0},
#  472: {'anger': 95.0, 'fear': 2.0, 'joy': 1.0, 'love': 1.0},
#  473: {'anger': 2.0,
#   'joy': 79.0,
#   'love': 12.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 5.0},
#  474: {'enthusiasm': 1.0, 'neutral': 98.0},
#  475: {'love': 12.0, 'surprise': 87.0},
#  476: {'anger': 84.0, 'fear': 1.0, 'joy': 14.0, 'sadness': 1.0},
#  477: {'anger': 2.0, 'fear': 3.0, 'joy': 90.0, 'surprise': 5.0},
#  478: {'fun': 7.0,
#   'happiness': 1.0,
#   'neutral': 10.0,
#   'relief': 6.0,
#   'sadness': 1.0,
#   'surprise': 11.0,
#   'worry': 64.0},
#  479: {'anger': 98.0, 'fear': 1.0, 'joy': 1.0},
#  480: {'anger': 7.0,
#   'boredom': 1.0,
#   'empty': 1.0,
#   'fear': 23.0,
#   'sadness': 66.0,
#   'worry': 1.0},
#  481: {'anger': 1.0, 'joy': 99.0},
#  482: {'anger': 1.0, 'fear': 93.0, 'surprise': 6.0},
#  483: {'surprise': 100.0},
#  484: {'fun': 8.0, 'happiness': 64.0, 'relief': 25.0, 'surprise': 1.0},
#  485: {'happiness': 96.0, 'relief': 3.0},
#  486: {'anger': 3.0,
#   'fear': 2.0,
#   'joy': 9.0,
#   'love': 2.0,
#   'sadness': 2.0,
#   'surprise': 81.0},
#  487: {'anger': 3.0,
#   'boredom': 1.0,
#   'fear': 22.0,
#   'sadness': 72.0,
#   'worry': 1.0},
#  488: {'happiness': 12.0,
#   'love': 6.0,
#   'neutral': 7.0,
#   'relief': 69.0,
#   'sadness': 2.0,
#   'worry': 1.0},
#  489: {'boredom': 3.0,
#   'enthusiasm': 1.0,
#   'hate': 1.0,
#   'relief': 3.0,
#   'sadness': 4.0,
#   'worry': 87.0},
#  490: {'surprise': 100.0},
#  491: {'boredom': 2.0,
#   'empty': 48.0,
#   'hate': 9.0,
#   'neutral': 2.0,
#   'relief': 36.0,
#   'sadness': 1.0,
#   'worry': 2.0},
#  492: {'anger': 1.0,
#   'boredom': 3.0,
#   'hate': 44.0,
#   'relief': 40.0,
#   'worry': 11.0},
#  493: {'boredom': 3.0,
#   'enthusiasm': 1.0,
#   'hate': 1.0,
#   'relief': 3.0,
#   'sadness': 4.0,
#   'worry': 87.0},
#  494: {'anger': 26.0, 'fear': 1.0, 'sadness': 73.0},
#  495: {'enthusiasm': 1.0, 'fun': 23.0, 'happiness': 53.0, 'relief': 22.0},
#  496: {'love': 99.0},
#  497: {'fear': 83.0,
#   'fun': 2.0,
#   'joy': 9.0,
#   'relief': 1.0,
#   'sadness': 4.0,
#   'surprise': 1.0},
#  498: {'anger': 5.0,
#   'boredom': 1.0,
#   'fear': 67.0,
#   'hate': 1.0,
#   'sadness': 23.0,
#   'worry': 1.0},
#  499: {'boredom': 2.0, 'hate': 1.0, 'worry': 96.0},
#  500: {'anger': 1.0,
#   'joy': 3.0,
#   'neutral': 1.0,
#   'relief': 20.0,
#   'sadness': 3.0,
#   'surprise': 71.0},
#  501: {'joy': 95.0, 'relief': 2.0, 'surprise': 2.0},
#  502: {'anger': 1.0, 'joy': 99.0},
#  503: {'anger': 8.0, 'fear': 1.0, 'sadness': 91.0},
#  504: {'joy': 5.0, 'love': 94.0},
#  505: {'anger': 2.0,
#   'enthusiasm': 19.0,
#   'fun': 29.0,
#   'happiness': 1.0,
#   'hate': 6.0,
#   'love': 13.0,
#   'surprise': 30.0},
#  506: {'anger': 1.0,
#   'happiness': 1.0,
#   'joy': 33.0,
#   'love': 34.0,
#   'relief': 19.0,
#   'sadness': 3.0,
#   'surprise': 8.0},
#  507: {'anger': 3.0,
#   'fear': 6.0,
#   'joy': 2.0,
#   'sadness': 57.0,
#   'surprise': 31.0},
#  508: {'anger': 1.0,
#   'joy': 11.0,
#   'neutral': 1.0,
#   'relief': 45.0,
#   'sadness': 38.0,
#   'surprise': 2.0,
#   'worry': 1.0},
#  509: {'boredom': 3.0,
#   'enthusiasm': 1.0,
#   'hate': 1.0,
#   'relief': 3.0,
#   'sadness': 4.0,
#   'worry': 87.0},
#  510: {'happiness': 75.0, 'relief': 25.0},
#  511: {'enthusiasm': 10.0,
#   'fun': 7.0,
#   'happiness': 71.0,
#   'joy': 1.0,
#   'love': 2.0,
#   'relief': 8.0},
#  512: {'joy': 98.0, 'surprise': 1.0},
#  513: {'anger': 47.0,
#   'boredom': 1.0,
#   'hate': 3.0,
#   'love': 1.0,
#   'sadness': 46.0,
#   'worry': 1.0},
#  514: {'surprise': 100.0},
#  515: {'anger': 1.0,
#   'joy': 29.0,
#   'love': 3.0,
#   'relief': 1.0,
#   'sadness': 9.0,
#   'surprise': 58.0},
#  516: {'enthusiasm': 1.0,
#   'fun': 19.0,
#   'happiness': 58.0,
#   'love': 1.0,
#   'relief': 4.0,
#   'surprise': 15.0,
#   'worry': 2.0},
#  517: {'anger': 1.0,
#   'joy': 80.0,
#   'love': 17.0,
#   'sadness': 1.0,
#   'surprise': 1.0},
#  518: {'anger': 2.0,
#   'fear': 1.0,
#   'sadness': 93.0,
#   'surprise': 2.0,
#   'worry': 2.0},
#  519: {'surprise': 100.0},
#  520: {'fear': 98.0, 'sadness': 2.0},
#  521: {'anger': 57.0,
#   'fear': 34.0,
#   'joy': 3.0,
#   'sadness': 1.0,
#   'surprise': 5.0},
#  522: {'anger': 7.0,
#   'fear': 1.0,
#   'joy': 6.0,
#   'love': 2.0,
#   'relief': 1.0,
#   'sadness': 11.0,
#   'surprise': 71.0},
#  523: {'fun': 2.0, 'happiness': 91.0, 'relief': 6.0, 'worry': 1.0},
#  524: {'anger': 3.0,
#   'boredom': 1.0,
#   'hate': 4.0,
#   'love': 2.0,
#   'sadness': 3.0,
#   'worry': 86.0},
#  525: {'surprise': 100.0},
#  526: {'fun': 2.0,
#   'happiness': 83.0,
#   'relief': 11.0,
#   'surprise': 1.0,
#   'worry': 3.0},
#  527: {'anger': 51.0, 'fear': 1.0, 'sadness': 47.0},
#  528: {'empty': 1.0,
#   'enthusiasm': 1.0,
#   'fun': 1.0,
#   'happiness': 59.0,
#   'love': 1.0,
#   'neutral': 3.0,
#   'relief': 34.0,
#   'sadness': 1.0},
#  529: {'surprise': 100.0},
#  530: {'enthusiasm': 2.0,
#   'fun': 1.0,
#   'happiness': 18.0,
#   'love': 4.0,
#   'relief': 61.0,
#   'surprise': 3.0,
#   'worry': 12.0},
#  531: {'fun': 1.0, 'worry': 98.0},
#  532: {'love': 22.0, 'relief': 76.0},
#  533: {'anger': 1.0,
#   'joy': 47.0,
#   'love': 36.0,
#   'relief': 1.0,
#   'sadness': 4.0,
#   'surprise': 11.0},
#  534: {'hate': 1.0, 'relief': 1.0, 'worry': 97.0},
#  535: {'anger': 45.0,
#   'fear': 1.0,
#   'joy': 2.0,
#   'love': 32.0,
#   'sadness': 17.0,
#   'surprise': 2.0},
#  536: {'anger': 6.0,
#   'fear': 6.0,
#   'fun': 1.0,
#   'joy': 67.0,
#   'love': 1.0,
#   'relief': 2.0,
#   'sadness': 1.0,
#   'surprise': 17.0},
#  537: {'anger': 3.0,
#   'fear': 1.0,
#   'joy': 17.0,
#   'sadness': 77.0,
#   'surprise': 1.0},
#  538: {'anger': 1.0, 'fear': 8.0, 'surprise': 91.0},
#  539: {'happiness': 97.0, 'relief': 2.0},
#  540: {'anger': 1.0,
#   'fun': 2.0,
#   'happiness': 1.0,
#   'joy': 8.0,
#   'neutral': 1.0,
#   'relief': 57.0,
#   'sadness': 4.0,
#   'surprise': 25.0},
#  541: {'enthusiasm': 3.0,
#   'fun': 17.0,
#   'happiness': 58.0,
#   'neutral': 1.0,
#   'relief': 20.0},
#  542: {'anger': 95.0, 'fear': 1.0, 'sadness': 3.0, 'surprise': 1.0},
#  543: {'hate': 1.0, 'worry': 98.0},
#  544: {'fun': 1.0,
#   'neutral': 1.0,
#   'sadness': 17.0,
#   'surprise': 72.0,
#   'worry': 9.0},
#  545: {'enthusiasm': 2.0,
#   'fun': 4.0,
#   'happiness': 60.0,
#   'relief': 27.0,
#   'surprise': 5.0,
#   'worry': 2.0},
#  546: {'joy': 100.0},
#  547: {'anger': 1.0, 'fear': 41.0, 'sadness': 58.0},
#  548: {'anger': 3.0, 'fear': 4.0, 'joy': 2.0, 'love': 1.0, 'surprise': 90.0},
#  549: {'empty': 36.0, 'neutral': 63.0},
#  550: {'anger': 19.0, 'boredom': 2.0, 'hate': 79.0},
#  551: {'anger': 74.0,
#   'boredom': 1.0,
#   'hate': 23.0,
#   'surprise': 1.0,
#   'worry': 1.0},
#  552: {'fun': 2.0,
#   'happiness': 83.0,
#   'love': 1.0,
#   'relief': 1.0,
#   'surprise': 2.0,
#   'worry': 9.0},
#  553: {'anger': 1.0,
#   'boredom': 9.0,
#   'empty': 3.0,
#   'fear': 24.0,
#   'hate': 4.0,
#   'sadness': 9.0,
#   'worry': 49.0},
#  554: {'neutral': 100.0},
#  555: {'anger': 1.0,
#   'boredom': 3.0,
#   'empty': 1.0,
#   'hate': 93.0,
#   'sadness': 1.0,
#   'worry': 1.0},
#  556: {'joy': 1.0, 'relief': 1.0, 'sadness': 81.0, 'surprise': 16.0},
#  557: {'enthusiasm': 2.0, 'hate': 3.0, 'relief': 93.0},
#  558: {'fun': 1.0,
#   'happiness': 1.0,
#   'joy': 21.0,
#   'relief': 6.0,
#   'sadness': 2.0,
#   'surprise': 68.0},
#  559: {'anger': 24.0, 'fear': 75.0},
#  560: {'happiness': 1.0,
#   'neutral': 1.0,
#   'relief': 63.0,
#   'sadness': 28.0,
#   'surprise': 3.0,
#   'worry': 1.0},
#  561: {'hate': 2.0, 'sadness': 1.0, 'worry': 96.0},
#  562: {'enthusiasm': 2.0, 'fun': 6.0, 'neutral': 91.0, 'worry': 1.0},
#  563: {'anger': 2.0,
#   'enthusiasm': 4.0,
#   'fun': 1.0,
#   'happiness': 1.0,
#   'hate': 4.0,
#   'joy': 6.0,
#   'love': 7.0,
#   'relief': 17.0,
#   'surprise': 58.0},
#  564: {'anger': 1.0, 'joy': 5.0, 'relief': 92.0},
#  565: {'happiness': 35.0, 'relief': 64.0},
#  566: {'anger': 4.0,
#   'boredom': 3.0,
#   'enthusiasm': 6.0,
#   'fear': 1.0,
#   'fun': 3.0,
#   'happiness': 1.0,
#   'hate': 1.0,
#   'joy': 1.0,
#   'relief': 9.0,
#   'sadness': 1.0,
#   'surprise': 2.0,
#   'worry': 66.0},
#  567: {'anger': 1.0,
#   'enthusiasm': 13.0,
#   'fun': 2.0,
#   'happiness': 46.0,
#   'hate': 9.0,
#   'love': 4.0,
#   'relief': 20.0,
#   'surprise': 3.0,
#   'worry': 1.0},
#  568: {'enthusiasm': 19.0,
#   'fun': 20.0,
#   'happiness': 2.0,
#   'joy': 1.0,
#   'relief': 55.0,
#   'surprise': 1.0},
#  569: {'happiness': 25.0, 'neutral': 20.0, 'relief': 53.0, 'worry': 1.0},
#  570: {'worry': 99.0},
#  571: {'anger': 1.0, 'sadness': 97.0, 'surprise': 1.0},
#  572: {'empty': 14.0,
#   'enthusiasm': 2.0,
#   'fear': 1.0,
#   'fun': 1.0,
#   'happiness': 2.0,
#   'hate': 1.0,
#   'love': 2.0,
#   'neutral': 70.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 2.0,
#   'worry': 3.0},
#  573: {'surprise': 99.0},
#  574: {'anger': 99.0},
#  575: {'enthusiasm': 1.0,
#   'happiness': 3.0,
#   'neutral': 2.0,
#   'relief': 93.0,
#   'surprise': 1.0},
#  576: {'anger': 3.0, 'fear': 1.0, 'joy': 92.0, 'love': 2.0},
#  577: {'surprise': 100.0},
#  578: {'enthusiasm': 1.0, 'fun': 95.0, 'happiness': 1.0, 'surprise': 3.0},
#  579: {'anger': 97.0, 'hate': 2.0},
#  580: {'anger': 1.0,
#   'boredom': 1.0,
#   'hate': 5.0,
#   'sadness': 11.0,
#   'worry': 81.0},
#  581: {'anger': 11.0,
#   'boredom': 9.0,
#   'empty': 2.0,
#   'fear': 12.0,
#   'hate': 53.0,
#   'sadness': 2.0,
#   'worry': 11.0},
#  582: {'anger': 14.0,
#   'boredom': 7.0,
#   'empty': 1.0,
#   'fear': 1.0,
#   'hate': 70.0,
#   'worry': 7.0},
#  583: {'anger': 73.0,
#   'boredom': 2.0,
#   'hate': 10.0,
#   'sadness': 4.0,
#   'worry': 10.0},
#  584: {'anger': 4.0, 'boredom': 6.0, 'hate': 80.0, 'worry': 9.0},
#  585: {'surprise': 99.0},
#  586: {'anger': 41.0, 'fear': 1.0, 'sadness': 58.0},
#  587: {'fun': 3.0,
#   'happiness': 28.0,
#   'joy': 1.0,
#   'love': 1.0,
#   'neutral': 1.0,
#   'relief': 15.0,
#   'sadness': 1.0,
#   'surprise': 50.0,
#   'worry': 1.0},
#  588: {'boredom': 3.0, 'empty': 1.0, 'hate': 5.0, 'worry': 90.0},
#  589: {'enthusiasm': 1.0, 'fun': 59.0, 'happiness': 39.0, 'surprise': 1.0},
#  590: {'anger': 76.0,
#   'fear': 15.0,
#   'joy': 1.0,
#   'sadness': 2.0,
#   'surprise': 4.0},
#  591: {'anger': 72.0,
#   'hate': 1.0,
#   'joy': 1.0,
#   'love': 17.0,
#   'sadness': 3.0,
# ...
#   'sadness': 5.0,
#   'surprise': 2.0},
#  807: {'surprise': 100.0},
#  808: {'anger': 38.0, 'fear': 2.0, 'joy': 18.0, 'love': 41.0},
#  809: {'fun': 1.0,
#   'happiness': 1.0,
#   'joy': 1.0,
#   'neutral': 1.0,
#   'relief': 94.0,
#   'worry': 1.0},
#  810: {'joy': 100.0},
#  811: {'fun': 1.0,
#   'happiness': 1.0,
#   'joy': 7.0,
#   'love': 3.0,
#   'neutral': 1.0,
#   'relief': 3.0,
#   'sadness': 6.0,
#   'surprise': 77.0},
#  812: {'anger': 72.0,
#   'fear': 2.0,
#   'joy': 1.0,
#   'love': 1.0,
#   'sadness': 20.0,
#   'surprise': 4.0},
#  813: {'enthusiasm': 1.0,
#   'happiness': 81.0,
#   'joy': 1.0,
#   'love': 13.0,
#   'relief': 4.0},
#  814: {'anger': 2.0,
#   'boredom': 67.0,
#   'empty': 10.0,
#   'enthusiasm': 6.0,
#   'hate': 2.0,
#   'relief': 13.0},
#  815: {'anger': 98.0, 'sadness': 1.0},
#  816: {'anger': 2.0, 'fear': 1.0, 'joy': 87.0, 'surprise': 9.0},
#  817: {'enthusiasm': 24.0,
#   'fun': 26.0,
#   'happiness': 46.0,
#   'relief': 3.0,
#   'surprise': 1.0},
#  818: {'anger': 2.0,
#   'boredom': 1.0,
#   'enthusiasm': 1.0,
#   'fun': 2.0,
#   'happiness': 1.0,
#   'hate': 1.0,
#   'joy': 2.0,
#   'relief': 86.0,
#   'sadness': 1.0,
#   'surprise': 1.0,
#   'worry': 2.0},
#  819: {'anger': 7.0,
#   'boredom': 2.0,
#   'fear': 20.0,
#   'hate': 17.0,
#   'sadness': 14.0,
#   'worry': 40.0},
#  820: {'enthusiasm': 9.0,
#   'fun': 7.0,
#   'happiness': 47.0,
#   'hate': 2.0,
#   'neutral': 1.0,
#   'relief': 7.0,
#   'surprise': 27.0},
#  821: {'fear': 1.0, 'surprise': 98.0},
#  822: {'fun': 1.0,
#   'happiness': 10.0,
#   'love': 1.0,
#   'neutral': 1.0,
#   'relief': 10.0,
#   'surprise': 75.0,
#   'worry': 1.0},
#  823: {'sadness': 100.0},
#  824: {'empty': 14.0,
#   'enthusiasm': 2.0,
#   'fear': 1.0,
#   'fun': 1.0,
#   'happiness': 2.0,
#   'hate': 1.0,
#   'love': 2.0,
#   'neutral': 70.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 2.0,
#   'worry': 3.0},
#  825: {'anger': 1.0,
#   'joy': 92.0,
#   'love': 5.0,
#   'sadness': 1.0,
#   'surprise': 1.0},
#  826: {'enthusiasm': 5.0,
#   'fun': 1.0,
#   'happiness': 1.0,
#   'hate': 1.0,
#   'neutral': 40.0,
#   'relief': 45.0,
#   'sadness': 2.0,
#   'surprise': 5.0},
#  827: {'surprise': 99.0},
#  828: {'enthusiasm': 4.0,
#   'fun': 47.0,
#   'happiness': 1.0,
#   'relief': 46.0,
#   'surprise': 1.0,
#   'worry': 1.0},
#  829: {'enthusiasm': 8.0,
#   'fun': 2.0,
#   'happiness': 1.0,
#   'joy': 6.0,
#   'relief': 35.0,
#   'surprise': 49.0},
#  830: {'anger': 1.0, 'fear': 95.0, 'joy': 2.0, 'sadness': 1.0},
#  831: {'anger': 77.0,
#   'boredom': 4.0,
#   'hate': 13.0,
#   'joy': 3.0,
#   'love': 2.0,
#   'relief': 1.0},
#  832: {'anger': 1.0, 'fear': 1.0, 'joy': 1.0, 'sadness': 97.0, 'worry': 1.0},
#  833: {'enthusiasm': 7.0,
#   'fun': 3.0,
#   'happiness': 57.0,
#   'neutral': 26.0,
#   'relief': 5.0},
#  834: {'fun': 1.0, 'surprise': 98.0},
#  835: {'fun': 4.0,
#   'happiness': 2.0,
#   'neutral': 2.0,
#   'relief': 10.0,
#   'sadness': 1.0,
#   'surprise': 79.0,
#   'worry': 1.0},
#  836: {'anger': 1.0,
#   'boredom': 1.0,
#   'fear': 12.0,
#   'sadness': 76.0,
#   'worry': 9.0},
#  837: {'enthusiasm': 4.0,
#   'fun': 7.0,
#   'happiness': 63.0,
#   'relief': 19.0,
#   'surprise': 1.0,
#   'worry': 6.0},
#  838: {'anger': 7.0,
#   'fear': 1.0,
#   'joy': 85.0,
#   'love': 1.0,
#   'relief': 1.0,
#   'sadness': 2.0,
#   'surprise': 2.0},
#  839: {'anger': 1.0,
#   'boredom': 1.0,
#   'enthusiasm': 66.0,
#   'fun': 2.0,
#   'hate': 19.0,
#   'love': 2.0,
#   'relief': 10.0},
#  840: {'anger': 11.0,
#   'fear': 3.0,
#   'joy': 2.0,
#   'love': 18.0,
#   'sadness': 1.0,
#   'surprise': 64.0},
#  841: {'fear': 1.0, 'joy': 4.0, 'love': 1.0, 'surprise': 93.0},
#  842: {'fun': 2.0,
#   'happiness': 3.0,
#   'love': 1.0,
#   'relief': 91.0,
#   'worry': 2.0},
#  843: {'anger': 9.0,
#   'boredom': 38.0,
#   'empty': 9.0,
#   'hate': 43.0,
#   'sadness': 1.0},
#  844: {'surprise': 100.0},
#  845: {'enthusiasm': 2.0,
#   'neutral': 7.0,
#   'relief': 7.0,
#   'surprise': 6.0,
#   'worry': 77.0},
#  846: {'neutral': 98.0, 'worry': 2.0},
#  847: {'empty': 14.0,
#   'enthusiasm': 2.0,
#   'fear': 1.0,
#   'fun': 1.0,
#   'happiness': 2.0,
#   'hate': 1.0,
#   'love': 2.0,
#   'neutral': 70.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 2.0,
#   'worry': 3.0},
#  848: {'fun': 2.0,
#   'happiness': 46.0,
#   'love': 1.0,
#   'neutral': 1.0,
#   'relief': 19.0,
#   'surprise': 1.0,
#   'worry': 29.0},
#  849: {'happiness': 1.0,
#   'joy': 83.0,
#   'relief': 13.0,
#   'surprise': 1.0,
#   'worry': 1.0},
#  850: {'happiness': 1.0,
#   'neutral': 2.0,
#   'relief': 30.0,
#   'sadness': 1.0,
#   'surprise': 46.0,
#   'worry': 18.0},
#  851: {'enthusiasm': 7.0, 'fun': 3.0, 'happiness': 20.0, 'relief': 69.0},
#  852: {'surprise': 100.0},
#  853: {'anger': 52.0, 'fear': 6.0, 'joy': 41.0, 'love': 1.0},
#  854: {'anger': 22.0, 'fear': 1.0, 'joy': 67.0, 'sadness': 7.0},
#  855: {'anger': 27.0, 'fear': 46.0, 'sadness': 26.0},
#  856: {'anger': 3.0,
#   'enthusiasm': 10.0,
#   'fear': 1.0,
#   'fun': 23.0,
#   'joy': 1.0,
#   'love': 1.0,
#   'surprise': 60.0},
#  857: {'anger': 7.0,
#   'fun': 1.0,
#   'hate': 1.0,
#   'love': 3.0,
#   'surprise': 88.0,
#   'worry': 1.0},
#  858: {'anger': 90.0,
#   'fear': 3.0,
#   'joy': 1.0,
#   'love': 1.0,
#   'sadness': 1.0,
#   'surprise': 3.0},
#  859: {'love': 4.0, 'sadness': 2.0, 'surprise': 93.0},
#  860: {'anger': 27.0,
#   'boredom': 1.0,
#   'fear': 50.0,
#   'hate': 1.0,
#   'joy': 1.0,
#   'sadness': 19.0,
#   'worry': 1.0},
#  861: {'boredom': 3.0,
#   'enthusiasm': 1.0,
#   'hate': 1.0,
#   'relief': 3.0,
#   'sadness': 4.0,
#   'worry': 87.0},
#  862: {'fun': 16.0,
#   'happiness': 4.0,
#   'joy': 6.0,
#   'love': 11.0,
#   'sadness': 1.0,
#   'surprise': 59.0,
#   'worry': 2.0},
#  863: {'surprise': 98.0},
#  864: {'sadness': 99.0},
#  865: {'anger': 83.0,
#   'boredom': 1.0,
#   'fear': 1.0,
#   'hate': 8.0,
#   'joy': 2.0,
#   'love': 3.0,
#   'sadness': 1.0,
#   'surprise': 1.0},
#  866: {'anger': 54.0,
#   'fear': 2.0,
#   'joy': 11.0,
#   'love': 6.0,
#   'sadness': 20.0,
#   'surprise': 6.0},
#  867: {'anger': 97.0, 'fear': 1.0, 'sadness': 1.0, 'surprise': 1.0},
#  868: {'enthusiasm': 2.0,
#   'fun': 7.0,
#   'happiness': 9.0,
#   'love': 1.0,
#   'neutral': 1.0,
#   'relief': 47.0,
#   'sadness': 2.0,
#   'surprise': 28.0,
#   'worry': 3.0},
#  869: {'sadness': 1.0, 'surprise': 99.0},
#  870: {'anger': 36.0, 'fear': 1.0, 'hate': 2.0, 'sadness': 59.0, 'worry': 1.0},
#  871: {'anger': 2.0,
#   'boredom': 30.0,
#   'empty': 11.0,
#   'fear': 3.0,
#   'hate': 39.0,
#   'sadness': 1.0,
#   'worry': 13.0},
#  872: {'happiness': 1.0, 'love': 2.0, 'surprise': 95.0},
#  873: {'anger': 4.0, 'fear': 1.0, 'joy': 93.0, 'love': 1.0},
#  874: {'anger': 9.0, 'fear': 78.0, 'sadness': 13.0},
#  875: {'anger': 4.0, 'fear': 7.0, 'joy': 12.0, 'surprise': 76.0},
#  876: {'surprise': 100.0},
#  877: {'anger': 1.0,
#   'boredom': 1.0,
#   'fear': 1.0,
#   'sadness': 39.0,
#   'worry': 58.0},
#  878: {'anger': 1.0,
#   'fear': 88.0,
#   'sadness': 8.0,
#   'surprise': 1.0,
#   'worry': 1.0},
#  879: {'anger': 91.0, 'fear': 2.0, 'sadness': 7.0},
#  880: {'anger': 90.0, 'fear': 3.0, 'joy': 2.0, 'sadness': 5.0},
#  881: {'anger': 46.0, 'fear': 29.0, 'joy': 19.0, 'love': 1.0, 'surprise': 4.0},
#  882: {'anger': 9.0,
#   'fear': 1.0,
#   'fun': 1.0,
#   'happiness': 1.0,
#   'joy': 7.0,
#   'love': 7.0,
#   'relief': 4.0,
#   'sadness': 42.0,
#   'surprise': 27.0,
#   'worry': 1.0},
#  883: {'anger': 29.0, 'fear': 26.0, 'sadness': 44.0},
#  884: {'anger': 10.0, 'fear': 1.0, 'joy': 86.0, 'surprise': 3.0},
#  885: {'anger': 92.0, 'fear': 5.0, 'joy': 2.0},
#  886: {'enthusiasm': 9.0,
#   'fun': 30.0,
#   'happiness': 36.0,
#   'joy': 1.0,
#   'love': 1.0,
#   'relief': 14.0,
#   'surprise': 8.0},
#  887: {'anger': 5.0,
#   'fear': 66.0,
#   'sadness': 19.0,
#   'surprise': 6.0,
#   'worry': 2.0},
#  888: {'anger': 1.0, 'love': 83.0, 'relief': 9.0, 'sadness': 5.0},
#  889: {'anger': 1.0, 'joy': 99.0},
#  890: {'anger': 2.0,
#   'boredom': 10.0,
#   'empty': 3.0,
#   'fear': 31.0,
#   'hate': 4.0,
#   'sadness': 17.0,
#   'worry': 33.0},
#  891: {'anger': 99.0},
#  892: {'enthusiasm': 23.0,
#   'fun': 44.0,
#   'happiness': 1.0,
#   'relief': 32.0,
#   'surprise': 1.0},
#  893: {'anger': 30.0,
#   'boredom': 3.0,
#   'empty': 1.0,
#   'fear': 28.0,
#   'hate': 4.0,
#   'sadness': 27.0,
#   'surprise': 2.0,
#   'worry': 6.0},
#  894: {'fun': 1.0,
#   'happiness': 2.0,
#   'love': 81.0,
#   'sadness': 1.0,
#   'surprise': 14.0,
#   'worry': 1.0},
#  895: {'anger': 1.0, 'fear': 1.0, 'joy': 26.0, 'surprise': 73.0},
#  896: {'fear': 1.0, 'joy': 1.0, 'surprise': 97.0},
#  897: {'sadness': 10.0, 'worry': 90.0},
#  898: {'surprise': 99.0},
#  899: {'enthusiasm': 8.0, 'fun': 68.0, 'happiness': 17.0, 'relief': 6.0},
#  900: {'fun': 8.0,
#   'happiness': 37.0,
#   'love': 51.0,
#   'relief': 3.0,
#   'worry': 1.0},
#  901: {'anger': 3.0,
#   'boredom': 2.0,
#   'empty': 1.0,
#   'fear': 46.0,
#   'hate': 1.0,
#   'sadness': 32.0,
#   'worry': 15.0},
#  902: {'anger': 4.0,
#   'happiness': 1.0,
#   'joy': 50.0,
#   'love': 19.0,
#   'neutral': 1.0,
#   'relief': 2.0,
#   'sadness': 7.0,
#   'surprise': 16.0},
#  903: {'anger': 20.0, 'fear': 68.0, 'joy': 2.0, 'sadness': 10.0},
#  904: {'anger': 84.0, 'fear': 1.0, 'joy': 13.0, 'love': 1.0},
#  905: {'anger': 8.0, 'fear': 9.0, 'fun': 2.0, 'surprise': 80.0},
#  906: {'happiness': 9.0,
#   'joy': 2.0,
#   'love': 6.0,
#   'relief': 1.0,
#   'surprise': 82.0},
#  907: {'anger': 4.0,
#   'joy': 9.0,
#   'love': 50.0,
#   'sadness': 3.0,
#   'surprise': 34.0},
#  908: {'anger': 16.0,
#   'fear': 4.0,
#   'fun': 2.0,
#   'happiness': 1.0,
#   'joy': 8.0,
#   'love': 3.0,
#   'relief': 4.0,
#   'sadness': 4.0,
#   'surprise': 57.0,
#   'worry': 1.0},
#  909: {'anger': 13.0, 'boredom': 4.0, 'hate': 55.0, 'relief': 28.0},
#  910: {'anger': 68.0,
#   'boredom': 4.0,
#   'empty': 2.0,
#   'fear': 1.0,
#   'fun': 1.0,
#   'hate': 11.0,
#   'joy': 2.0,
#   'neutral': 2.0,
#   'sadness': 3.0,
#   'surprise': 2.0,
#   'worry': 2.0},
#  911: {'anger': 1.0,
#   'happiness': 1.0,
#   'joy': 70.0,
#   'love': 12.0,
#   'relief': 3.0,
#   'sadness': 8.0,
#   'surprise': 6.0},
#  912: {'anger': 99.0, 'sadness': 1.0},
#  913: {'surprise': 100.0},
#  914: {'anger': 1.0, 'sadness': 98.0},
#  915: {'anger': 95.0,
#   'fear': 1.0,
#   'joy': 1.0,
#   'sadness': 2.0,
#   'surprise': 1.0},
#  916: {'happiness': 11.0, 'relief': 89.0},
#  917: {'enthusiasm': 1.0,
#   'fun': 4.0,
#   'happiness': 3.0,
#   'love': 1.0,
#   'relief': 90.0},
#  918: {'anger': 2.0,
#   'boredom': 39.0,
#   'empty': 2.0,
#   'hate': 51.0,
#   'relief': 4.0,
#   'worry': 1.0},
#  919: {'anger': 17.0, 'boredom': 1.0, 'fear': 1.0, 'joy': 81.0},
#  920: {'fun': 2.0,
#   'joy': 1.0,
#   'neutral': 5.0,
#   'relief': 2.0,
#   'sadness': 2.0,
#   'surprise': 77.0,
#   'worry': 11.0},
#  921: {'anger': 14.0,
#   'boredom': 4.0,
#   'empty': 1.0,
#   'hate': 76.0,
#   'sadness': 1.0,
#   'worry': 4.0},
#  922: {'fun': 1.0,
#   'happiness': 1.0,
#   'love': 1.0,
#   'neutral': 7.0,
#   'relief': 4.0,
#   'sadness': 5.0,
#   'surprise': 76.0,
#   'worry': 5.0},
#  923: {'anger': 5.0,
#   'fear': 61.0,
#   'sadness': 30.0,
#   'surprise': 2.0,
#   'worry': 1.0},
#  924: {'boredom': 3.0,
#   'empty': 79.0,
#   'fear': 2.0,
#   'neutral': 2.0,
#   'worry': 14.0},
#  925: {'fun': 3.0, 'happiness': 35.0, 'love': 59.0, 'surprise': 2.0},
#  926: {'anger': 97.0, 'joy': 1.0, 'sadness': 1.0},
#  927: {'hate': 1.0, 'worry': 99.0},
#  928: {'empty': 2.0, 'neutral': 98.0},
#  929: {'surprise': 100.0},
#  930: {'anger': 16.0,
#   'boredom': 8.0,
#   'enthusiasm': 3.0,
#   'hate': 31.0,
#   'joy': 3.0,
#   'love': 31.0,
#   'relief': 7.0},
#  931: {'happiness': 1.0,
#   'joy': 1.0,
#   'relief': 49.0,
#   'sadness': 18.0,
#   'surprise': 30.0,
#   'worry': 1.0},
#  932: {'anger': 91.0, 'joy': 7.0, 'love': 1.0},
#  933: {'anger': 6.0, 'boredom': 3.0, 'fear': 79.0, 'sadness': 11.0},
#  934: {'relief': 100.0},
#  935: {'joy': 100.0},
#  936: {'anger': 12.0,
#   'boredom': 1.0,
#   'fear': 33.0,
#   'sadness': 50.0,
#   'surprise': 1.0,
#   'worry': 3.0},
#  937: {'anger': 3.0,
#   'joy': 2.0,
#   'love': 3.0,
#   'relief': 1.0,
#   'sadness': 1.0,
#   'surprise': 88.0},
#  938: {'anger': 98.0, 'fear': 1.0},
#  939: {'worry': 99.0},
#  940: {'anger': 2.0, 'fear': 91.0, 'sadness': 6.0, 'surprise': 1.0},
#  941: {'anger': 95.0, 'fear': 1.0, 'joy': 1.0, 'sadness': 2.0},
#  942: {'anger': 72.0, 'fear': 4.0, 'joy': 23.0, 'love': 1.0},
#  943: {'happiness': 1.0, 'joy': 2.0, 'love': 9.0, 'surprise': 87.0},
#  944: {'anger': 33.0,
#   'fear': 20.0,
#   'joy': 33.0,
#   'love': 1.0,
#   'sadness': 5.0,
#   'surprise': 6.0},
#  945: {'happiness': 53.0, 'neutral': 1.0, 'relief': 45.0},
#  946: {'fun': 1.0,
#   'happiness': 10.0,
#   'neutral': 86.0,
#   'relief': 2.0,
#   'sadness': 1.0},
#  947: {'anger': 5.0,
#   'boredom': 21.0,
#   'empty': 4.0,
#   'fear': 1.0,
#   'hate': 64.0,
#   'worry': 5.0},
#  948: {'joy': 34.0, 'love': 65.0},
#  949: {'fun': 5.0, 'happiness': 93.0, 'relief': 1.0, 'surprise': 1.0},
#  950: {'anger': 38.0,
#   'boredom': 1.0,
#   'fear': 2.0,
#   'fun': 1.0,
#   'happiness': 1.0,
#   'hate': 1.0,
#   'joy': 10.0,
#   'love': 33.0,
#   'relief': 8.0,
#   'sadness': 5.0},
#  951: {'anger': 82.0, 'fear': 3.0, 'sadness': 14.0},
#  952: {'anger': 92.0,
#   'boredom': 1.0,
#   'fun': 1.0,
#   'hate': 2.0,
#   'love': 1.0,
#   'sadness': 1.0,
#   'surprise': 1.0,
#   'worry': 1.0},
#  953: {'anger': 98.0, 'fear': 1.0, 'sadness': 1.0},
#  954: {'surprise': 100.0},
#  955: {'surprise': 98.0},
#  956: {'surprise': 100.0},
#  957: {'boredom': 3.0,
#   'enthusiasm': 1.0,
#   'hate': 1.0,
#   'relief': 3.0,
#   'sadness': 4.0,
#   'worry': 87.0},
#  958: {'joy': 34.0, 'love': 65.0},
#  959: {'boredom': 1.0, 'hate': 73.0, 'worry': 25.0},
#  960: {'anger': 82.0, 'fear': 3.0, 'sadness': 14.0},
#  961: {'anger': 1.0,
#   'boredom': 1.0,
#   'empty': 2.0,
#   'fear': 15.0,
#   'sadness': 67.0,
#   'worry': 13.0},
#  962: {'anger': 2.0,
#   'boredom': 8.0,
#   'empty': 2.0,
#   'fear': 6.0,
#   'hate': 1.0,
#   'relief': 1.0,
#   'sadness': 2.0,
#   'worry': 78.0},
#  963: {'anger': 12.0,
#   'boredom': 5.0,
#   'empty': 1.0,
#   'fear': 44.0,
#   'hate': 7.0,
#   'sadness': 16.0,
#   'worry': 16.0},
#  964: {'surprise': 100.0},
#  965: {'enthusiasm': 1.0,
#   'fun': 3.0,
#   'happiness': 1.0,
#   'neutral': 92.0,
#   'relief': 2.0},
#  966: {'surprise': 100.0},
#  967: {'surprise': 100.0},
#  968: {'anger': 2.0,
#   'boredom': 1.0,
#   'fear': 29.0,
#   'fun': 1.0,
#   'sadness': 59.0,
#   'surprise': 1.0,
#   'worry': 8.0},
#  969: {'anger': 78.0,
#   'fear': 1.0,
#   'joy': 10.0,
#   'love': 4.0,
#   'sadness': 6.0,
#   'surprise': 1.0},
#  970: {'anger': 1.0, 'fear': 2.0, 'joy': 11.0, 'surprise': 86.0},
#  971: {'enthusiasm': 2.0, 'hate': 1.0, 'relief': 97.0},
#  972: {'anger': 6.0, 'fear': 56.0, 'sadness': 37.0},
#  973: {'enthusiasm': 3.0,
#   'fun': 6.0,
#   'happiness': 69.0,
#   'love': 1.0,
#   'neutral': 2.0,
#   'relief': 19.0},
#  974: {'anger': 97.0, 'fear': 2.0},
#  975: {'anger': 1.0,
#   'joy': 84.0,
#   'love': 8.0,
#   'relief': 1.0,
#   'sadness': 3.0,
#   'surprise': 2.0},
#  976: {'anger': 98.0, 'hate': 1.0, 'surprise': 1.0},
#  977: {'anger': 3.0,
#   'boredom': 2.0,
#   'enthusiasm': 1.0,
#   'joy': 28.0,
#   'relief': 60.0,
#   'sadness': 3.0,
#   'worry': 2.0},
#  978: {'anger': 12.0, 'fear': 67.0, 'sadness': 21.0},
#  979: {'relief': 84.0, 'worry': 15.0},
#  980: {'anger': 12.0,
#   'boredom': 1.0,
#   'enthusiasm': 2.0,
#   'fear': 2.0,
#   'fun': 2.0,
#   'joy': 46.0,
#   'neutral': 1.0,
#   'relief': 3.0,
#   'sadness': 6.0,
#   'surprise': 23.0},
#  981: {'happiness': 7.0, 'neutral': 1.0, 'relief': 88.0, 'worry': 2.0},
#  982: {'relief': 100.0},
#  983: {'anger': 89.0, 'fear': 1.0, 'joy': 5.0, 'sadness': 5.0},
#  984: {'enthusiasm': 1.0,
#   'hate': 16.0,
#   'neutral': 1.0,
#   'sadness': 1.0,
#   'surprise': 21.0,
#   'worry': 57.0},
#  985: {'anger': 2.0, 'joy': 97.0},
#  986: {'joy': 100.0},
#  987: {'happiness': 62.0, 'neutral': 1.0, 'relief': 35.0, 'worry': 1.0},
#  988: {'anger': 82.0,
#   'fear': 2.0,
#   'joy': 1.0,
#   'sadness': 9.0,
#   'surprise': 5.0},
#  989: {'anger': 1.0,
#   'fear': 1.0,
#   'joy': 1.0,
#   'love': 2.0,
#   'sadness': 1.0,
#   'surprise': 94.0},
#  990: {'joy': 99.0},
#  991: {'fear': 1.0, 'surprise': 98.0},
#  992: {'fun': 1.0,
#   'happiness': 10.0,
#   'love': 1.0,
#   'neutral': 1.0,
#   'relief': 10.0,
#   'surprise': 75.0,
#   'worry': 1.0},
#  993: {'anger': 1.0,
#   'joy': 92.0,
#   'love': 5.0,
#   'sadness': 1.0,
#   'surprise': 1.0},
#  994: {'love': 2.0,
#   'neutral': 5.0,
#   'sadness': 2.0,
#   'surprise': 90.0,
#   'worry': 1.0},
#  995: {'anger': 2.0,
#   'boredom': 3.0,
#   'empty': 1.0,
#   'sadness': 91.0,
#   'worry': 2.0},
#  996: {'enthusiasm': 1.0, 'fun': 71.0, 'surprise': 26.0, 'worry': 1.0},
#  997: {'anger': 3.0,
#   'boredom': 6.0,
#   'empty': 1.0,
#   'enthusiasm': 1.0,
#   'fear': 54.0,
#   'hate': 4.0,
#   'sadness': 5.0,
#   'worry': 25.0},
#  998: {'anger': 1.0,
#   'boredom': 1.0,
#   'fear': 11.0,
#   'sadness': 43.0,
#   'worry': 43.0},
#  999: {'enthusiasm': 7.0,
#   'fun': 3.0,
#   'happiness': 57.0,
#   'neutral': 26.0,
#   'relief': 5.0},
#  ...}

# %% [markdown]
# Realizamos la creación de una lista que va almacenando los resultados por sentimiento de cada una de las conversaciones, esto lo hacemos para hacer una ponderación después y obtener resultados globales de las emociones de los usuarios.

# %%
anger=[]
boredom=[]
empty=[]
fun=[]
happiness=[]
relief=[]
neutral=[]
worry=[]
love=[]
sadness=[]
surprise=[]
hate=[]
enthusiasm=[]
fear=[]
joy=[]
for name, value in dic_sentiment.items():
  for n, v in value.items():
    if n=='anger':
      anger.append(v)
    if n=='boredom':
      boredom.append(v)
    if n=='empty':
      empty.append(v)
    if n=='fun':
      fun.append(v)
    if n=='happiness':
      happiness.append(v)
    if n=='relief':
      relief.append(v)
    if n=='neutral':
      neutral.append(v)
    if n=='worry':
      worry.append(v)
    if n=='love':
      love.append(v)
    if n=='sadness':
      sadness.append(v)
    if n=='surprise':
      surprise.append(v)
    if n=='hate':
      hate.append(v)
    if n=='enthusiasm':
      enthusiasm.append(v)
    if n=='joy':
      joy.append(v)
    if n=='fear':
      fear.append(v)

# %%
sentiment=['enojo','desinterés','vacio','diversión','felicidad','alivio','neutral','preocupación','amor','incertidumbre','sorpresa','odio','entusiasmo', 'miedo', 'disfrute']
percentage=[sum(anger)/len(df),sum(boredom)/len(df),sum(empty)/len(df), sum(fun)/len(df), sum(happiness)/len(df), sum(relief)/len(df), sum(neutral)/len(df), sum(worry)/len(df), sum(love)/len(df),sum(sadness)/len(df), sum(surprise)/len(df), sum(hate)/len(df), sum(enthusiasm)/len(df), sum(fear)/len(df), sum(joy)/len(df)]
results=pd.DataFrame(sentiment)
results=results.rename(columns={0:'sentiment'})
results['percentage']=percentage

# %%
plot_result(results,'Distribución Emociones')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1f81a714-8621-44ab-bf0b-989ff00debd6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1f81a714-8621-44ab-bf0b-989ff00debd6")) {
#                     Plotly.newPlot(
#                         '1f81a714-8621-44ab-bf0b-989ff00debd6',
#                         [{"customdata": [["enojo"], ["desinter\u00e9s"], ["vacio"], ["diversi\u00f3n"], ["felicidad"], ["alivio"], ["neutral"], ["preocupaci\u00f3n"], ["amor"], ["incertidumbre"], ["sorpresa"], ["odio"], ["entusiasmo"], ["miedo"], ["disfrute"]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hole": 0.3, "hoverlabel": {"namelength": 0}, "hovertemplate": "sentiment=%{label}<br>percentage=%{value}", "labels": ["enojo", "desinter\u00e9s", "vacio", "diversi\u00f3n", "felicidad", "alivio", "neutral", "preocupaci\u00f3n", "amor", "incertidumbre", "sorpresa", "odio", "entusiasmo", "miedo", "disfrute"], "legendgroup": "", "marker": {"colors": ["#636efa", "#EF553B", "#00cc96", "#ab63fa", "#FFA15A", "#19d3f3", "#FF6692", "#B6E880", "#FF97FF", "#FECB52", "#636efa", "#EF553B", "#00cc96", "#ab63fa", "#FFA15A"]}, "name": "", "showlegend": true, "type": "pie", "values": [16.438180956892467, 1.017764092846992, 1.1489815253434392, 1.5348176219801042, 3.8382283278067266, 9.974419706300331, 3.502131691141639, 7.842965419232591, 3.6390336333491238, 6.933680720037897, 21.90241591662719, 2.5611084793936523, 0.6437707247749882, 4.743249644718143, 13.777593557555662]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %% [markdown]
# Para poder hacer la gráfica de sentimientos en versión polar debemos estandarizar todos los valores y esto lo hacemos con la función de MinMaxScaler()

# %%
#Para dibujar los sentimientos de forma polar
# diferencia con emociones. Sentimientos: Polaridad positiva o negativa, extendido en el tiempo. emociones :polaridad con mas granularidad, feliz ,contento, triste, deprimido , dura menos

results=results.rename(columns={'sentiment':'sentimiento','percentage':'porcentaje'})
results=results.set_index('sentimiento')
df_scaled = pd.DataFrame(MinMaxScaler().fit_transform(results), columns=results.columns)
results.reset_index(inplace=True)
results=results['sentimiento']
df_scaled=df_scaled.merge(results, how='inner', on=results.index)

# %%
df_scaled_personal=df_scaled

# %%
fig=px.line_polar(df_scaled, 
              r="porcentaje", 
              theta="sentimiento", 
              title='Distribución de las emociones de los usuarios en las conversaciones',
              #color="darkgreen", 
              line_close=True,
              line_shape='spline',
              range_r=[0, 1],
              color_discrete_sequence=["#25427B","gold"])
              #color_discrete_sequence=px.colors.qualitative.G10)
fig.write_html("personal_polar_usuario_.html")

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9502423b-2196-4f10-9fc1-5b52657269f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9502423b-2196-4f10-9fc1-5b52657269f2")) {
#                     Plotly.newPlot(
#                         '9502423b-2196-4f10-9fc1-5b52657269f2',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "porcentaje=%{r}<br>sentimiento=%{theta}", "legendgroup": "", "line": {"color": "#25427B", "dash": "solid", "shape": "spline"}, "mode": "lines", "name": "", "r": [0.7429641018784677, 0.017592530695010804, 0.02376495755063841, 0.041914566481716695, 0.15026628339684026, 0.4389108006328408, 0.13445640305724535, 0.338647859705417, 0.14089622746618535, 0.2958753927401564, 1.0, 0.09019096641932392, 0.0, 0.19283820219711656, 0.6178109053635493, 0.7429641018784677], "showlegend": false, "subplot": "polar", "theta": ["enojo", "desinter\u00e9s", "vacio", "diversi\u00f3n", "felicidad", "alivio", "neutral", "preocupaci\u00f3n", "amor", "incertidumbre", "sorpresa", "odio", "entusiasmo", "miedo", "disfrute", "enojo"], "type": "scatterpolar"}],
#                         {"legend": {"tracegroupgap": 0}, "polar": {"angularaxis": {"direction": "clockwise", "rotation": 90}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "radialaxis": {"range": [0, 1]}}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": "" ...

# %% [markdown]
# <b><font color=orange size=5> Analisis de sentimientos</font></b>

# %%
df_personal0=df_personal

# %%
df_personal.columns
# Out:
# Index(['name_file', 'agent', 'client', 'speech_ratio', 'confidance', 'Mes',
#        'transcripcion', 'owner', 'raw', 'len_trans', 'media', 'desv',
#        'lim_atip_max', 'atipico', 'transcripcion1'],
#       dtype='object')

# %%
# %%time

#Seleccion de los datos
segmento='Experiencia general del cliente'
df_personal=df_personal0
# df_personal=df_personal.rename(columns={'client':'transcripcion'})#solo silenciar esta linea

# Normalizacion de valores perdidos
df_personal['transcripcion'] = df_personal['transcripcion'].apply(lambda x: '' if ((len(str(x)) == 3) & ((str(x) == 'NAN') | (str(x) == 'nan'))) | ((len(str(x)) == 4) & ((str(x) == 'NONE') | (str(x) == 'none') | (str(x) == 'None'))) else x)

# Aplicacion analisis de polaridad
#df_personal['polaridad_cliente'] = df_personal['transcripcion'].apply(lambda x: sentiment.sentiment(x))
df_personal['polaridad_cliente'] = df_personal['transcripcion'].apply(polaridad)

# Persistencia
# dfgral.to_parquet(rt1 + 'operativo_sentiment.parquet')

#Asignacion del sentimiento
df_personal['sentimiento_cliente'] = df_personal['polaridad_cliente'].apply(lambda x:'Negativos' if x<=0.001 else('Positivos' if x>=0.08 else 'Neutrales'))

df=df_personal
names = 'Negativos', 'Positivos', 'Neutrales'

b = len(df[df.sentimiento_cliente=='Positivos'])
a = len(df[df.sentimiento_cliente=='Negativos'])
c = len(df[df.sentimiento_cliente=='Neutrales'])

sizes=[a, b, c]

df0=pd.DataFrame()
df0['experiencia']=[ 'Negativos', 'Positivos', 'Neutrales']
df0['cantidad']=sizes

fig = px.pie(df0, values='cantidad', names='experiencia',hole=0.5,title=segmento,color_discrete_sequence=["#25427B","#33BBFF","#EBECED"])
fig.show()
fig.write_html(segmento+"_polaridad.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0ab02bfd-eae7-459b-84a6-64715d7eb585" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0ab02bfd-eae7-459b-84a6-64715d7eb585")) {
#                     Plotly.newPlot(
#                         '0ab02bfd-eae7-459b-84a6-64715d7eb585',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hole": 0.5, "hoverlabel": {"namelength": 0}, "hovertemplate": "experiencia=%{label}<br>cantidad=%{value}", "labels": ["Negativos", "Positivos", "Neutrales"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [1896, 495, 1831]}],
#                         {"legend": {"tracegroupgap": 0}, "piecolorway": ["#25427B", "#33BBFF", "#EBECED"], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks ...
# CPU times: user 21min 13s, sys: 6.19 s, total: 21min 19s
# Wall time: 21min 19s

# %%
while True:pass
